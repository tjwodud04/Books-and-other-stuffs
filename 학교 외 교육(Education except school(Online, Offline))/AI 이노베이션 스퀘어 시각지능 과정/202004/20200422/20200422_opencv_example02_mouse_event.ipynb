# %%
import cv2 as cv

# %%
def on_mouse(event, x, y, flags, param):
    print(event, x, y, flags, param)

img = cv.imread('cat.jpg', cv.IMREAD_UNCHANGED)

cv.namedWindow('img')
cv.setMouseCallback('img', on_mouse)

cv.imshow('img', img)
cv.waitKey()

cv.destroyAllWindows()
# Out:
# 0 478 182 0 None
# 0 477 181 0 None
# 0 475 180 0 None
# 0 473 180 0 None
# 0 472 179 0 None
# 0 470 178 0 None
# 0 470 178 0 None
# 0 468 178 0 None
# 0 466 177 0 None
# 0 465 177 0 None
# 0 463 176 0 None
# 0 462 175 0 None
# 0 461 175 0 None
# 0 459 174 0 None
# 0 458 174 0 None
# 0 458 174 0 None
# 0 457 173 0 None
# 0 455 173 0 None
# 0 454 172 0 None
# 0 453 172 0 None
# 0 451 171 0 None
# 0 449 171 0 None
# 0 447 170 0 None
# 0 446 169 0 None
# 0 446 169 0 None
# 0 443 168 0 None
# 0 442 168 0 None
# 0 440 168 0 None
# 0 439 167 0 None
# 0 436 166 0 None
# 0 435 166 0 None
# 0 433 166 0 None
# 0 432 165 0 None
# 0 430 165 0 None
# 0 430 165 0 None
# 0 428 164 0 None
# 0 426 163 0 None
# 0 424 163 0 None
# 0 422 163 0 None
# 0 421 163 0 None
# 0 420 162 0 None
# 0 418 162 0 None
# 0 416 161 0 None
# 0 416 161 0 None
# 0 415 161 0 None
# 0 414 161 0 None
# 0 412 160 0 None
# 0 410 160 0 None
# 0 409 159 0 None
# 0 406 159 0 None
# 0 405 159 0 None
# 0 404 158 0 None
# 0 402 157 0 None
# 0 400 157 0 None
# 0 398 157 0 None
# 0 397 157 0 None
# 0 395 157 0 None
# 0 393 156 0 None
# 0 392 156 0 None
# 0 392 155 0 None
# 0 390 155 0 None
# 0 389 155 0 None
# 0 388 154 0 None
# 0 387 154 0 None
# 0 386 154 0 None
# 0 385 153 0 None
# 0 384 153 0 None
# 0 383 153 0 None
# 0 382 153 0 None
# 0 382 152 0 None
# 0 381 152 0 None
# 0 380 152 0 None
# 0 379 152 0 None
# 0 378 151 0 None
# 0 377 151 0 None
# 0 376 151 0 None
# 0 375 150 0 None
# 0 374 150 0 None
# 0 373 150 0 None
# 0 372 150 0 None
# 0 371 149 0 None
# 0 370 149 0 None
# 0 369 149 0 None
# 0 368 149 0 None
# 0 368 148 0 None
# 0 367 148 0 None
# 0 366 148 0 None
# 0 365 148 0 None
# 0 365 147 0 None
# 0 364 147 0 None
# 0 363 147 0 None
# 0 362 147 0 None
# 0 361 147 0 None
# 0 360 147 0 None
# 0 359 147 0 None
# 0 358 147 0 None
# 0 357 147 0 None
# 0 357 146 0 None
# 0 356 146 0 None
# 0 355 146 0 None
# 0 354 146 0 None
# 0 353 146 0 None
# 0 352 146 0 None
# 0 351 146 0 None
# 0 350 146 0 None
# 0 349 146 0 None
# 0 348 146 0 None
# 0 347 146 0 None
# 0 346 146 0 None
# 0 345 146 0 None
# 0 344 146 0 None
# 0 342 146 0 None
# 0 341 146 0 None
# 0 340 146 0 None
# 0 339 146 0 None
# 0 338 146 0 None
# 0 337 146 0 None
# 0 336 146 0 None
# 0 335 146 0 None
# 0 334 146 0 None
# 0 333 146 0 None
# 0 331 146 0 None
# 0 330 146 0 None
# 0 328 146 0 None
# 0 327 146 0 None
# 0 325 146 0 None
# 0 324 146 0 None
# 0 323 146 0 None
# 0 322 146 0 None
# 0 321 146 0 None
# 0 320 146 0 None
# 0 319 146 0 None
# 0 318 146 0 None
# 0 317 146 0 None
# 0 317 147 0 None
# 0 316 148 0 None
# 0 316 149 0 None
# 0 315 149 0 None
# 0 314 149 0 None
# 0 314 150 0 None
# 0 313 150 0 None
# 0 313 151 0 None
# 0 313 152 0 None
# 0 312 152 0 None
# 0 312 153 0 None
# 0 312 154 0 None
# 0 311 154 0 None
# 0 311 155 0 None
# 0 311 156 0 None
# 0 310 156 0 None
# 0 310 157 0 None
# 0 309 158 0 None

# %%
def on_mouse(event, x, y, flags, param):
    if event == cv.EVENT_LBUTTONDOWN:
        print('Left mouse button down at', x, y)

img = cv.imread('cat.jpg', cv.IMREAD_UNCHANGED)

cv.namedWindow('img')
cv.setMouseCallback('img', on_mouse)
cv.imshow('img', img)
cv.waitKey()
cv.destroyAllWindows()
# Out:
# Left mouse button down at 146 141

# %%
def on_mouse(event, x, y, flags, param):
    if event == cv.EVENT_LBUTTONDOWN:
        print('Left mouse button down at', x, y)
    elif event == cv.EVENT_LBUTTONUP:
        print('Left mouse button up at', x, y)
    elif event == cv.EVENT_RBUTTONDOWN:
        print('Right mouse button down at', x, y)
    elif event == cv.EVENT_RBUTTONUP:
        print('Right mouse button up at', x, y)
    elif event == cv.EVENT_LBUTTONDBLCLK:
        print('Left mouse button double clicked at', x, y)
    elif event == cv.EVENT_RBUTTONDBLCLK:
        print('Right mouse button double clicked at', x, y)
    elif event == cv.EVENT_MOUSEWHEEL:
        if flags > 0:
            print('mouse wheel scrolled up at', x, y)
        else:
            print('mouse wheel scrolled down at', x, y)

def on_mouse(event, x, y, flags, param):
    if event == cv.EVENT_LBUTTONDOWN:
        print('Left mouse button down at', x, y)
    elif event == cv.EVENT_LBUTTONUP:
        print('Left mouse button up at', x, y)
    elif event == cv.EVENT_RBUTTONDOWN:
        print('Right mouse button down at', x, y)
    elif event == cv.EVENT_RBUTTONUP:
        print('Right mouse button up at', x, y)
    elif event == cv.EVENT_LBUTTONDBLCLK:
        print('Left mouse button double clicked at', x, y)
    elif event == cv.EVENT_RBUTTONDBLCLK:
        print('Right mouse button double clicked at', x, y)
    elif event == cv.EVENT_MOUSEWHEEL:
        if flags > 0:
            print('mouse wheel scrolled up at', x, y)
        else:
            print('mouse wheel scrolled down at', x, y)

img = cv.imread('cat.jpg', cv.IMREAD_UNCHANGED)

cv.namedWindow('img')
cv.setMouseCallback('img', on_mouse)

cv.imshow('img', img)
cv.waitKey()

cv.destroyAllWindows()
# Out:
# Left mouse button down at 183 204
# Left mouse button up at 177 178
# Right mouse button down at 176 189
# Right mouse button up at 187 209
# mouse wheel scrolled down at 215 209
# mouse wheel scrolled up at 215 209
