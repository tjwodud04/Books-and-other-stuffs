# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (4.7.1)
# Requirement already satisfied: soupsieve>=1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4) (1.8)

# %%
html = """
<html>
    <head></head>
    <body>
        <div id="result">
            <p class="row">
                <a class="red">go to page1</a>
                <a class="blue">go to page2</a>
            </p>
        </div>
    </body>
</html>
"""

# %%
from bs4 import BeautifulSoup

dom = BeautifulSoup(html, "lxml")

# %%
type(dom.html.head), type(dom.html)
# Out:
# (bs4.element.Tag, bs4.element.Tag)

# %%
dom.a, dom.find('a')
# Out:
# (<a class="red">go to page1</a>, <a class="red">go to page1</a>)

# %%
for tag in dom.find_all('a'):
    print(tag.name, tag['class'], tag.text)
# Out:
# a ['red'] go to page1
# a ['blue'] go to page2

# %%
dom.prettify()
# Out:
# '<html>\n <head>\n </head>\n <body>\n  <div>\n   <p>\n    <a>\n     go to page\n    </a>\n   </p>\n  </div>\n </body>\n</html>\n'

# %%
dom.html.body.p, dom.p, [_ for _ in dom.p.children]
# Out:
# (<p>
#  <a>go to page</a>
#  </p>, <p>
#  <a>go to page</a>
#  </p>, ['\n', <a>go to page</a>, '\n'])

# %%
dom.find_all('', {'id':'result'})
# Out:
# [<div id="result">
#  <p class="row">
#  <a class="red">go to page1</a>
#  <a class="blue">go to page2</a>
#  </p>
#  </div>]

# %%
type(dom.div), type(dom.span)
try:
    dom.span.attr
    dom.h1.text
except AttributeError as e:
    print("Not found")
# Out:
# Not found

# %% [markdown]
# ### http://pythonscraping.com/pages/page3.html (Test Url)

# %%
from urllib import parse
import requests

header = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}

def download(url, params={}, retries=3):
    resp = None

    try:
        resp = requests.get(url, params=params, headers = header)
        resp.raise_for_status()
    except requests.exceptions.HTTPError as e:
        if 500 <= e.response.status_code < 600 and retries > 0:
            print(retries)
            resp = download(url, params, retries - 1)
        else:
            print(e.response.status_code)
            print(e.response.reason)
            print(e.request.headers)

    return resp

# %%
url = 'http://pythonscraping.com/pages/page3.html'
html = download(url)
dom = BeautifulSoup(html.text, 'lxml')
footer = dom.find('div', {'id':'footer'})

# %%
parent = footer.find_parent()
parent.name, parent.attrs
# Out:
# ('div', {'id': 'wrapper'})

# %%
children = parent.find_all()

# %%
children = parent.find_all(recursive=False)
for row in children:
    print(row.name, row.attrs)
# Out:
# img {'src': '../img/gifts/logo.jpg', 'style': 'float:left;'}
# h1 {}
# div {'id': 'content'}
# table {'id': 'giftList'}
# div {'id': 'footer'}

# %%
descendants = parent.find_all()
for row in descendants:
    print(row.name, row.attrs)
# Out:
# img {'src': '../img/gifts/logo.jpg', 'style': 'float:left;'}
# h1 {}
# div {'id': 'content'}
# p {}
# br {}
# br {}
# table {'id': 'giftList'}
# tr {}
# th {}
# th {}
# th {}
# th {}
# tr {'id': 'gift1', 'class': ['gift']}
# td {}
# td {}
# span {'class': ['excitingNote']}
# td {}
# td {}
# img {'src': '../img/gifts/img1.jpg'}
# tr {'id': 'gift2', 'class': ['gift']}
# td {}
# td {}
# span {'class': ['excitingNote']}
# td {}
# td {}
# img {'src': '../img/gifts/img2.jpg'}
# tr {'id': 'gift3', 'class': ['gift']}
# td {}
# td {}
# span {'class': ['excitingNote']}
# td {}
# td {}
# img {'src': '../img/gifts/img3.jpg'}
# tr {'id': 'gift4', 'class': ['gift']}
# td {}
# td {}
# span {'class': ['excitingNote']}
# td {}
# td {}
# img {'src': '../img/gifts/img4.jpg'}
# tr {'id': 'gift5', 'class': ['gift']}
# td {}
# td {}
# span {'class': ['excitingNote']}
# td {}
# td {}
# img {'src': '../img/gifts/img6.jpg'}
# div {'id': 'footer'}
# br {}

# %%
divChildren = children[2].find_all(recursive=False)
for row in divChildren:
    print(row.name, row.attrs, row.text)
# Out:
# p {}
# We haven't figured out how to make online shopping carts yet, but you can send us a check to:
# 123 Main St.
# Abuja, Nigeria
# We will then send your totally amazing gift, pronto! Please include an extra $5.00 for gift wrapping.

# %%
divTag = children[2]
children[1].name, divTag.find_previous_sibling().name
# Out:
# ('h1', 'h1')

# %%
divTag.find_next_sibling()
# Out:
# <table id="giftList">
# <tr><th>
# Item Title
# </th><th>
# Description
# </th><th>
# Cost
# </th><th>
# Image
# </th></tr>
# <tr class="gift" id="gift1"><td>
# Vegetable Basket
# </td><td>
# This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
# <span class="excitingNote">Now with super-colorful bell peppers!</span>
# </td><td>
# $15.00
# </td><td>
# <img src="../img/gifts/img1.jpg"/>
# </td></tr>
# <tr class="gift" id="gift2"><td>
# Russian Nesting Dolls
# </td><td>
# Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
# </td><td>
# $10,000.52
# </td><td>
# <img src="../img/gifts/img2.jpg"/>
# </td></tr>
# <tr class="gift" id="gift3"><td>
# Fish Painting
# </td><td>
# If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
# </td><td>
# $10,005.00
# </td><td>
# <img src="../img/gifts/img3.jpg"/>
# </td></tr>
# <tr class="gift" id="gift4"><td>
# Dead Parrot
# </td><td>
# This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
# </td><td>
# $0.50
# </td><td>
# <img src="../img/gifts/img4.jpg"/>
# </td></tr>
# <tr class="gift" id="gift5"><td>
# Mystery Box
# </td><td>
# If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
# </td><td>
# $1.50
# </td><td>
# <img src="../img/gifts/img6.jpg"/>
# </td></tr>
# </table>

# %%
children[3] == divTag.find_next_sibling()
# Out:
# True

# %%
alist = dom.find_all('tr')
for row in alist:
    print(row.find_all(recursive = False)[2].text.strip())
# Out:
# Cost
# $15.00
# $10,000.52
# $10,005.00
# $0.50
# $1.50

# %%
import requests
google = download("https://www.google.com/search", params={"q":"박보영"})

# %%
html = download("http://pythonscraping.com/pages/page3.html")
exercise = BeautifulSoup(html.text, "lxml")

# %%
footer = exercise.find("", {"id":"footer"})

# %%
footer.name, footer["id"], \
footer.find_parent().name, footer.find_parent()["id"], \
footer.find_parent().find_parent().name #(.name = 태그이름) (.attrs = 속성(키-밸류))
# Out:
# ('div', 'footer', 'div', 'wrapper', 'body')

# %%
[_.name for _ in parent.find_all(recursive=False)]
# Out:
# ['img', 'h1', 'div', 'table', 'div']

# %%
[_.name for _ in footer.find_previous_siblings()]
# Out:
# ['table', 'div', 'h1', 'img']

# %%
[_.text.strip() for _ in parent.find_all(recursive=False)[3].find_all("th")]
# Out:
# ['Item Title', 'Description', 'Cost', 'Image']

# %%
exercise.find_all("td")
# Out:
# [<td>
#  Vegetable Basket
#  </td>, <td>
#  This vegetable basket is the perfect gift for your health conscious (or overweight) friends!
#  <span class="excitingNote">Now with super-colorful bell peppers!</span>
#  </td>, <td>
#  $15.00
#  </td>, <td>
#  <img src="../img/gifts/img1.jpg"/>
#  </td>, <td>
#  Russian Nesting Dolls
#  </td>, <td>
#  Hand-painted by trained monkeys, these exquisite dolls are priceless! And by "priceless," we mean "extremely expensive"! <span class="excitingNote">8 entire dolls per set! Octuple the presents!</span>
#  </td>, <td>
#  $10,000.52
#  </td>, <td>
#  <img src="../img/gifts/img2.jpg"/>
#  </td>, <td>
#  Fish Painting
#  </td>, <td>
#  If something seems fishy about this painting, it's because it's a fish! <span class="excitingNote">Also hand-painted by trained monkeys!</span>
#  </td>, <td>
#  $10,005.00
#  </td>, <td>
#  <img src="../img/gifts/img3.jpg"/>
#  </td>, <td>
#  Dead Parrot
#  </td>, <td>
#  This is an ex-parrot! <span class="excitingNote">Or maybe he's only resting?</span>
#  </td>, <td>
#  $0.50
#  </td>, <td>
#  <img src="../img/gifts/img4.jpg"/>
#  </td>, <td>
#  Mystery Box
#  </td>, <td>
#  If you love suprises, this mystery box is for you! Do not place on light-colored surfaces. May cause oil staining. <span class="excitingNote">Keep your friends guessing!</span>
#  </td>, <td>
#  $1.50
#  </td>, <td>
#  <img src="../img/gifts/img6.jpg"/>
#  </td>]

# %%
td = exercise.find("", {"id":"gift1"})

# %%
table = footer.find_previous_sibling()
tr = table.find_all("tr", {"class":"gift"})
for _ in tr:
    print(_.find_all(recursive=False)[2].text.strip())

#for _ in execise.find_all("tr", {"class":"gift"}):
# print(_.find_all(recursive=False)[2].text.strip())
# Out:
# $15.00
# $10,000.52
# $10,005.00
# $0.50
# $1.50

# %%
import re
[_.text.strip() for _ in exercise.find_all("td", text=re.compile("[0-9]+.\d+"))]
# Out:
# ['$15.00', '$10,000.52', '$10,005.00', '$0.50', '$1.50']

# %%
[_["src"] for _ in exercise.find_all("img", {"src":re.compile("../img/gifts/img[0-9]+.jpg")})]
# Out:
# ['../img/gifts/img1.jpg',
#  '../img/gifts/img2.jpg',
#  '../img/gifts/img3.jpg',
#  '../img/gifts/img4.jpg',
#  '../img/gifts/img6.jpg']

# %%
[requests.compat.urljoin(html.request.url, _["src"]) for _ in exercise.find_all("img", {"src":re.compile("../img/gifts/img\d+.jpg")})]
# Out:
# ['http://pythonscraping.com/img/gifts/img1.jpg',
#  'http://pythonscraping.com/img/gifts/img2.jpg',
#  'http://pythonscraping.com/img/gifts/img3.jpg',
#  'http://pythonscraping.com/img/gifts/img4.jpg',
#  'http://pythonscraping.com/img/gifts/img6.jpg']

# %%
html.request.url
# Out:
# 'http://pythonscraping.com/pages/page3.html'

# %%
from urllib import request, error, parse
html = download("https://www.google.com/search", {"q":"박보영"})
practice = BeautifulSoup(html.text, "lxml")

# %%
html.request.url
# Out:
# 'https://www.google.com/sorry/index?continue=https://www.google.com/search%3Fq%3D%25EB%25B0%2595%25EB%25B3%25B4%25EC%2598%2581&q=EgRzWzdDGLjxsOYFIhkA8aeDS_A3nNucx6i2cnS7v5MQm7snKi5hMgFy'

# %%
practice.find_all("h3", {"class":"LC201b"})
# Out:
# []

# %%
for h3 in practice.find_all("h3", {"class":"LC201b"}):
    print(h3.text.strip())
    print(_.find_parent()["href"])

# %%
result = dict()
for _ in google.find_all("h3", {"class":"LC201b"}):
    result[_.text.strip()] = .find_parent()
    print(h3.text.strip())
    print(_.find_parent()["href"])

# %%
html = download("https://search.naver.com/search.naver", {"query":"박보영"})
test = BeautifulSoup(html.text, "lxml")

# %%
print(html)
# Out:
# <Response [200]>

# %%
print(practice)
# Out:
# <!DOCTYPE html>
# <html lang="ko"> <head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="박보영 : 네이버 통합검색" property="og:title"/> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'박보영'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'박보영'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>박보영 : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_140327.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"/><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_190221.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_190221.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/api_atcmp_181122.css" rel="stylesheet" type="text/css"/><script type="text/javascript"> naver = window.naver || {}; naver.search = naver.search || {}; var g_D = 0 ; if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } function urlencode (q) { return escape(q).replace(/\+/g, "%2B") ; } function urlexpand (url) { var href = document.location.href ; if (url == "") return href ; if (url.match(/^[-.A-Za-z]+:/)) return url ; if (url.charAt(0) == '#') return href.split("#")[0] + url ; if (url.charAt(0) == '?') return href.split("?")[0] + url ; if (url.charAt(0) == '/') return href.replace(/([^:\/])\/.*$/, "$1") + url ; return href.substring(0, href.lastIndexOf("/")+1) + url ; } naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; expires=" + exdate.toUTCString(); } } cookie = cookie + "; path=/"; if (domain != null) { cookie = cookie + "; domain=" + domain; } document.cookie = cookie; }, get : function (key) { var cookie_list = document.cookie.split(/\s*;\s*/); for (var i = 0; i < cookie_list.length; i++) { var tmp_list = cookie_list[i].split("="); var c_key = tmp_list[0].trim(); var c_value = tmp_list[1]; if (key == c_key) { return unescape(c_value); } } return null; } } })(); naver.search.https = window.location.protocol == "https:"; naver.search.meta_referrer = 0; var _nx_js_load = (function () { var scrs = {} ; return function (script, callback) { scrs[script] = {} ; scrs[script].domscript = document.createElement('script'); scrs[script].domscript.src = script ; if (callback) scrs[script].callback = (callback instanceof Array) ? callback : [callback]; scrs[script].domscript.onloadDone = false; scrs[script].domscript.onload = function() { scrs[script].domscript.onloadDone = true; if (scrs[script].callback) { for (var i = 0; i < scrs[script].callback.length; i++) { scrs[script].callback[i]() ; } } scrs[script].domscript.onload = scrs[script].domscript.onreadystatechange = null; } ; scrs[script].domscript.onreadystatechange = function() { if ( ("loaded" === scrs[script].domscript.readyState || "complete" === scrs[script].domscript.readyState) && !scrs[script].domscript.onloadDone ) { scrs[script].domscript.onload(); } } ; document.getElementsByTagName('head')[0].appendChild(sc ...
# <script type="text/javascript"> /* thumnail 처리 */ function on_realtime_nxtab_noimage(img, type ) { img.onerror=null; img.src="https://ssl.pstatic.net/sstatic/search/img3/img_profile_twitter5.png"; img.alt="이미지 준비중"; img.width="50"; img.height="50"; } </script> <div class="realtime2 section _prs_rea_doc" id="realTimeSearchBody"> <div class="section_head"> <h2>실시간검색</h2> <a class="link_help" href="https://help.naver.com/support/alias/search/integration/integration_7.naver" onclick="return goOtherCR(this, 'a=rea.help&amp;r=0&amp;i=0&amp;u='+urlencode(this.href));" target="_blank"><i class="sprenew api_ico_help">도움말</i></a> <p class="title_desc sort"> <strong>최신</strong> <span class="bar"></span> <a href="?where=realtime&amp;sm=tab_smr&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;ie=utf8&amp;best=1" onclick="return goOtherCR(this, 'a=rea.pop&amp;r=0&amp;i=0&amp;u='+urlencode(this.href));">인기</a> </p> <div class="rt_update"><span class="update_state"></span></div> </div> <h3 class="blind">최신순</h3> <div class="rt_wrap rt_wrap2"> <div> <ul class="type01"> <li class="first_child"> <div class="thumb"> <a crlink="a=rea_doc*e.img&amp;r=&amp;i=9015809d_000000040000000065FE36BF&amp;ps=&amp;nd=&amp;u=" href="http://news.naver.com/main/pass.nhn?type=commentList&amp;id=news241,0002909559" target="_blank"><img alt="연예 댓글" height="50" src="https://ssl.pstatic.net/sstatic/search/2015/ico_rt_entertain.png" width="50"/> <span class="mask"></span> <span class="valign"></span> </a> </div> <dl> <dd> <a class="rt_user" crlink="a=rea_doc*e.id&amp;r=&amp;i=9015809d_000000040000000065FE36BF&amp;ps=&amp;nd=&amp;u=" href="http://news.naver.com/main/pass.nhn?type=commentList&amp;id=news241,0002909559" target="_blank"><span class="user_name">qkqh****</span></a> </dd> <dd><a class="txt_link" crlink="a=rea_doc*e.comment&amp;r=&amp;i=9015809d_000000040000000065FE36BF&amp;ps=&amp;nd=&amp;u=" href="http://news.naver.com/main/pass.nhn?type=commentList&amp;id=news241,0002909559" target="_blank">잘생겼다~ ^^ 대배우♡ 홧팅!!!</a></dd> <dd class="rt_sub _rt_time _time_1556886107"> <div class="sub_area"> <span class="sub_time _timeinfo">7분 전</span> <span class="bar"></span> <span class="sub_reply">답글 0</span> <span class="bar"></span> <span class="sub_like">공감 0</span> <span class="bar"></span> <span class="sub_dis">비공감 0</span> </div> </dd> <dd class="rt_org"> <div class="org_area"> <a class="org_thumb" crlink="a=rea_doc*e.source&amp;r=&amp;i=9015809d_000000040000000065FE36BF&amp;ps=&amp;nd=&amp;u=" href="http://news.naver.com/main/pass.nhn?type=commentService&amp;id=news241,0002909559" target="_blank"><img alt="'어비스' 이시언 &quot;박보영 팬이라 선택…대본에 스킨십 없어져 섭섭&quot;" height="30" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Forigin%2F241%2F2019%2F05%2F03%2F2909559.jpg&amp;type=n66_66_re2" width="30"/> <span class="mask"></span> <span class="valign"></span></a> <div class="org_info"> <a class="info_tit" crlink="a=rea_doc*e.source&amp;r=&amp;i=9015809d_000000040000000065FE36BF&amp;ps=&amp;nd=&amp;u=" href="http://news.naver.com/main/pass.nhn?type=commentService&amp;id=news241,0002909559" target="_blank">'어비스' 이시언 "<strong class="hl">박보영</strong> 팬이라 선택…대본에 스킨십 없어져 섭섭"</a> <a class="info_cite" crlink="a=rea_doc*e.source&amp;r=&amp;i=9015809d_000000040000000065FE36BF&amp;ps=&amp;nd=&amp;u=" href="http://news.naver.com/main/pass.nhn?type=commentService&amp;id=news241,0002909559" target="_blank"><cite>entertain.naver.com</cite></a> </div> </div> </dd></dl> </li> <li class=""> <div class="thumb"> <a crlink="a=rea_doc*e.img&amp;r=&amp;i=9015809d_0000000400000000663F0C45&amp;ps=&amp;nd=&amp;u=" href="http://news.naver.com/main/pass.nhn?type=commentList&amp;id=news410,0000581707" target="_blank"><img alt="연예 댓글" height="50" src="https://ssl.pstatic.net/sstatic/search/2015/ico_rt_entertain.png" width="50"/> <span class="mask"></span> <span class="valign"></span> </a> </div> <dl> <dd> <a class="rt_user" crlink= ...
# </div><div class="sub_pack" id="sub_pack"><div class="content_search section" data-dss-logarea="x8d"> <div class="content03"> <div class="header"> <h2><a href="?where=nexearch&amp;sm=tab_etc&amp;pkid=1&amp;os=126986&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" nocr="" onclick="return goOtherCR(this, 'a=nco_x8d*3.name&amp;r=1&amp;i=1800000D_00000001F00A+1800000D_0000000741D8+1800000D_0000001E06BD+1800000D_000000040A8A&amp;u=' + urlencode(this.href));">박보영(영화배우)</a>의 V LIVE 정보</h2> </div> <div class="contents03_sub"> <link href="https://ssl.pstatic.net/sstatic/keypage/outside/scui/v_con/css/cs_v_con_171124.css" rel="stylesheet" type="text/css"/> <div class="cs_v_con_side _cs_v_con_side"> <div class="v_celeb_info"> <span class="sns_thum"> <span class="sns_msk"></span> <img alt="Park Bo Young 프로필 이미지" height="32" onerror="this.onerror=null;this.src='...';" src="https://search.pstatic.net/common?type=f&amp;size=32x32&amp;quality=95&amp;direct=true&amp;src=http%3A%2F%2Fv.phinf.naver.net%2F20150811_37%2F1439277803334mfaj5_PNG%2Fupload_pby_profile.jpg.png" width="32"/> </span> <div class="sns_info"> <strong class="sns_name"> Park Bo Young </strong> <p class="sns_txt">팔로워<em>1,185,065</em></p> </div> <a class="btn_link" href="http://www.vlive.tv/channels/FCE49" nocr="" onclick="return goOtherCR(this, 'a=nco_x8d*3.vchannel&amp;r=1&amp;i=1800000D_00000001F00A+1800000D_0000000741D8+1800000D_0000001E06BD+1800000D_000000040A8A&amp;u=' + urlencode(this.href));" target="_blank"><span class="blind">Park Bo Young V</span></a> </div> <div class="v_thum_list"> <ul class="lst_thum"> <li> <a class="video_thum" href="http://www.vlive.tv/video/123513" nocr="" onclick="return goOtherCR(this, 'a=nco_x8d*3.img&amp;r=1&amp;i=1800000D_00000001F00A+1800000D_0000000741D8+1800000D_0000001E06BD+1800000D_000000040A8A&amp;u=' + urlencode(this.href));" target="_blank"> <span class="thum_msk"></span> <img alt="제목없음 썸네일 이미지" height="72" onerror="this.onerror=null;this.src='...';" src="https://search.pstatic.net/common?type=ofullfill_black&amp;size=128x72&amp;quality=95&amp;direct=true&amp;src=http%3A%2F%2Fv.phinf.naver.net%2F20190412_39%2F1555074899669M63Yz_JPEG%2Fe6b83b98-5d24-11e9-93af-505dac8c35ff_03.jpg" width="128"/> <span class="ico_play"></span> <dl class="play_time"> <dt>동영상 재생시간</dt> <dd>31분 23초</dd> </dl> </a> <div class="video_tit"><strong class="scm_ellipsis _ellipsis" style="height:34px"><a href="http://www.vlive.tv/video/123513" nocr="" onclick="return goOtherCR(this, 'a=nco_x8d*3.tit&amp;r=1&amp;i=1800000D_00000001F00A+1800000D_0000000741D8+1800000D_0000001E06BD+1800000D_000000040A8A&amp;u=' + urlencode(this.href));" target="_blank">제목없음</a></strong></div> <p class="video_date">2019.04.12. 22:16</p> <div class="video_detail_info"> <span class="video_play"><em class="ico ico_play"><span class="blind">재생수</span></em><span>99,337</span></span> </div> </li> <li> <a class="video_thum" href="http://www.vlive.tv/video/120051" nocr="" onclick="return goOtherCR(this, 'a=nco_x8d*3.img&amp;r=1&amp;i=1800000D_00000001F00A+1800000D_0000000741D8+1800000D_0000001E06BD+1800000D_000000040A8A&amp;u=' + urlencode(this.href));" target="_blank"> <span class="thum_msk"></span> <img alt="오랜만이네요~ 오늘은 목소리만. 썸네일 이미지" height="72" onerror="this.onerror=null;this.src='...';" src="https://search.pstatic.net/common?type=ofullfill_black&amp;size=128x72&amp;quality=95&amp;direct=true&amp;src=http%3A%2F%2Fv.phinf.naver.net%2F20190324_79%2F1553436186460Bs39p_JPEG%2F38250289305.jpg" width="128"/> <span class="ico_play"></span> <dl class="play_time"> <dt>동영상 재생시간</dt> <dd>54분 50초</dd> </dl> </a> <div class="video_tit"><strong class="scm_ellipsis _ellipsis" style="height:34px"><a href="http://www.vlive.tv/video/120051" nocr="" onclick="return goOtherCR(this, 'a=nco_x8d*3.tit&amp;r=1&amp;i=1800000D_00000001F00A+1800000D_0000000741D8+1800000D_0000001E06BD+1800000D_000000040A8A&amp;u=' + urlencode(this.href));" target="_blank">오랜만이네요~ 오늘은 목소리만.</a></strong></div> <p class="video_date">2019.03.25 ...

# %%
practice.find_all("a")
# Out:
# [<a href="#lnb"><span>메뉴 영역으로 바로가기</span></a>,
#  <a href="#content"><span>본문 영역으로 바로가기</span></a>,
#  <a class="spnew logo_naver" href="http://www.naver.com" onclick="return goOtherCR(this, 'a=sta.naver&amp;r=&amp;i=&amp;u='+urlencode(this.href));">NAVER</a>,
#  <a class="bt_atcp _btn_arw fold" href="#" onclick="return false;"><span class="blind _text">자동완성 펼치기</span><span class="ico_arrow spnew"></span></a>,
#  <a class="spat ico_info" href="https://help.naver.com/support/alias/search/word/word_16.naver" onclick="__atcmpCR(event, this, 'plus.help', '','','');" target="_blank"><span class="blind">도움말 보기</span></a>,
#  <a class="btn_turnon active" href="#" onclick="__atcmpCR(event, this, 'plus.use', '','','');">ON<span class="blind">선택됨</span></a>,
#  <a class="btn_turnoff" href="#" onclick="__atcmpCR(event, this, 'plus.unuse', '','','');">OFF</a>,
#  <a class="btn btn_login" href="https://nid.naver.com/nidlogin.login?url=https%3A%2F%2Fsearch.naver.com%2Fsearch.naver%3Fquery%3D%25EB%25B0%2595%25EB%25B3%25B4%25EC%2598%2581" onclick="__atcmpCR(event, this, 'plus.login', '','','');">로그인</a>,
#  <a class="btn btn_view" href="https://help.naver.com/support/alias/search/word/word_16.naver" onclick="__atcmpCR(event, this, 'plus.detail', '','','');" target="_blank">자세히</a>,
#  <a class="btn btn_view" href="https://help.naver.com/support/alias/search/word/word_21.naver" onclick="__atcmpCR(event, this, 'plus.detail', '','','');" target="_blank">자세히</a>,
#  <a class="_help" href="https://help.naver.com/support/alias/search/word/word_17.naver" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_18.naver" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 끄기</a>,
#  <a class="_help" href="https://help.naver.com/support/alias/search/word/word_17.naver" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_18.naver" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 끄기</a>,
#  <a class="_help" href="https://help.naver.com/support/alias/search/word/word_17.naver" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_18.naver" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 끄기</a>,
#  <a class="_help" href="https://help.naver.com/support/alias/search/word/word_17.naver" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_18.naver" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 켜기</a>,
#  <a href="javascript:;">최근검색어</a>,
#  <a href="javascript:;">내 검색어</a>,
#  <a class="t@my@ _star _myBtn" href="javascript:;" title="내 검색어 등록"><em class="spat">내 검색어 등록</em></a>,
#  <a class="keyword" href="javascript:;">@txt@</a>,
#  <a class="btn_delete spat _del" href="javascript:;" title="검색어삭제">삭제</a>,
#  <a class="ton _star _myBtn" href="javascript:;" title="내 검색어 해제"><em class="spat">내 검색어 해제</em></a>,
#  <a class="keyword" href="javascript:;">@txt@</a>,
#  <a class="_delMode" href="javascript:;">기록 삭제</a>,
#  <a class="_keywordOff" href="javascript:;">검색어저장 끄기</a>,
#  <a class="_acOff" href="javascript:;">자동완성 끄기</a>,
#  <a class="_delAll" href="javascript:;" title="최근 검색어 기록을 모두 삭제합니다.">기록 전체 삭제</a>,
#  <a class="_delDone" href="javascript:;">완료</a>,
#  <a class="_delAll" href="javascript:;" title="설정된 내 검색어를 모두 삭제합니다.">기록 전체 삭제</a>,
#  <a class="_keywordOff" href="javascript:;">검색어저장 끄기</a>,
#  <a class="_acOff" href="javascript:;">자동완성 끄기</a>,
#  <a class="btn_close _close" href="javascript:;"><i class="spat ico_close">닫기</i></a>,
#  <a class="_link" href="" onclick="return goOtherCR(this,'a=sug.vote&amp;r=&amp;i=&amp;u='+urlencode(this.href));" target="_blank">자세히보기</a>,
#  <a class="tab on" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_jum&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tab*N.now&amp;r=1&amp;i=&amp;u='+urlencode(this.href));"><span class="spnew name">통합검색</span></a>,
#  <a class="tab" href="?where=image&amp;sm=tab_jum&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tab*i.jmp&amp;r=2&amp;i=&amp;u='+urlencode(this.href));"><span class="spnew name">이미지</span></a>,
#  <a class="tab" href="?where=realtime&amp;sm=tab_jum&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tab*r.jmp&amp;r=3&amp;i=&amp;u='+urlencode(this.href));"><span class="spnew name">실시간검색</span></a>,
#  <a class="tab" href="?where=news&amp;sm=tab_jum&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tab*n.jmp&amp;r=4&amp;i=&amp;u='+urlencode(this.href));"><span class="spnew name">뉴스</span></a>,
#  <a class="tab" href="?where=post&amp;sm=tab_jum&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tab*b.jmp&amp;r=5&amp;i=&amp;u='+urlencode(this.href))"><span class="spnew name">블로그</span></a>,
#  <a class="tab" href="?where=video&amp;sm=tab_jum&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tab*v.jmp&amp;r=6&amp;i=&amp;u='+urlencode(this.href));"><span class="spnew name">동영상</span></a>,
#  <a class="tab" href="?where=article&amp;sm=tab_jum&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tab*c.jmp&amp;r=7&amp;i=&amp;u='+urlencode(this.href));"><span class="spnew name">카페</span></a>,
#  <a class="tab" href="http://m.post.naver.com/search/post.nhn?keyword=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tab*p.jmp&amp;r=8&amp;i=&amp;u='+urlencode(this.href));" target="_blank"><span class="spnew name">포스트</span><i class="spnew ico_window">새창</i></a>,
#  <a class="lnb_more" href="#" onclick="jQuery('#_nx_lnb_more').toggleClass('more_on'); tCR(jQuery('#_nx_lnb_more').hasClass('more_on') ? 'a=tab.more' : 'a=tmr.less'); return false;"><span class="spnew name">더보기</span></a>,
#  <a class="tab" href="?where=kin&amp;sm=tab_jum&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tmr*k.jmp&amp;r=1&amp;i=&amp;u='+urlencode(this.href));"><span class="spnew name">지식iN</span></a>,
#  <a class="tab" href="?where=webkr&amp;sm=tab_jum&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tmr*w.jmp&amp;r=2&amp;i=&amp;u='+urlencode(this.href));"><span class="spnew name">웹사이트</span></a>,
#  <a class="tab" href="?where=kdic&amp;sm=tab_jum&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tmr*K.jmp&amp;r=3&amp;i=&amp;u='+urlencode(this.href));"><span class="spnew name">지식백과</span></a>,
#  <a class="tab" href="https://search.shopping.naver.com/search/all.nhn?where=all&amp;frm=NVSCTAB&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tmr*S.jmp&amp;r=4&amp;i=&amp;u='+urlencode(this.href));" target="_blank"><span class="spnew name">쇼핑</span><i class="spnew ico_window">새창</i></a>,
#  <a class="tab" href="http://dic.naver.com/search.nhn?dicQuery=%EB%B0%95%EB%B3%B4%EC%98%81&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;target=dic&amp;query_utf=&amp;isOnlyViewEE=" onclick="return goOtherCR(this,'a=tmr*L.jmp&amp;r=5&amp;i=&amp;u='+urlencode(this.href));" target="_blank"><span class="spnew name">어학사전</span><i class="spnew ico_window">새창</i></a>,
#  <a class="tab" href="https://map.naver.com/local/search.nhn?query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tmr*M.jmp&amp;r=6&amp;i=&amp;u='+urlencode(this.href));" target="_blank"><span class="spnew name">지도</span><i class="spnew ico_window">새창</i></a>,
#  <a class="tab" href="http://book.naver.com/search/search.nhn?query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tmr*B.jmp&amp;r=7&amp;i=&amp;u='+urlencode(this.href));" target="_blank"><span class="spnew name">책</span><i class="spnew ico_window">새창</i></a>,
#  <a class="tab" href="http://music.naver.com/search/search.nhn?query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tmr*m.jmp&amp;r=8&amp;i=&amp;u='+urlencode(this.href));" target="_blank"><span class="spnew name">뮤직</span><i class="spnew ico_window">새창</i></a>,
#  <a class="tab" href="http://academic.naver.com/search.naver?field=0&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this,'a=tmr*a.jmp&amp;r=9&amp;i=&amp;u='+urlencode(this.href));" target="_blank"><span class="spnew name">학술정보</span><i class="spnew ico_window">새창</i></a>,
#  <a class="bt_option" href="#" id="_search_option_btn" onclick="return tCR('a=fno.option');" title="검색옵션 열기">검색옵션<span class="spnew ico_arrow"></span></a>,
#  <a class="bt_help" href="https://help.naver.com/support/alias/search/integration/integration_1.naver" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;a=fno.help&amp;r=&amp;i='); return false;" target="_blank"><span class="spnew ico_help">도움말</span></a>,
#  <a class="bt_origin" href="https://help.naver.com/support/alias/search/integration/integration_2.naver" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;a=fno.origin&amp;r=&amp;i='); return false;" target="_blank"><span class="spnew ico_origin">원본반영</span></a>,
#  <a class="bt_share naver-splugin" data-band-url="https://search.naver.com/search.naver?query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;sm=bdp_pin" data-blog-url="https://search.naver.com/search.naver?query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;sm=svc_pin.blog" data-cafe-source-form="2" data-cafe-url="https://search.naver.com/search.naver?query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;sm=svc_pin.cafe" data-calendar-url="https://search.naver.com/search.naver?query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;sm=svc_pin.cal" data-evkey="search" data-facebook-url="https://search.naver.com/search.naver?query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;sm=fbp_pin" data-mail-display="off" data-me-display="off" data-memo-url="https://search.naver.com/search.naver?query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;sm=svc_pin.memo" data-option="{baseElement:'spiButton2', layerPosition:'outside-bottom', align:'right', top:4, left:0, marginLeft:8, marginTop:10}" data-service-name="통합검색" data-style="unity-v2" data-twitter-url="https://search.naver.com/search.naver?query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;sm=twp_pin" data-use-short-url="on" href="#" id="spiButton2" onclick="return tCR('a=fno.pplugin');" title="보내기 열기/닫기"><span class="spnew naver-splugin-c ico_share"></span><span class="blind">보내기</span></a>,
#  <a class="m" href="#" id="_nx_search_option_sort_link" onclick="return tCR('a=fno.sortlink');">정렬<span class="spim"></span></a>,
#  <a href="#" onclick="nx_searchOptionSelect('so', 'r'); return false;">관련도순</a>,
#  <a href="#" onclick="nx_searchOptionSelect('so', 'dd'); return false;">최신순</a>,
#  <a class="m" href="#" id="_nx_search_option_date_link" onclick="return tCR('a=fno.datelink');">기간<span class="spim"></span></a>,
#  <a href="#" onclick="nx_searchOptionSelect('p', 'all'); return false;">전체</a>,
#  <a href="#" onclick="nx_searchOptionSelect('p', '1d'); return false;">1일</a>,
#  <a href="#" onclick="nx_searchOptionSelect('p', '1w'); return false;">1주</a>,
#  <a href="#" onclick="nx_searchOptionSelect('p', '1m'); return false;">1개월</a>,
#  <a href="#" onclick="nx_searchOptionSelect('p', '1y'); return false;">1년</a>,
#  <a class="spim _btn_start" href="#" onclick="return tCR('a=fno.datecalenderopen');">달력 레이어 호출</a>,
#  <a class="spim _btn_end" href="#" onclick="return tCR('a=fno.datecalenderopen');">달력 레이어 호출</a>,
#  <a class="m" href="#" id="_nx_search_option_area_link" onclick="return tCR('a=fno.alink');">영역<span class="spim"></span></a>,
#  <a href="#" onclick="nx_searchOptionSelect('a', 'all'); return false;">전체</a>,
#  <a href="#" onclick="nx_searchOptionSelect('a', 't'); return false;">제목</a>,
#  <a class="m" href="#" onclick="return tCR('a=fno.dtslink');">상세검색<span class="spim"></span></a>,
#  <a class="btn_help" href="https://help.naver.com/support/alias/search/integration/integration_4.naver" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;a=fno.dtshelp');" target="_blank">도움말</a>,
#  <a class="btn_initial _reset" href="#" onclick="return tCR('a=fno.dtsclear');">초기화</a>,
#  <a class="bt_pv2 calendar-btn-prev-year" href="#" onclick="return tCR('a=fno.datecalendercheck');" title="이전 년도"><span>이전 년도</span></a>,
#  <a class="bt_pv calendar-btn-prev-mon" href="#" onclick="return tCR('a=fno.datecalendercheck');" title="이전 달"><span>이전 달</span></a>,
#  <a class="bt_nx calendar-btn-next-mon" href="#" onclick="return tCR('a=fno.datecalendercheck');" title="다음 달"><span>다음 달</span></a>,
#  <a class="bt_nx2 calendar-btn-next-year" href="#" onclick="return tCR('a=fno.datecalendercheck');" title="다음 년도"><span>다음 년도</span></a>,
#  <a class="calendar-date" href="#" onclick="return tCR('a=fno.datecalendercheck');"></a>,
#  <a class="calendar-date" href="#" onclick="return tCR('a=fno.datecalendercheck');"></a>,
#  <a class="calendar-date" href="#" onclick="return tCR('a=fno.datecalendercheck');"></a>,
#  <a class="calendar-date" href="#" onclick="return tCR('a=fno.datecalendercheck');"></a>,
#  <a class="calendar-date" href="#" onclick="return tCR('a=fno.datecalendercheck');"></a>,
#  <a class="calendar-date" href="#" onclick="return tCR('a=fno.datecalendercheck');"></a>,
#  <a class="calendar-date" href="#" onclick="return tCR('a=fno.datecalendercheck');"></a>,
#  <a class="_today" href="#" onclick="return tCR('a=fno.datecalendertoday');"></a>,
#  <a class="ly_close _close" href="#" onclick="return tCR('a=fno.datecalenderclose');"> <img alt="닫기" height="11" src="https://ssl.pstatic.net/sstatic/keypage/lifesrch/sports/img2010/bt_ly_close.gif" width="11"/> </a>,
#  <a class="link_help" href="https://help.naver.com/support/alias/search/word/word_1.naver" onclick="return goOtherCR(this, 'a=rsk.guide&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));" target="_blank"><i class="sprenew api_ico_help">도움말</i></a>,
#  <a data-area="*q" data-idx="1" href="?where=nexearch&amp;query=%EC%95%88%ED%9A%A8%EC%84%AD&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0">안효섭</a>,
#  <a data-area="*q" data-idx="2" href="?where=nexearch&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81+%EA%B9%80%EC%98%81%EA%B4%91+%EC%97%B4%EC%95%A0&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0">박보영 김영광 열애</a>,
#  <a data-area="*q" data-idx="3" href="?where=nexearch&amp;query=%EC%96%B4%EB%B9%84%EC%8A%A4&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0">어비스</a>,
#  <a data-area="*q" data-idx="4" href="?where=nexearch&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81+%EB%93%9C%EB%9D%BC%EB%A7%88&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0">박보영 드라마</a>,
#  <a data-area="*q" data-idx="5" href="?where=nexearch&amp;query=%EA%B9%80%EC%98%81%EA%B4%91&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0">김영광</a>,
#  <a data-area="*q" data-idx="6" href="?where=nexearch&amp;query=%EB%B0%95%EB%B3%B4%EA%B2%80&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0">박보검</a>,
#  <a data-area="*q" data-idx="7" href="?where=nexearch&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81+%EC%9D%B8%EC%8A%A4%ED%83%80%EA%B7%B8%EB%9E%A8&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0">박보영 인스타그램</a>,
#  <a data-area="*q" data-idx="8" href="?where=nexearch&amp;query=%EC%96%B4%EB%B9%84%EC%8A%A4+%EC%98%81%ED%98%BC%EC%86%8C%EC%83%9D%EA%B5%AC%EC%8A%AC&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0">어비스 영혼소생구슬</a>,
#  <a data-area="*q" data-idx="9" href="?where=nexearch&amp;query=%EC%9D%B4%EB%B3%B4%EC%98%81&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0">이보영</a>,
#  <a data-area="*q" data-idx="10" href="?where=nexearch&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81+%EA%B9%80%EC%98%81%EA%B4%91&amp;ie=utf8&amp;sm=tab_she&amp;qdt=0">박보영 김영광</a>,
#  <a class="open _related_keyword_toggle" href="#" onclick="return false;" role="button">열기</a>,
#  <a class="btn_more _related_keyword_btn_more" href="#" onclick="return false;" role="button" style="display: none;"><span class="unfold">더보기<span class="spkw ico_darr"></span></span><span class="fold">접기<span class="spkw ico_uarr"></span></span></a>,
#  <a class="btn_report" href="https://help.naver.com/support/alias/search/word/word_2.naver" onclick="return goOtherCR(this, 'a=rsk.report&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));" target="_blank">신고</a>,
#  <a class="btn_close _related_keyword_toggle" href="#" onclick="return false;" role="button"><span class="spkw">검색어제안 기능 닫기</span></a>,
#  <a href="https://search.naver.com/search.naver?where=image&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;merge=0&amp;res_fr=0&amp;res_to=0&amp;sort=0&amp;viewtype=0&amp;site=&amp;face=1&amp;color=0&amp;mcs=0&amp;a_q=&amp;n_q=&amp;o_q=&amp;sm=tab_etc" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.image&amp;i='+'1800000D_00000001F00A');"><img alt="영화배우 박보영 이미지" height="150" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=a&amp;size=120x150&amp;quality=95&amp;direct=true&amp;src=http%3A%2F%2Fsstatic.naver.net%2Fpeople%2Fportrait%2F201312%2F20131211170041770-2535427.jpg" width="120"/></a>,
#  <a class="btn_profile_update" href="http://myprofile.naver.com" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.edit&amp;i='+'1800000D_00000001F00A');" target="_blank"><span class="blind">영화배우 박보영</span>내 프로필 수정</a>,
#  <a href="https://people.search.naver.com/search.naver?where=nexearch&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;sm=tab_etc&amp;ie=utf8&amp;key=PeopleService&amp;os=126986" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.namepeople&amp;i='+'1800000D_00000001F00A');" target="_blank"><strong>박보영</strong></a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;query=%ED%94%BC%EB%8D%B0%EC%8A%A4%EC%8A%A4%ED%8C%8C%ED%8B%B0%EC%9C%B0" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.management&amp;i='+'1800000D_00000001F00A');">피데스스파티윰</a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;query=%EB%8B%A8%EA%B5%AD%EB%8C%80%ED%95%99%EA%B5%90" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.school&amp;i='+'1800000D_00000001F00A');">단국대학교</a>,
#  <a href="http://cafe.daum.net/parkboyoungfd" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.officialsite&amp;i='+'1800000D_00000001F00A');" target="_blank">공식사이트</a>,
#  <a href="http://www.vlive.tv/channels/FCE49" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.vlive&amp;i='+'1800000D_00000001F00A');" target="_blank">V LIVE</a>,
#  <a href="javascript:;" id="more_div_btn" nocr=""><img alt="네이버 인물정보 도움말" height="12" src="https://ssl.pstatic.net/sstatic/search/img/ico_help.gif" width="12"/></a>,
#  <a class="request" href="https://myprofile.naver.com/Main.nhn" nocr="" onclick="return goOtherCR(this, 'a=nco_x29*3.imaginfmy&amp;r=1&amp;i=1800000D_00000001F00A+1800000D_0000000741D8+1800000D_0000001E06BD+1800000D_000000040A8A&amp;u=' + urlencode(this.href));" target="_blank">본인 및 소속사의 인물정보 수정요청</a>,
#  <a class="helpdesk" href="https://help.naver.com/support/alias/search/people/people_0.naver" nocr="" onclick="return goOtherCR(this, 'a=nco_x29*3.imaginfcs&amp;r=1&amp;i=1800000D_00000001F00A+1800000D_0000000741D8+1800000D_0000001E06BD+1800000D_000000040A8A&amp;u=' + urlencode(this.href));" target="_blank">네이버 고객센터</a>,
#  <a class="closelayer C" href="javascript:;" nocr="" onclick="fnLayerClose();return false;"><img alt="네이버 인물정보 도움말 닫기" height="9" src="https://ssl.pstatic.net/sstatic/search/images11/btn_layer_close.gif" width="10"/></a>,
#  <a class="btn_txt_more" href="https://people.search.naver.com/search.naver?where=nexearch&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;sm=tab_etc&amp;ie=utf8&amp;key=PeopleService&amp;os=126986" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.profiledetail&amp;i='+'1800000D_00000001F00A');" target="_blank"><span class="blind">영화배우 박보영</span>프로필 더보기</a>,
#  <a class="pg_btn" href="#" nocr="1">네이버TV</a>,
#  <a class="pg_btn" href="#" nocr="1">앨범</a>,
#  <a class="pg_btn" href="#" nocr="1">영화</a>,
#  <a class="pg_btn" href="#" nocr="1">방송</a>,
#  <a class="pg_btn" href="#" nocr="1">공연</a>,
#  <a href="https://tv.naver.com/v/8247195" nocr="" onclick="return goOtherCR(this, 'a=nco_x29*3.tvcimg&amp;r=1&amp;i=1800000D_00000001F00A&amp;u=' + urlencode(this.href));" target="_blank"> <img alt="[선공개] 보영&amp;amp;효섭의 첫 받쓰! 이소라&amp;amp;박효신 It`s gonna be rolling♪" class="" height="72" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=ofullfill_black&amp;size=128x72&amp;quality=95&amp;direct=true&amp;src=https%3A%2F%2Fphinf.pstatic.net%2Ftvcast%2F20190503_213%2Fjj2ic_1556874160933IMfz8_JPEG%2FB120188696_EPI0057_19_B.jpg" width="128"/> <span class="ico_play"></span> <span class="runtime"><span class="bg">재생시간</span><em>3분 10초</em></span> <span class="img_bd"></span> </a>,
#  <a class="cast_txt" href="https://tv.naver.com/v/8247195" nocr="" onclick="return goOtherCR(this, 'a=nco_x29*3.tvctit&amp;r=1&amp;i=1800000D_00000001F00A&amp;u=' + urlencode(this.href));" target="_blank">[선공개] 보영&amp;효섭의 첫 받쓰! 이소라&amp;...</a>,
#  <a href="https://tv.naver.com/v/8247194" nocr="" onclick="return goOtherCR(this, 'a=nco_x29*3.tvcimg&amp;r=1&amp;i=1800000D_00000001F00A&amp;u=' + urlencode(this.href));" target="_blank"> <img alt="[선공개] 외쳐! 갓보영! 갓효섭! 박보영이 흔한 얼굴?!" class="" height="72" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=ofullfill_black&amp;size=128x72&amp;quality=95&amp;direct=true&amp;src=https%3A%2F%2Fphinf.pstatic.net%2Ftvcast%2F20190503_118%2Fa6NJp_1556874157331UObxO_JPEG%2FB120188696_EPI0057_18_B.jpg" width="128"/> <span class="ico_play"></span> <span class="runtime"><span class="bg">재생시간</span><em>3분 11초</em></span> <span class="img_bd"></span> </a>,
#  <a class="cast_txt" href="https://tv.naver.com/v/8247194" nocr="" onclick="return goOtherCR(this, 'a=nco_x29*3.tvctit&amp;r=1&amp;i=1800000D_00000001F00A&amp;u=' + urlencode(this.href));" target="_blank">[선공개] 외쳐! 갓보영! 갓효섭! 박보영...</a>,
#  <a href="https://tv.naver.com/v/8210579" nocr="" onclick="return goOtherCR(this, 'a=nco_x29*3.tvcimg&amp;r=1&amp;i=1800000D_00000001F00A&amp;u=' + urlencode(this.href));" target="_blank"> <img alt="[하이라이트]′내가 죽은 널, 다시 살렸으니까′ 모든 사건은 하나로 연결되어 있다! tvN [어비스-영혼소생구슬]" class="" height="72" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=ofullfill_black&amp;size=128x72&amp;quality=95&amp;direct=true&amp;src=https%3A%2F%2Fphinf.pstatic.net%2Ftvcast%2F20190430_259%2FIWm1s_1556613156418ICwzT_JPEG%2FB120192997_EPI0000_23_B.jpg" width="128"/> <span class="ico_play"></span> <span class="runtime"><span class="bg">재생시간</span><em>6분 20초</em></span> <span class="img_bd"></span> </a>,
#  <a class="cast_txt" href="https://tv.naver.com/v/8210579" nocr="" onclick="return goOtherCR(this, 'a=nco_x29*3.tvctit&amp;r=1&amp;i=1800000D_00000001F00A&amp;u=' + urlencode(this.href));" target="_blank">[하이라이트]′내가 죽은 널, 다시 살렸으...</a>,
#  <a href="https://tv.naver.com/v/8210562" nocr="" onclick="return goOtherCR(this, 'a=nco_x29*3.tvcimg&amp;r=1&amp;i=1800000D_00000001F00A&amp;u=' + urlencode(this.href));" target="_blank"> <img alt="[하이라이트]′기억났어! 이 얼굴′ 흔한(?) 얼굴 박보영x위험한 얼굴 안효섭, tvN [어비스-영혼소생구슬]" class="" height="72" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=ofullfill_black&amp;size=128x72&amp;quality=95&amp;direct=true&amp;src=https%3A%2F%2Fphinf.pstatic.net%2Ftvcast%2F20190430_178%2FjmFq1_1556613102743sjrJ8_JPEG%2FB120192997_EPI0000_22_B.jpg" width="128"/> <span class="ico_play"></span> <span class="runtime"><span class="bg">재생시간</span><em>1분 21초</em></span> <span class="img_bd"></span> </a>,
#  <a class="cast_txt" href="https://tv.naver.com/v/8210562" nocr="" onclick="return goOtherCR(this, 'a=nco_x29*3.tvctit&amp;r=1&amp;i=1800000D_00000001F00A&amp;u=' + urlencode(this.href));" target="_blank">[하이라이트]′기억났어! 이 얼굴′ 흔한(...</a>,
#  <a class="more_view" href="http://tv.naver.com/search/clip?query=박보영&amp;sort=date" nocr="" onclick="return goOtherCR(this, 'a=nco_x29*3.tvcmore&amp;r=1&amp;i=1800000D_00000001F00A&amp;u=' + urlencode(this.href));" target="_blank"><span class="blind">네이버TV </span>더보기</a>,
#  <a href="https://music.naver.com/album/index.nhn?albumId=2500698" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.albumimage&amp;i='+'1800000D_00000001F00A');" target="_blank"><img alt="영화 너의결혼식 OST Part 1" class="" height="71" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=o&amp;size=78x71&amp;quality=95&amp;direct=true&amp;src=https%3A%2F%2Fmusicmeta-phinf.pstatic.net%2Falbum%2F002%2F500%2F2500698.jpg%3Ftype%3Dr204Fll%26v%3D20181212201549" width="78"/><img alt="" class="bg_album" height="75" src="https://ssl.pstatic.net/sstatic/search/images11/blank.gif" width="84"/></a>,
#  <a class="sh_people_title sh_people_link" href="https://music.naver.com/album/index.nhn?albumId=2500698" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.albumtitle&amp;i='+'1800000D_00000001F00A');" target="_blank" title="영화 너의결혼식 OST Part 1">영화 너의결혼식 ...</a>,
#  <a href="https://music.naver.com/album/index.nhn?albumId=565464" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.albumimage&amp;i='+'1800000D_00000001F00A');" target="_blank"><img alt="오 나의 귀신님 OST Part 3" class="" height="71" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=o&amp;size=78x71&amp;quality=95&amp;direct=true&amp;src=https%3A%2F%2Fmusicmeta-phinf.pstatic.net%2Falbum%2F000%2F565%2F565464.jpg%3Ftype%3Dr204Fll%26v%3D20181011204155" width="78"/><img alt="" class="bg_album" height="75" src="https://ssl.pstatic.net/sstatic/search/images11/blank.gif" width="84"/></a>,
#  <a class="sh_people_title sh_people_link" href="https://music.naver.com/album/index.nhn?albumId=565464" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.albumtitle&amp;i='+'1800000D_00000001F00A');" target="_blank" title="오 나의 귀신님 OST Part 3">오 나의 귀신님 ...</a>,
#  <a href="https://movie.naver.com/movie/bi/mi/basic.nhn?code=140652" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.movieimage&amp;i='+'1800000D_00000001F00A');" target="_blank"><img alt="너의 결혼식" class="" height="80" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=ofullfill&amp;size=56x80&amp;quality=95&amp;direct=true&amp;src=https%3A%2F%2Fssl.pstatic.net%2Fimgmovie%2Fmdi%2Fmi%2F1406%2F140652_P38_143110.jpg" width="56"/></a>,
#  <a class="sh_people_title sh_people_link" href="https://movie.naver.com/movie/bi/mi/basic.nhn?code=140652" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.movietitle&amp;i='+'1800000D_00000001F00A');" target="_blank">너의 결혼식</a>,
#  <a href="https://movie.naver.com/movie/bi/mi/basic.nhn?code=128258" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.movieimage&amp;i='+'1800000D_00000001F00A');" target="_blank"><img alt="열정같은소리하고있네" class="" height="80" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=ofullfill&amp;size=56x80&amp;quality=95&amp;direct=true&amp;src=https%3A%2F%2Fssl.pstatic.net%2Fimgmovie%2Fmdi%2Fmi%2F1282%2F128258_P44_104043.jpg" width="56"/></a>,
#  <a class="sh_people_title sh_people_link" href="https://movie.naver.com/movie/bi/mi/basic.nhn?code=128258" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.movietitle&amp;i='+'1800000D_00000001F00A');" target="_blank">열정같은소리하고있네</a>,
#  <a href="https://movie.naver.com/movie/bi/mi/basic.nhn?code=130733" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.movieimage&amp;i='+'1800000D_00000001F00A');" target="_blank"><img alt="돌연변이" class="" height="80" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=ofullfill&amp;size=56x80&amp;quality=95&amp;direct=true&amp;src=https%3A%2F%2Fssl.pstatic.net%2Fimgmovie%2Fmdi%2Fmi%2F1307%2F130733_P34_095700.jpg" width="56"/></a>,
#  <a class="sh_people_title sh_people_link" href="https://movie.naver.com/movie/bi/mi/basic.nhn?code=130733" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.movietitle&amp;i='+'1800000D_00000001F00A');" target="_blank">돌연변이</a>,
#  <a class="more_view" href="http://movie.naver.com/movie/bi/pi/filmo.nhn?code=116132&amp;v=i" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.wtmoviemore&amp;i='+'1800000D_00000001F00A');" target="_blank"><span class="blind">영화 </span>더보기</a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;mra=bjkw&amp;x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%228692982%22%7D&amp;pkid=57&amp;os=8692982&amp;query=%EC%96%B4%EB%B9%84%EC%8A%A4" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.dramaimage&amp;i='+'1800000D_00000001F00A');"><img alt="어비스" class="" height="82" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=o&amp;size=58x82&amp;quality=95&amp;direct=true&amp;src=http%3A%2F%2Fsstatic.naver.net%2Fkeypage%2Fimage%2Fdss%2F57%2F69%2F29%2F82%2F57_8692982_poster_image_1554443597663.jpg" width="58"/></a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;mra=bjkw&amp;x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%228692982%22%7D&amp;pkid=57&amp;os=8692982&amp;query=%EC%96%B4%EB%B9%84%EC%8A%A4" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.dramatitle&amp;i='+'1800000D_00000001F00A');">어비스</a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;query=%EC%96%B4%EB%B9%84%EC%8A%A4%EA%B3%A0%EC%84%B8%EC%97%B0" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.dramacharacter&amp;i='+'1800000D_00000001F00A');">고세연</a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;mra=bjkw&amp;x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%223619390%22%7D&amp;pkid=57&amp;os=3619390&amp;query=%ED%9E%98%EC%8E%88%EC%97%AC%EC%9E%90%EB%8F%84%EB%B4%89%EC%88%9C" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.dramaimage&amp;i='+'1800000D_00000001F00A');"><img alt="힘쎈여자 도봉순" class="" height="82" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=o&amp;size=58x82&amp;quality=95&amp;direct=true&amp;src=http%3A%2F%2Fsstatic.naver.net%2Fkeypage%2Fimage%2Fdss%2F57%2F61%2F93%2F90%2F57_3619390_poster_image_1486002679074.jpg" width="58"/></a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;mra=bjkw&amp;x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%223619390%22%7D&amp;pkid=57&amp;os=3619390&amp;query=%ED%9E%98%EC%8E%88%EC%97%AC%EC%9E%90%EB%8F%84%EB%B4%89%EC%88%9C" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.dramatitle&amp;i='+'1800000D_00000001F00A');">힘쎈여자 도봉순</a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;query=%ED%9E%98%EC%8E%88%EC%97%AC%EC%9E%90%EB%8F%84%EB%B4%89%EC%88%9C%EB%8F%84%EB%B4%89%EC%88%9C" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.dramacharacter&amp;i='+'1800000D_00000001F00A');">도봉순</a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;mra=bjkw&amp;x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%223022014%22%7D&amp;pkid=57&amp;os=3022014&amp;query=%EC%9C%84%ED%82%A4%EB%93%9C" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.dramaimage&amp;i='+'1800000D_00000001F00A');"><img alt="위키드" class="" height="82" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=o&amp;size=58x82&amp;quality=95&amp;direct=true&amp;src=http%3A%2F%2Fsstatic.naver.net%2Fkeypage%2Fimage%2Fdss%2F57%2F02%2F20%2F14%2F57_3022014_poster_image_1458009703337.jpg" width="58"/></a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;mra=bjkw&amp;x_csa=%7B%22pkid%22%3A%2257%22%2C%22os%22%3A%223022014%22%7D&amp;pkid=57&amp;os=3022014&amp;query=%EC%9C%84%ED%82%A4%EB%93%9C" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.dramatitle&amp;i='+'1800000D_00000001F00A');">위키드</a>,
#  <a class="more_view" href="https://people.search.naver.com/search.naver?where=nexearch&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;sm=tab_etc&amp;ie=utf8&amp;key=PeopleService&amp;os=126986" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.wtonairmore&amp;i='+'1800000D_00000001F00A');" target="_blank"><span class="blind">방송 </span>더보기</a>,
#  <a href="http://ticket.yes24.com/Pages/Perf/Detail/Detail.aspx?IdPerf=32189&amp;site_pid=cp511NPlay1" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.playimage&amp;i='+'1800000D_00000001F00A');" target="_blank"><img alt="2019 박보영 팬미팅 [어느, 맑은 하루]" class="" height="80" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=mfullfill&amp;size=66x80&amp;quality=95&amp;direct=true&amp;src=https%3A%2F%2Fdbscthumb-phinf.pstatic.net%2F4209_000_3%2F20190115142551814_TP4Q0656W.jpg%2F2019%2B%25EB%25B0%2595%25EB%25B3%25B4.jpg%3Ftype%3Dr160" width="66"/></a>,
#  <a class="sh_people_title sh_people_link" href="http://ticket.yes24.com/Pages/Perf/Detail/Detail.aspx?IdPerf=32189&amp;site_pid=cp511NPlay1" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.playtitle&amp;i='+'1800000D_00000001F00A');" target="_blank" title="2019 박보영 팬미팅 [어느, 맑은 하루]">2019 박보영 ...</a>,
#  <a href="http://ticket.yes24.com/Pages/Perf/Detail/Detail.aspx?IdPerf=29886&amp;site_pid=cp511NPlay1" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.playimage&amp;i='+'1800000D_00000001F00A');" target="_blank"><img alt="박보영 첫번째 팬미팅 [달콤한 하루]" class="" height="80" onerror="tx_noimage_thumb(this, 'sp_noimg', 'https://ssl.pstatic.net/sstatic/search/images11/blank.gif');" src="https://search.pstatic.net/common?type=mfullfill&amp;size=66x80&amp;quality=95&amp;direct=true&amp;src=http%3A%2F%2Fdbscthumb.phinf.naver.net%2F4209_000_1%2F20180517103933926_VWZUD9ZRR.jpg%2F%25EB%25B0%2595%25EB%25B3%25B4.jpg%3Ftype%3Dr160" width="66"/></a>,
#  <a class="sh_people_title sh_people_link" href="http://ticket.yes24.com/Pages/Perf/Detail/Detail.aspx?IdPerf=29886&amp;site_pid=cp511NPlay1" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.playtitle&amp;i='+'1800000D_00000001F00A');" target="_blank" title="박보영 첫번째 팬미팅 [달콤한 하루]">박보영 첫번째 팬...</a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;mra=bjky&amp;pkid=1&amp;os=475608&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.namesimage&amp;i='+'1800000D_0000000741D8');"><img alt="뮤지컬배우" height="70" onerror="tx_noimage_thumb(this, '', 'https://ssl.pstatic.net/sstatic/keypage/outside/scui/people/img/no_img8.gif');" src="https://search.pstatic.net/common?type=ofullfill&amp;size=56x70&amp;quality=95&amp;direct=true&amp;src=http%3A%2F%2Fsstatic.naver.net%2Fpeople%2Fportrait%2F201405%2F20140517124719384-2250866.jpg" width="56"/><span class="mask"></span></a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;mra=bjky&amp;pkid=1&amp;os=475608&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.names&amp;i='+'1800000D_0000000741D8');">박보영</a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;mra=bjky&amp;pkid=1&amp;os=1967805&amp;query=%EC%97%B0%EC%A7%80%ED%95%B4" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.namesimage&amp;i='+'1800000D_0000001E06BD');"><img alt="영화배우" height="70" onerror="tx_noimage_thumb(this, '', 'https://ssl.pstatic.net/sstatic/keypage/outside/scui/people/img/no_img8.gif');" src="https://search.pstatic.net/common?type=ofullfill&amp;size=56x70&amp;quality=95&amp;direct=true&amp;src=http%3A%2F%2Fsstatic.naver.net%2Fpeople%2Fportrait%2F201406%2F20140610043221160.jpg" width="56"/><span class="mask"></span></a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;mra=bjky&amp;pkid=1&amp;os=1967805&amp;query=%EC%97%B0%EC%A7%80%ED%95%B4" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.names&amp;i='+'1800000D_0000001E06BD');">연지해</a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;mra=bjky&amp;pkid=1&amp;os=264842&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.namesimage&amp;i='+'1800000D_000000040A8A');"><img alt="판사" height="70" onerror="tx_noimage_thumb(this, '', 'https://ssl.pstatic.net/sstatic/keypage/outside/scui/people/img/no_img8.gif');" src="https://search.pstatic.net/common?type=ofullfill&amp;size=56x70&amp;quality=95&amp;direct=true&amp;src=http%3A%2F%2Fsstatic.naver.net%2Fpeople%2F53%2F201110281208351441.jpg" width="56"/><span class="mask"></span></a>,
#  <a href="?where=nexearch&amp;sm=tab_etc&amp;mra=bjky&amp;pkid=1&amp;os=264842&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.names&amp;i='+'1800000D_000000040A8A');">박보영</a>,
#  <a href="?&amp;where=news&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;sort=1&amp;sm=tab_smr&amp;nso=so:dd,p:all,a:all" onclick="return goOtherCR(this, 'a=nws_all.sortdate&amp;r=0&amp;i=0&amp;u='+urlencode(this.href));">최신순</a>,
#  <a class="sp_thmb thmb80" href="http://news1.kr/articles/?3613110" onclick="return goOtherCR(this, 'a=nws_all*a.img&amp;r=1&amp;i=08138263_000000000000000003972619&amp;g=421.0003972619&amp;u='+urlencode(this.href));" target="_blank"><img alt='[N현장] "목표는 20%"' class="" height="80" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F421%2F2019%2F05%2F03%2F3972619.jpg&amp;type=ofullfill80_80_q75_re2" width="80"/><span class="thmb_v"></span></a>,
#  <a class="_sp_each_title" href="http://news1.kr/articles/?3613110" onclick="return goOtherCR(this, 'a=nws_all*a.tit&amp;r=1&amp;i=08138263_000000000000000003972619&amp;g=421.0003972619&amp;u='+urlencode(this.href));" target="_blank" title="[N현장] &quot;목표는 20%&quot; 박보영X유제원 '어비스', '오나귀' 신드롬 재현할까(종합)">[N현장] "목표는 20%" <strong class="hl">박보영</strong>X유제원 '어비스', '오나귀' 신드롬 재현할까(종...</a>,
#  <a class="_sp_each_url" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=421&amp;aid=0003972619" onclick="return goOtherCR(this, 'a=nws_all*a.nav&amp;r=1&amp;i=08138263_000000000000000003972619&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a>,
#  <a class="bt_scial2 naver-splugin" data-oninitialize="splugin_oninitialize('sp_nws_all1');" data-style="unity-v2" href="#" onclick="goOtherTCR(this, 'a=nws_all*a.pplugin&amp;r=1&amp;i=08138263_000000000000000003972619&amp;u='+urlencode(this.href)); return false;">보내기</a>,
#  <a href="https://www.ytn.co.kr/_sn/0117_201905031542444999" onclick="return goOtherCR(this, 'a=nws_all*c.tit&amp;r=2&amp;i=880000AF_000000000000000001288761&amp;g=052.0001288761&amp;u='+urlencode(this.href));" target="_blank" title="[Y현장] '흔녀' 박보영·'남신' 안효섭이 그리는 판타지 로맨스, '어비스'(종합)">[Y현장] '흔녀' <strong class="hl">박보영</strong>·'남신' 안효섭이 그리는 판타지 로맨스, '어비스'(종...</a>,
#  <a class="_sp_each_url" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=052&amp;aid=0001288761" onclick="return goOtherCR(this, 'a=nws_all*c.nav&amp;r=2&amp;i=880000AF_000000000000000001288761&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a>,
#  <a href="http://sports.mk.co.kr/view.php?year=2019&amp;no=289759" onclick="return goOtherCR(this, 'a=nws_all*c.tit&amp;r=3&amp;i=88127054_000000000000000000581726&amp;g=410.0000581726&amp;u='+urlencode(this.href));" target="_blank" title="“박보영X유제원 PD 재회”..‘어비스’, ‘오나귀’ 열풍 재현할까(종합)">“<strong class="hl">박보영</strong>X유제원 PD 재회”..‘어비스’, ‘오나귀’ 열풍 재현할까(종합)</a>,
#  <a class="_sp_each_url" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=410&amp;aid=0000581726" onclick="return goOtherCR(this, 'a=nws_all*c.nav&amp;r=3&amp;i=88127054_000000000000000000581726&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a>,
#  <a class="more_news" href="?&amp;where=news&amp;sm=mtb_tnw&amp;query=%EB%B0%95%EB%B3%B4%EC%98%81&amp;nso=so:r,p:all,a:all&amp;related=1&amp;docid=4210003972619" onclick="return goOtherCR(this, 'a=nws_all*r.more&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));">관련뉴스 전체보기</a>,
#  <a class="sp_thmb thmb80" href="http://star.mt.co.kr/stview.php?no=2019050313501862541" onclick="return goOtherCR(this, 'a=nws_all*a.img&amp;r=4&amp;i=880000C3_000000000000000002781149&amp;g=108.0002781149&amp;u='+urlencode(this.href));" target="_blank"><img alt="박보영X안효섭 ‘어비스" class="" height="80" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F108%2F2019%2F05%2F03%2F2781149.jpg&amp;type=ofullfill80_80_q75_re2" width="80"/><span class="thmb_v"></span></a>,
#  <a class="_sp_each_title" href="http://star.mt.co.kr/stview.php?no=2019050313501862541" onclick="return goOtherCR(this, 'a=nws_all*a.tit&amp;r=4&amp;i=880000C3_000000000000000002781149&amp;g=108.0002781149&amp;u='+urlencode(this.href));" target="_blank" title="박보영X안효섭 '어비스', 이시언의 20% 소망 이뤄줄까[종합]"><strong class="hl">박보영</strong>X안효섭 '어비스', 이시언의 20% 소망 이뤄줄까[종합]</a>,
#  <a class="_sp_each_url" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=108&amp;aid=0002781149" onclick="return goOtherCR(this, 'a=nws_all*a.nav&amp;r=4&amp;i=880000C3_000000000000000002781149&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a>,
#  <a class="bt_scial2 naver-splugin" data-oninitialize="splugin_oninitialize('sp_nws_all4');" data-style="unity-v2" href="#" onclick="goOtherTCR(this, 'a=nws_all*a.pplugin&amp;r=4&amp;i=880000C3_000000000000000002781149&amp;u='+urlencode(this.href)); return false;">보내기</a>,
#  <a href="http://isplus.live.joins.com/news/article/aid.asp?aid=23050425" onclick="return goOtherCR(this, 'a=nws_all*c.tit&amp;r=5&amp;i=880002FC_000000000000000002909555&amp;g=241.0002909555&amp;u='+urlencode(this.href));" target="_blank" title="[포토]이성재-박보영-안효섭-이시언, 사랑스런 조합">[포토]이성재-<strong class="hl">박보영</strong>-안효섭-이시언, 사랑스런 조합</a>,
#  <a class="_sp_each_url" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=241&amp;aid=0002909555" onclick="return goOtherCR(this, 'a=nws_all*c.nav&amp;r=5&amp;i=880002FC_000000000000000002909555&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a>,
#  <a class="sp_thmb thmb80" href="http://digitalchosun.dizzo.com/site/data/html_dir/2019/05/03/2019050380185.html" onclick="return goOtherCR(this, 'a=nws_all*b.img&amp;r=6&amp;i=88184407_000000000000000000006436&amp;g=5641.0000006436&amp;u='+urlencode(this.href));" target="_blank"><img alt="[HD영상] ‘어비스‘ 안" class="" height="80" onerror="this.parentNode.style.display='none';" src="https://search.pstatic.net/common/?src=https%3A%2F%2Fimgnews.pstatic.net%2Fimage%2Forigin%2F5641%2F2019%2F05%2F03%2F6436.jpg&amp;type=ofullfill80_80_q75_re2" width="80"/><span class="thmb_v"></span></a>,
#  <a class="_sp_each_url _sp_each_title" href="http://digitalchosun.dizzo.com/site/data/html_dir/2019/05/03/2019050380185.html" onclick="return goOtherCR(this, 'a=nws_all*b.tit&amp;r=6&amp;i=88184407_000000000000000000006436&amp;g=5641.0000006436&amp;u='+urlencode(this.href));" target="_blank" title="[HD영상] '어비스' 안효섭 &quot;'세젤흔녀' 박보영? 얼굴 보면 몰입 안 된다&quot;">[HD영상] '어비스' 안효섭 "'세젤흔녀' <strong class="hl">박보영</strong>? 얼굴 보면 몰입 안 된다"</a>,
#  <a class="bt_scial2 naver-splugin" data-oninitialize="splugin_oninitialize('sp_nws_all6');" data-style="unity-v2" href="#" onclick="goOtherTCR(this, 'a=nws_all*b.pplugin&amp;r=6&amp;i=88184407_000000000000000000006436&amp;u='+urlencode(this.href)); return false;">보내기</a>,
#  <a href="http://www.osen.co.kr/article/G1111135169" onclick="return goOtherCR(this, 'a=nws_all*c.tit&amp;r=7&amp;i=8800011B_000000000000000004002550&amp;g=109.0004002550&amp;u='+urlencode(this.href));" target="_blank" title="'어비스' 박보영 &quot;여신-세젤흔녀 연기, 김사랑과 차이 극대화했다&quot;">'어비스' <strong class="hl">박보영</strong> "여신-세젤흔녀 연기, 김사랑과 차이 극대화했다"</a>,
#  <a class="" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=109&amp;aid=0004002550" onclick="return goOtherCR(this, 'a=nws_all*c.nav&amp;r=7&amp;i=8800011B_000000000000000004002550&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a>,
#  <a href="http://www.sportsseoul.com/news/read/758699" onclick="return goOtherCR(this, 'a=nws_all*c.tit&amp;r=8&amp;i=88156f78_000000000000000000503518&amp;g=468.0000503518&amp;u='+urlencode(this.href));" target="_blank" title="'어비스' 박보영이 세젤흔女 외모? 안효섭 &quot;몰입하기 쉽지 않았다&quot;">'어비스' <strong class="hl">박보영</strong>이 세젤흔女 외모? 안효섭 "몰입하기 쉽지 않았다"</a>,
#  <a class="" href="https://news.naver.com/main/read.nhn?mode=LSD&amp;mid=sec&amp;sid1=106&amp;oid=468&amp;aid=0000503518" onclick="return goOtherCR(this, 'a=nws_all*c.nav&amp;r=8&amp;i=88156f78_000000000000000000503518&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a>,
# ...
#  <a class="datalab _status" href="https://datalab.naver.com/keyword/realtimeDetail.naver?query=%EA%B8%88%EC%9A%94%EC%9D%BC+%EC%98%88%EB%8A%A5&amp;datetime=2019-05-03T21%3A28%3A00&amp;age=all&amp;period=now&amp;where=search" onclick="return goOtherCR(this, 'a=fkc_rkl.numv&amp;r=19&amp;i=&amp;u='+urlencode(this.href));" target="_blank"><i class="spim ico_graph">검색 추이</i></a>,
#  <a class="keyword" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_lvf.allnow&amp;ie=utf8&amp;query=%EC%9D%91%EB%8B%B5%ED%95%98%EB%9D%BC+1988" onclick="return goOtherCR(this, 'a=fkc_rkl.list&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <em class="num">20</em> <span class="tit _text">응답하라 1988</span> </a>,
#  <a class="datalab _status" href="https://datalab.naver.com/keyword/realtimeDetail.naver?query=%EC%9D%91%EB%8B%B5%ED%95%98%EB%9D%BC+1988&amp;datetime=2019-05-03T21%3A28%3A00&amp;age=all&amp;period=now&amp;where=search" onclick="return goOtherCR(this, 'a=fkc_rkl.numv&amp;r=20&amp;i=&amp;u='+urlencode(this.href));" target="_blank"><i class="spim ico_graph">검색 추이</i></a>,
#  <a class="link_rts_help" href="https://help.naver.com/support/alias/search/word/word_5.naver" onclick="return goOtherCR(this, 'a=fkc_rkl.guide&amp;r=&amp;i=&amp;u='+urlencode(this.href))" target="_blank"><i class="sprenew api_ico_help2">도움말</i></a>,
#  <a class="link_history" href="https://datalab.naver.com/keyword/realtimeList.naver?where=search" onclick="return goOtherCR(this, 'a=fkc_rkl.trmore&amp;r=&amp;i=&amp;u='+urlencode(this.href));" target="_blank"><i class="spim ico_datalab">DataLab</i>급상승 트래킹<i class="spim ico_arr"></i></a>,
#  <a href="#" onclick="return tCR('fkc_htk.nws', 1, '');">뉴스</a>,
#  <a href="#" onclick="return tCR('fkc_htk.ents', 1, '');">연예·스포츠</a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.nws&amp;ie=utf8&amp;query=%EC%8A%B9%EB%A6%AC+%EB%8B%A4%EC%9D%8C%EC%A3%BC+%EA%B5%AC%EC%86%8D%EC%98%81%EC%9E%A5+%EC%8B%A0%EC%B2%AD" onclick="return goOtherCR(this, 'a=fkc_htk.nwslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">1</em> <span class="tit _text">승리 다음주 구속영장 신청</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.nws&amp;ie=utf8&amp;query=%EC%98%AC%ED%95%B4+%EC%B2%AB+SFTS+%ED%99%98%EC%9E%90+%EB%B0%9C%EC%83%9D" onclick="return goOtherCR(this, 'a=fkc_htk.nwslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">2</em> <span class="tit _text">올해 첫 SFTS 환자 발생</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.nws&amp;ie=utf8&amp;query=%EA%B0%80%EC%8A%B5%EA%B8%B0%EC%82%B4%EA%B7%A0%EC%A0%9C+%ED%8A%B9%EB%B3%84%EA%B5%AC%EC%A0%9C+112%EB%AA%85+%EC%B6%94%EA%B0%80" onclick="return goOtherCR(this, 'a=fkc_htk.nwslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">3</em> <span class="tit _text">가습기살균제 특별구제 112명 추가</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.nws&amp;ie=utf8&amp;query=%EC%9B%90+%EB%8B%AC%EB%9F%AC+%ED%99%98%EC%9C%A8" onclick="return goOtherCR(this, 'a=fkc_htk.nwslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">4</em> <span class="tit _text">원 달러 환율</span> </span> </a>,
#  <a class="bx" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.nws&amp;ie=utf8&amp;query=%ED%99%A9%EA%B5%90%EC%95%88+%EB%AC%BC%EC%84%B8%EB%A1%80" onclick="return goOtherCR(this, 'a=fkc_htk.nwslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">5</em> <span class="tit _text">황교안 물세례</span> </span> </a>,
#  <a class="bx" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.nws&amp;ie=utf8&amp;query=%EC%88%98%EC%82%AC%EA%B6%8C+%EC%A1%B0%EC%A0%95+%EB%B0%98%EB%B0%9C" onclick="return goOtherCR(this, 'a=fkc_htk.nwslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">6</em> <span class="tit _text">수사권 조정 반발</span> </span> </a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.nws&amp;ie=utf8&amp;query=%EA%B5%AD%EC%84%B8%EC%B2%AD+%EA%B7%BC%EB%A1%9C%EC%9E%A5%EB%A0%A4%EA%B8%88" onclick="return goOtherCR(this, 'a=fkc_htk.nwslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">7</em> <span class="tit _text">국세청 근로장려금</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.nws&amp;ie=utf8&amp;query=5%EC%9B%94+%ED%99%A9%EA%B8%88%EC%97%B0%ED%9C%B4" onclick="return goOtherCR(this, 'a=fkc_htk.nwslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">8</em> <span class="tit _text">5월 황금연휴</span> </span> </a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.nws&amp;ie=utf8&amp;query=%EB%A1%AF%EB%8D%B0%EC%BC%80%EB%AF%B8%EC%B9%BC+1%EB%B6%84%EA%B8%B0+%EC%98%81%EC%97%85%EC%9D%B5+2957%EC%96%B5" onclick="return goOtherCR(this, 'a=fkc_htk.nwslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">9</em> <span class="tit _text">롯데케미칼 1분기 영업익 2957억</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.nws&amp;ie=utf8&amp;query=%EB%A9%94%EB%94%94%ED%8F%AC%EC%8A%A4%ED%8A%B8+%ED%9D%91%EC%9E%90%EC%A0%84%ED%99%98" onclick="return goOtherCR(this, 'a=fkc_htk.nwslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">10</em> <span class="tit _text">메디포스트 흑자전환</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.ent&amp;ie=utf8&amp;query=%EC%96%B4%EB%B9%84%EC%8A%A4+%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this, 'a=fkc_htk.entslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">1</em> <span class="tit _text">어비스 박보영</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.ent&amp;ie=utf8&amp;query=%ED%95%98%ED%8A%B8%EC%8B%9C%EA%B7%B8%EB%84%90+%EA%B9%80%ED%98%84%EC%9A%B0" onclick="return goOtherCR(this, 'a=fkc_htk.entslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">2</em> <span class="tit _text">하트시그널 김현우</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.ent&amp;ie=utf8&amp;query=%EA%B2%BD%EC%A3%BC+%ED%99%94%EB%9E%91%EA%B5%90%EC%9C%A1%EC%9B%90" onclick="return goOtherCR(this, 'a=fkc_htk.entslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">3</em> <span class="tit _text">경주 화랑교육원</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.ent&amp;ie=utf8&amp;query=%EC%95%84%EB%8A%94%ED%98%95%EB%8B%98+%EC%95%84%EC%9D%B4%EC%A6%88%EC%9B%90" onclick="return goOtherCR(this, 'a=fkc_htk.entslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">4</em> <span class="tit _text">아는형님 아이즈원</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.ent&amp;ie=utf8&amp;query=%ED%94%BC%ED%84%B0+%EB%A9%94%EC%9D%B4%ED%9C%B4+%EB%B3%84%EC%84%B8" onclick="return goOtherCR(this, 'a=fkc_htk.entslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">5</em> <span class="tit _text">피터 메이휴 별세</span> </span> </a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.ent&amp;ie=utf8&amp;query=%EC%96%B4%EB%B2%A4%EC%A0%B8%EC%8A%A4%3A+%EC%97%94%EB%93%9C%EA%B2%8C%EC%9E%84+900%EB%A7%8C+%EB%8F%8C%ED%8C%8C" onclick="return goOtherCR(this, 'a=fkc_htk.entslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">6</em> <span class="tit _text">어벤져스: 엔드게임 900만 돌파</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.ent&amp;ie=utf8&amp;query=%EC%9C%A0%EC%9D%B4+%EA%B7%BC%ED%99%A9" onclick="return goOtherCR(this, 'a=fkc_htk.entslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">7</em> <span class="tit _text">유이 근황</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.ent&amp;ie=utf8&amp;query=%EA%B7%B8%EA%B2%83%EC%9D%B4+%EC%95%8C%EA%B3%A0%EC%8B%B6%EB%8B%A4+%ED%99%A9%ED%95%98%EB%82%98%EC%99%80+%EB%B2%84%EB%8B%9D%EC%8D%AC" onclick="return goOtherCR(this, 'a=fkc_htk.entslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">8</em> <span class="tit _text">그것이 알고싶다 황하나와 버닝썬</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx bx_item" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.ent&amp;ie=utf8&amp;query=%EC%9D%B4%ED%9B%88+%EC%82%AC%EC%97%85%EC%8B%A4%ED%8C%A8" onclick="return goOtherCR(this, 'a=fkc_htk.entslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">9</em> <span class="tit _text">이훈 사업실패</span> </span> <em class="rank new"><span class="spim"></span><span>NEW</span></em> </a>,
#  <a class="bx" href="//search.naver.com/search.naver?where=nexearch&amp;sm=tab_htf.ent&amp;ie=utf8&amp;query=1%EB%93%B1%EC%9D%80+%EB%84%88%EC%98%80%EC%96%B4" onclick="return goOtherCR(this, 'a=fkc_htk.entslist&amp;r=20&amp;i=&amp;u='+urlencode(this.href));"> <span class="keyword"> <em class="num">10</em> <span class="tit _text">1등은 너였어</span> </span> </a>,
#  <a class="link_rts_help" href="https://help.naver.com/support/alias/search/word/word_3.naver" onclick="return goOtherCR(this, 'a=fkc_htk.guide&amp;r=&amp;i=&amp;u='+urlencode(this.href))" target="_blank"><i class="sprenew api_ico_help2">도움말</i></a>,
#  <a class="bt_atcp _btn_arw fold" href="#" onclick="return false;"><span class="blind _text">자동완성 펼치기</span><span class="ico_arrow spnew"></span></a>,
#  <a class="_help" href="https://help.naver.com/support/alias/search/word/word_17.naver" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_18.naver" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 끄기</a>,
#  <a class="spat ico_info" href="https://help.naver.com/support/alias/search/word/word_16.naver" onclick="__atcmpCR(event, this, 'plus.help', '','','');" target="_blank"><span class="blind">도움말 보기</span></a>,
#  <a class="btn_turnon active" href="#" onclick="__atcmpCR(event, this, 'plus.use', '','','');">ON<span class="blind">선택됨</span></a>,
#  <a class="btn_turnoff" href="#" onclick="__atcmpCR(event, this, 'plus.unuse', '','','');">OFF</a>,
#  <a class="btn btn_login" href="https://nid.naver.com/nidlogin.login?url=https%3A%2F%2Fsearch.naver.com%2Fsearch.naver%3Fquery%3D%25EB%25B0%2595%25EB%25B3%25B4%25EC%2598%2581" onclick="__atcmpCR(event, this, 'plus.login', '','','');">로그인</a>,
#  <a class="btn btn_view" href="https://help.naver.com/support/alias/search/word/word_16.naver" onclick="__atcmpCR(event, this, 'plus.detail', '','','');" target="_blank">자세히</a>,
#  <a class="btn btn_view" href="https://help.naver.com/support/alias/search/word/word_21.naver" onclick="__atcmpCR(event, this, 'plus.detail', '','','');" target="_blank">자세히</a>,
#  <a class="_help" href="https://help.naver.com/support/alias/search/word/word_17.naver" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_18.naver" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 끄기</a>,
#  <a class="_help" href="https://help.naver.com/support/alias/search/word/word_17.naver" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_18.naver" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 끄기</a>,
#  <a class="_help" href="https://help.naver.com/support/alias/search/word/word_17.naver" onclick="__atcmpCR(event, this, 'help', '','','');" target="_blank">도움말</a>,
#  <a href="https://help.naver.com/support/alias/search/word/word_18.naver" onclick="__atcmpCR(event, this, 'report', '','','');" target="_blank">신고</a>,
#  <a class="hisoff" href="javascript:;">검색어저장 켜기</a>,
#  <a class="funoff" href="javascript:;">자동완성 켜기</a>,
#  <a class="_delMode" href="javascript:;">기록 삭제</a>,
#  <a class="_keywordOff" href="javascript:;">검색어저장 끄기</a>,
#  <a class="_acOff" href="javascript:;">자동완성 끄기</a>,
#  <a class="_delAll" href="javascript:;" title="최근 검색어 기록을 모두 삭제합니다.">기록 전체 삭제</a>,
#  <a class="_delDone" href="javascript:;">완료</a>,
#  <a class="_delAll" href="javascript:;" title="설정된 내 검색어를 모두 삭제합니다.">기록 전체 삭제</a>,
#  <a class="_keywordOff" href="javascript:;">검색어저장 끄기</a>,
#  <a class="_acOff" href="javascript:;">자동완성 끄기</a>,
#  <a class="t@my@ _star _myBtn" href="javascript:;" title="내 검색어 등록"><em class="spat">내 검색어 등록</em></a>,
#  <a class="keyword" href="javascript:;">@txt@</a>,
#  <a class="btn_delete spat _del" href="javascript:;" title="검색어삭제">삭제</a>,
#  <a class="ton _star _myBtn" href="javascript:;" title="내 검색어 해제"><em class="spat">내 검색어 해제</em></a>,
#  <a class="keyword" href="javascript:;">@txt@</a>,
#  <a href="javascript:;">최근검색어</a>,
#  <a href="javascript:;">내 검색어</a>,
#  <a class="btn_close _close" href="javascript:;"><i class="spat ico_close">닫기</i></a>,
#  <a class="_link" href="" onclick="return goOtherCR(this,'a=sug.vote&amp;r=&amp;i=&amp;u='+urlencode(this.href));" target="_blank">자세히보기</a>,
#  <a href="https://help.naver.com/support/alias/search/footer/policy.naver" onclick="return goOtherCR(this, 'a=fot.web&amp;r=&amp;i=&amp;u='+urlencode(this.href));" target="_blank">웹문서 수집 및 삭제 정책</a>,
#  <a href="https://smartplace.naver.com/" onclick="return goOtherCR(this, 'a=fot.submit&amp;r=&amp;i=&amp;u='+urlencode(this.href));" target="_blank">플레이스업체 등록</a>,
#  <a href="http://searchad.naver.com/" onclick="return goOtherCR(this, 'a=fot.searchad&amp;r=&amp;i=&amp;u='+urlencode(this.href));" target="_blank">검색광고 안내</a>,
#  <a href="https://help.naver.com/support/alias/search/integration/integration_1.naver" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;a=fot.help&amp;r=&amp;i=');" target="_blank">통합검색 고객센터</a>,
#  <a href="https://help.naver.com/support/alias/report/unsound.naver" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;a=fot.inform&amp;r=&amp;i=');" target="_blank">유해게시물신고</a>,
#  <a href="http://www.navercorp.com/" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;a=fot.nhn&amp;r=&amp;i=');" target="_blank">NAVER Corp.</a>]

# %%
practice.find_all("dt")
# Out:
# [<dt><label for="inpop0">기본검색</label></dt>,
#  <dt><label for="inpop1">상세검색</label></dt>,
#  <dt><span class="tit_relate _related_keyword_lis">연관검색어</span><a class="link_help" href="https://help.naver.com/support/alias/search/word/word_1.naver" onclick="return goOtherCR(this, 'a=rsk.guide&amp;r=&amp;i=&amp;u='+urlencode(urlexpand(this.href)));" target="_blank"><i class="sprenew api_ico_help">도움말</i></a></dt>,
#  <dt>출생</dt>,
#  <dt>신체</dt>,
#  <dt>소속사</dt>,
#  <dt>학력</dt>,
#  <dt>데뷔</dt>,
#  <dt>수상</dt>,
#  <dt>사이트</dt>,
#  <dt><a class="sh_people_title sh_people_link" href="https://music.naver.com/album/index.nhn?albumId=2500698" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.albumtitle&amp;i='+'1800000D_00000001F00A');" target="_blank" title="영화 너의결혼식 OST Part 1">영화 너의결혼식 ...</a></dt>,
#  <dt><a class="sh_people_title sh_people_link" href="https://music.naver.com/album/index.nhn?albumId=565464" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.albumtitle&amp;i='+'1800000D_00000001F00A');" target="_blank" title="오 나의 귀신님 OST Part 3">오 나의 귀신님 ...</a></dt>,
#  <dt>주연 - 환승희, 노래</dt>,
#  <dt>주연 - 도라희</dt>,
#  <dt>주연 - 주진</dt>,
#  <dt><a href="?where=nexearch&amp;sm=tab_etc&amp;query=%EC%96%B4%EB%B9%84%EC%8A%A4%EA%B3%A0%EC%84%B8%EC%97%B0" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.dramacharacter&amp;i='+'1800000D_00000001F00A');">고세연</a>(주연)</dt>,
#  <dt><a href="?where=nexearch&amp;sm=tab_etc&amp;query=%ED%9E%98%EC%8E%88%EC%97%AC%EC%9E%90%EB%8F%84%EB%B4%89%EC%88%9C%EB%8F%84%EB%B4%89%EC%88%9C" nocr="" onclick="return goOtherCR(this, 'u='+urlencode(this.href)+'&amp;r=1&amp;a='+nco_area_126986_475608_1967805_264842+'.dramacharacter&amp;i='+'1800000D_00000001F00A');">도봉순</a>(주연)</dt>,
#  <dt>광림아트센터 BBCH홀</dt>,
#  <dt>마포아트센터 아트홀맥</dt>,
#  <dt><a class="_sp_each_title" href="http://news1.kr/articles/?3613110" onclick="return goOtherCR(this, 'a=nws_all*a.tit&amp;r=1&amp;i=08138263_000000000000000003972619&amp;g=421.0003972619&amp;u='+urlencode(this.href));" target="_blank" title="[N현장] &quot;목표는 20%&quot; 박보영X유제원 '어비스', '오나귀' 신드롬 재현할까(종합)">[N현장] "목표는 20%" <strong class="hl">박보영</strong>X유제원 '어비스', '오나귀' 신드롬 재현할까(종...</a></dt>,
#  <dt><a class="_sp_each_title" href="http://star.mt.co.kr/stview.php?no=2019050313501862541" onclick="return goOtherCR(this, 'a=nws_all*a.tit&amp;r=4&amp;i=880000C3_000000000000000002781149&amp;g=108.0002781149&amp;u='+urlencode(this.href));" target="_blank" title="박보영X안효섭 '어비스', 이시언의 20% 소망 이뤄줄까[종합]"><strong class="hl">박보영</strong>X안효섭 '어비스', 이시언의 20% 소망 이뤄줄까[종합]</a></dt>,
#  <dt><a class="_sp_each_url _sp_each_title" href="http://digitalchosun.dizzo.com/site/data/html_dir/2019/05/03/2019050380185.html" onclick="return goOtherCR(this, 'a=nws_all*b.tit&amp;r=6&amp;i=88184407_000000000000000000006436&amp;g=5641.0000006436&amp;u='+urlencode(this.href));" target="_blank" title="[HD영상] '어비스' 안효섭 &quot;'세젤흔녀' 박보영? 얼굴 보면 몰입 안 된다&quot;">[HD영상] '어비스' 안효섭 "'세젤흔녀' <strong class="hl">박보영</strong>? 얼굴 보면 몰입 안 된다"</a></dt>,
#  <dt><a class="_sp_each_title" href="http://star.mbn.co.kr/view.php?year=2019&amp;no=289721&amp;refer=portal" onclick="return goOtherCR(this, 'a=nws_all*a.tit&amp;r=9&amp;i=880000BF_000000000000000001347581&amp;g=057.0001347581&amp;u='+urlencode(this.href));" target="_blank" title="“흔녀된 뽀블리”…박보영X유제원 감독, ‘오나귀’ 잇는 신드롬 일으킬까(종합)">“흔녀된 뽀블리”…<strong class="hl">박보영</strong>X유제원 감독, ‘오나귀’ 잇는 신드롬 일으킬까(종...</a></dt>,
#  <dt class="info_title tit"> <a class="title _text" href="https://tv.naver.com/v/8245633" onclick="goOtherCR(this, 'a=vdo_bas*d.tit&amp;r=1&amp;i=0812601B_000008245633&amp;u='+urlencode(this.href));" target="_blank" title="'어비스' 안효섭, 박보영이 흔녀? '몰입하기 쉽지 않아'"> '어비스' 안효섭, <strong class="hl">박보영</strong>이 흔녀? '몰입하기... </a> </dt>,
#  <dt class="info_title tit"> <a class="title _text" href="https://tv.naver.com/v/8245448" onclick="goOtherCR(this, 'a=vdo_bas*d.tit&amp;r=2&amp;i=0812601B_000008245448&amp;u='+urlencode(this.href));" target="_blank" title="'어비스' 이시언, 박보영 스킨십 장면 있는거 보고 출연 결심?"> '어비스' 이시언, <strong class="hl">박보영</strong> 스킨십 장면 있는거... </a> </dt>,
#  <dt class="info_title tit"> <a class="title _text" href="https://tv.naver.com/v/8245318" onclick="goOtherCR(this, 'a=vdo_bas*d.tit&amp;r=3&amp;i=0812601B_000008245318&amp;u='+urlencode(this.href));" target="_blank" title="'어비스' 박보영, '세젤흔녀' 연기.. 김사랑과 저는 '결이 다른 얼굴'"> '어비스' <strong class="hl">박보영</strong>, '세젤흔녀' 연기.. 김사랑과... </a> </dt>,
#  <dt class="info_title tit"> <a class="title _text" href="https://tv.naver.com/v/8245519" onclick="goOtherCR(this, 'a=vdo_bas*d.tit&amp;r=4&amp;i=0812601B_000008245519&amp;u='+urlencode(this.href));" target="_blank" title="'어비스' 박보영, 뽀블리가 마블리를 만났을때? '대적 불가'..feat.조정석"> '어비스' <strong class="hl">박보영</strong>, 뽀블리가 마블리를... </a> </dt>,
#  <dt><a href="https://m.post.naver.com/viewer/postView.nhn?volumeNo=19568466&amp;memberNo=36645352&amp;vType=VERTICAL" onclick="return goOtherCR(this, 'a=pst_bas.link&amp;r=1&amp;i=00055f7ca0_00012a9752&amp;u='+urlencode(this.href));" target="_blank">배우 <strong class="hl">박보영</strong>, 반할 수밖에 없는 청순 러블리</a></dt>,
#  <dt><a href="https://m.post.naver.com/viewer/postView.nhn?volumeNo=17970239&amp;memberNo=23519771&amp;vType=VERTICAL" onclick="return goOtherCR(this, 'a=pst_bas.link&amp;r=2&amp;i=00055f7ca0_000112343f&amp;u='+urlencode(this.href));" target="_blank"><strong class="hl">박보영</strong>에게‘무장해제’ 당한 상대 배우들</a></dt>,
#  <dt><a href="https://m.post.naver.com/viewer/postView.nhn?volumeNo=19260625&amp;memberNo=22401813&amp;vType=VERTICAL" onclick="return goOtherCR(this, 'a=pst_bas.link&amp;r=3&amp;i=00055f7ca0_000125e4d1&amp;u='+urlencode(this.href));" target="_blank">이 세상 사이즈가 아니라는 <strong class="hl">박보영</strong> 얼굴 크기 체감</a></dt>,
#  <dt><a class="sh_cafe_title" href="https://cafe.naver.com/imsanbu/44492596" onclick="return goOtherCR(this, 'a=caf_bas*a.tit&amp;r=1&amp;i=90000004_009A07A302A6E73400000000&amp;u='+urlencode(urlexpand(this.href)));" target="_blank" title=""><strong class="hl">박보영</strong> 이런 모습도 있네요?</a></dt>,
#  <dt><a class="sh_cafe_title" href="https://cafe.naver.com/linearbeit/43556" onclick="return goOtherCR(this, 'a=caf_bas*a.tit&amp;r=2&amp;i=90000004_01A3F5430000AA2400000000&amp;u='+urlencode(urlexpand(this.href)));" target="_blank" title="">2019.04.29 <strong class="hl">박보영</strong> 쏘피 바디피트 팬사인회 현장</a></dt>,
#  <dt><a class="sh_cafe_title" href="https://cafe.naver.com/momakakao/11285454" onclick="return goOtherCR(this, 'a=caf_bas*a.tit&amp;r=3&amp;i=90000004_018FD53600AC33CE00000000&amp;u='+urlencode(urlexpand(this.href)));" target="_blank" title=""><strong class="hl">박보영</strong>은 언제쯤 결혼을 할까요?</a></dt>,
#  <dt><a class="sh_cafe_title" href="https://cafe.naver.com/isajime/3995463" onclick="return goOtherCR(this, 'a=caf_bas*a.tit&amp;r=4&amp;i=90000004_00BDF136003CF74700000000&amp;u='+urlencode(urlexpand(this.href)));" target="_blank" title=""><strong class="hl">박보영</strong> 나오는 드라마 하나봐요</a></dt>,
#  <dt><a class="sh_cafe_title" href="https://cafe.naver.com/joonggonara/583117874" onclick="return goOtherCR(this, 'a=caf_bas*s.tit&amp;r=5&amp;i=90000004_00995A6222C1AC3200000000&amp;u='+urlencode(urlexpand(this.href)));" target="_blank" title="">럭키슈에뜨 <strong class="hl">박보영</strong> 가디건</a><img alt="상품" class="icon" height="14" src="https://ssl.pstatic.net/sstatic/search/img3/ico_cafe_goods.gif" width="25"/></dt>,
#  <dt> <a class="sh_blog_title _sp_each_url _sp_each_title" href="https://blog.naver.com/js2y86?Redirect=Log&amp;logNo=221454815826" onclick="return goOtherCR(this,'a=blg_1st*i.tit&amp;r=1&amp;i=90000003_00000000000000338FBC5252&amp;u='+urlencode(urlexpand(this.href)));" target="_blank" title="박보영 : 오 나의 귀신님 나봉선"><strong class="hl">박보영</strong> : 오 나의 귀신님 나봉선</a> </dt>,
#  <dt> <a class="sh_blog_title _sp_each_url _sp_each_title" href="https://blog.naver.com/cuterobbie?Redirect=Log&amp;logNo=221521796495" onclick="return goOtherCR(this,'a=blg_1st*i.tit&amp;r=2&amp;i=90000003_000000000000003393BA5D8F&amp;u='+urlencode(urlexpand(this.href)));" target="_blank" title="[티저] 초면에 사랑합니다 vs 어비스 (김영광vs박보영)">[티저] 초면에 사랑합니다 vs 어비스 (김영광vs<strong class="hl">박보영</strong>)</a> </dt>,
#  <dt> <a class="sh_blog_title _sp_each_url _sp_each_title" href="https://blog.naver.com/agaci01?Redirect=Log&amp;logNo=221528823480" onclick="return goOtherCR(this,'a=blg_1st*i.tit&amp;r=3&amp;i=90000003_0000000000000033942596B8&amp;u='+urlencode(urlexpand(this.href)));" target="_blank" title="NO.44 낙성대속눈썹 /서울대입구속눈썹 tvn 월화드라마 어비스로 돌아올 박보영 스타일에 대해 알아보자">월화드라마 어비스로 돌아올 <strong class="hl">박보영</strong> 스타일에 대해 알아보자</a> </dt>,
#  <dt> <a class="sh_blog_title _sp_each_url _sp_each_title" href="https://skinous.tistory.com/entry/%EB%B0%95%EB%B3%B4%EC%98%81-%EA%B9%80%EC%98%81%EA%B4%91-%EC%97%B4%EC%95%A0-%EB%82%98%EC%9D%B4%EC%99%80%ED%82%A4-%EA%B5%B0%EB%8C%80-%EB%AF%B8%EC%9A%B0%EC%83%88-%EC%B6%9C%EC%97%B0" onclick="return goOtherCR(this,'a=blg_1st*t.tit&amp;r=4&amp;i=a00000fa_72d29ebb56b3722a2aa8865c&amp;u='+urlencode(urlexpand(this.href)));" target="_blank" title="박보영 김영광 열애 나이와키 군대 미우새 출연"><strong class="hl">박보영</strong> 김영광 열애 나이와키 군대 미우새 출연</a> </dt>,
#  <dt> <a class="sh_blog_title _sp_each_url _sp_each_title" href="https://chearrr.tistory.com/entry/%EB%B0%95%EB%B3%B4%EC%98%81-%EA%B9%80%EC%98%81%EA%B4%91-%EC%97%B4%EC%95%A0-%ED%82%A4%EC%B0%A8%EC%9D%B4-%EC%95%84%EB%B2%84%EC%A7%80-%EA%B5%B0%EB%8C%80" onclick="return goOtherCR(this,'a=blg_1st*t.tit&amp;r=5&amp;i=a00000fa_4b37b4c6787f898e887bce9c&amp;u='+urlencode(urlexpand(this.href)));" target="_blank" title="박보영 김영광 열애 키차이 아버지 군대 ?"><strong class="hl">박보영</strong> 김영광 열애 키차이 아버지 군대 ?</a> </dt>,
#  <dt class="question"> <strong class="spkn">질문</strong> <a href="https://kin.naver.com/qna/detail.nhn?d1id=3&amp;dirId=306&amp;docId=325917258&amp;qb=67CV67O07JiB&amp;enc=utf8&amp;section=kin&amp;rank=1&amp;search_sort=0&amp;spq=1" onclick="add_pid_sid_once(this); return goOtherCR(this,'a=kin_2nd*q.tit&amp;r=1&amp;i=10000009_0000136d1a4a&amp;u='+urlencode(this.href));" target="_blank">제가 <strong class="hl">박보영</strong> 옛날 턱이락 똑같은데 어</a> </dt>,
#  <dt class="question"> <strong class="spkn">질문</strong> <a href="https://kin.naver.com/qna/detail.nhn?d1id=3&amp;dirId=31402&amp;docId=322399276&amp;qb=67CV67O07JiB&amp;enc=utf8&amp;section=kin&amp;rank=2&amp;search_sort=0&amp;spq=1" onclick="add_pid_sid_once(this); return goOtherCR(this,'a=kin_2nd*q.tit&amp;r=2&amp;i=10000009_000013376c2c&amp;u='+urlencode(this.href));" target="_blank"><strong class="hl">박보영</strong> 이 사진 고화질 부탁 내공 5</a> </dt>,
#  <dt class="question"> <strong class="spkn">질문</strong> <a href="https://kin.naver.com/qna/detail.nhn?d1id=3&amp;dirId=31401&amp;docId=315877714&amp;qb=67CV67O07JiB&amp;enc=utf8&amp;section=kin&amp;rank=3&amp;search_sort=0&amp;spq=1" onclick="add_pid_sid_once(this); return goOtherCR(this,'a=kin_2nd*q.tit&amp;r=3&amp;i=10000009_000012d3e952&amp;u='+urlencode(this.href));" target="_blank"><strong class="hl">박보영</strong> 폰 배경사진 고화질로 여러장</a> </dt>,
#  <dt class="question"> <strong class="spkn">질문</strong> <a href="https://kin.naver.com/qna/detail.nhn?d1id=8&amp;dirId=8030203&amp;docId=323375788&amp;qb=67CV67O07JiB&amp;enc=utf8&amp;section=kin&amp;rank=4&amp;search_sort=0&amp;spq=1" onclick="add_pid_sid_once(this); return goOtherCR(this,'a=kin_2nd*q.tit&amp;r=4&amp;i=10000009_0000134652ac&amp;u='+urlencode(this.href));" target="_blank"><strong class="hl">박보영</strong> 머리색깔</a> </dt>,
#  <dt> <a class="title_link" href="https://namu.wiki/w/%EB%B0%95%EB%B3%B4%EC%98%81" onclick="return goOtherCR(this, 'a=web_all*w.tit&amp;r=1&amp;i=a00000fa_8a96d12a72d00f80d7b77f41&amp;u='+urlencode(this.href ? this.href : location.href))" target="_blank"><strong class="hl">박보영</strong> - 나무위키</a> <span class="ico_area"> </span> </dt>,
#  <dt> <a class="title_link" href="http://gall.dcinside.com/board/lists/?id=parkboyoung" onclick="return goOtherCR(this, 'a=web_all*w.tit&amp;r=2&amp;i=a00000fa_cf2bc48c8943e5599cc3e5a3&amp;u='+urlencode(this.href ? this.href : location.href))" target="_blank"><strong class="hl">박보영</strong> 갤러리</a> <span class="ico_area"> </span> </dt>,
#  <dt> <a class="title_link" href="https://movie.daum.net/person/main?personId=105244" onclick="return goOtherCR(this, 'a=web_all*w.tit&amp;r=3&amp;i=a00000fa_45c148359252c90712a55813&amp;u='+urlencode(this.href ? this.href : location.href))" target="_blank"><strong class="hl">박보영</strong></a> <span class="ico_area"> </span> </dt>,
#  <dt>동영상 재생시간</dt>,
#  <dt>동영상 재생시간</dt>,
#  <dt>동영상 재생시간</dt>,
#  <dt class="blind">유의사항</dt>]

# %%
for _ in dom.find_all("dt"):
    if "-".join([_.name for _ in _.find_parents(limits=4)]) == "dl-li-ul-div":
        a = _.find("a")
        
        if a:
            print("a.text.strip()")
            print(a["href"])

# %%
html = download("https://search.daum.net/search", {"q":"박보영"})
daum = BeautifulSoup(html.text, "lxml")

# %%
i = 0
for _ in daum.find_all("div", {"class":"wrap_tit"}):
    a = _.find("a")
    
    if a:
        i += 1
        print(a.text.strip())
        print(a["href"])

print(i)
# Out:
# "세젤흔녀로 변신한 박보영"..유제원 감독X박보영 '어비스' (종합)
# http://v.media.daum.net/v/20190503153440722?f=o
# '어비스' 이성재 "다시 태어난다면? 예쁜 박보영으로"..박보영 '폭소'
# http://v.media.daum.net/v/20190503145429254?f=o
# 박보영이 가장 흔한 여자, 설득력 있을까 '어비스'
# http://v.media.daum.net/v/20190503172414326?f=o
# [현장]'어비스' 박보영 "김사랑과 차이? 커졌다 작아졌다.."
# http://v.media.daum.net/v/20190503165134297?f=o
# 김영광 박보영 열애 터진 이유
# http://adam24eve.tistory.com/858
# 박보영 실제 키는 도대체 몇일까?
# http://papa0717.tistory.com/223
# 박보영 나이 키 몸매 대박
# http://k3k2y.tistory.com/35
# 박보영 키 나이 인스타그램 드라마 어비스
# http://listup.tistory.com/248
# 드라마 어비스 인물 소개, 예고편(박보영, 안효섭 주연)
# http://cafe.daum.net/subdued20club/ReHf/2282606?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영과 역대급 케미뽐낸 상대배우 고르기
# http://cafe.daum.net/subdued20club/ReHf/2280152?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 런닝맨 나올 때마다 케미 보여준 송지효X박보영.jpgif
# http://cafe.daum.net/ok1221/9Zdf/1524913?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영이 왜 못 오를 나무냐는 박수홍.jpg
# http://cafe.daum.net/ASMONACOFC/gAVU/1243818?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영
# https://ko.wikipedia.org/wiki/%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영 (법조인)
# https://ko.wikipedia.org/wiki/%EB%B0%95%EB%B3%B4%EC%98%81%20%28%EB%B2%95%EC%A1%B0%EC%9D%B8%29
# 박보영 갤러리
# http://gall.dcinside.com/board/lists/?id=parkboyoung
# 박보영 공식팬카페 뽀르테
# http://cafe.daum.net/parkboyoungfd
# Park Bo Young V LIVE
# http://channels.vlive.tv/FCE49/video
# 인천방주교회
# http://www.bjc.or.kr/
# 박보영, 송지효는 ‘친언니’ 이광수는 ‘그냥 기린’
# javascript:;
# 박형식, 박보영을 번쩍(!) 둘만의 '피아노 키스♥' //ㅁ//
# javascript:;
# '비밀의 교정'때의 박보영☆
# javascript:;
# [메이킹]세젤흔녀로 돌아온 박보영, ＜어비스 : 영혼소생구슬＞ 대본리딩 현장 최초 공개!
# javascript:;
# 애교 있어 보이지만 상여자(?) 스타일이라는 박보영
# javascript:;
# 박보영누나 과속스캔들찍고 또 다른 드라마나 영화 찍나요?> 박보영누나...
# http://tip.daum.net/answer/55072609?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영, 과속스캔들 OST 중 '아마도그건' 불렀다던데, 이번에 과속...
# http://tip.daum.net/answer/54767339?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영 질문요. 박보영 진짜 예쁘더군요... 박보영이 대체 누군...
# http://tip.daum.net/answer/54866982?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 박보영, 제2의 문근영이라는 호칭때문에 악플에 시달렸나요? 아역배우...
# http://tip.daum.net/answer/54503481?q=%EB%B0%95%EB%B3%B4%EC%98%81
# 27

# %% [markdown]
# ### Google

# %%
url = 'https://www.google.com/search'
params = {'q':'박보영'}
html = download(url, params)

dom = BeautifulSoup(html.text, 'lxml')

for tag in dom.find_all('', {'class':'r'}):
    print(tag.find('h3'))
