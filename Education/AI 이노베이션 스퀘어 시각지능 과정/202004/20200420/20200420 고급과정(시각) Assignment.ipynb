# %%
from __future__ import print_function
import keras
from keras.datasets import cifar10
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
import os

batch_size = 32
num_classes = 10
epochs = 50
data_augmentation = True
num_predictions = 20
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'keras_cifar10_trained_model.h5'

(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=x_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes))
model.add(Activation('softmax'))

opt = keras.optimizers.RMSprop(lr=0.0001, decay=1e-6)

model.compile(loss='categorical_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True)
else:
    print('Using real-time data augmentation.')

    datagen = ImageDataGenerator(
        featurewise_center=False,
        samplewise_center=False,
        featurewise_std_normalization=False,
        samplewise_std_normalization=False,
        zca_whitening=False,
        zca_epsilon=1e-06,
        rotation_range=0,
        width_shift_range=0.1,
        height_shift_range=0.1,
        shear_range=0.,
        zoom_range=0.,
        channel_shift_range=0.,
        fill_mode='nearest',
        cval=0.,
        horizontal_flip=True,
        vertical_flip=False,
        rescale=None,
        preprocessing_function=None,
        data_format=None,
        validation_split=0.0)

    datagen.fit(x_train)

    model.fit_generator(datagen.flow(x_train, y_train,
                                     batch_size=batch_size),
                        epochs=epochs,
                        steps_per_epoch=500,
                        validation_data=(x_test, y_test),
                        workers=4)

if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)

print('Saved trained model at %s ' % model_path)

scores = model.evaluate(x_test, y_test, verbose=1)

print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# Using real-time data augmentation.
# Epoch 1/50
# 500/500 [==============================] - 33s 66ms/step - loss: 2.1033 - accuracy: 0.2121 - val_loss: 1.8577 - val_accuracy: 0.3455
# Epoch 2/50
# 500/500 [==============================] - 33s 65ms/step - loss: 1.8336 - accuracy: 0.3298 - val_loss: 1.6613 - val_accuracy: 0.4089
# Epoch 3/50
# 500/500 [==============================] - 32s 65ms/step - loss: 1.7266 - accuracy: 0.3659 - val_loss: 1.6958 - val_accuracy: 0.3887
# Epoch 4/50
# 500/500 [==============================] - 33s 65ms/step - loss: 1.6573 - accuracy: 0.3915 - val_loss: 1.5282 - val_accuracy: 0.4469
# Epoch 5/50
# 500/500 [==============================] - 33s 65ms/step - loss: 1.5978 - accuracy: 0.4093 - val_loss: 1.5217 - val_accuracy: 0.4614
# Epoch 6/50
# 500/500 [==============================] - 33s 66ms/step - loss: 1.5587 - accuracy: 0.4324 - val_loss: 1.4145 - val_accuracy: 0.4901
# Epoch 7/50
# 500/500 [==============================] - 33s 66ms/step - loss: 1.5112 - accuracy: 0.4526 - val_loss: 1.3881 - val_accuracy: 0.4989
# Epoch 8/50
# 500/500 [==============================] - 33s 66ms/step - loss: 1.4705 - accuracy: 0.4682 - val_loss: 1.3422 - val_accuracy: 0.5224
# Epoch 9/50
# 500/500 [==============================] - 33s 66ms/step - loss: 1.4383 - accuracy: 0.4839 - val_loss: 1.2998 - val_accuracy: 0.5372
# Epoch 10/50
# 500/500 [==============================] - 33s 66ms/step - loss: 1.4178 - accuracy: 0.4882 - val_loss: 1.3106 - val_accuracy: 0.5250
# Epoch 11/50
# 500/500 [==============================] - 33s 65ms/step - loss: 1.3977 - accuracy: 0.4997 - val_loss: 1.2543 - val_accuracy: 0.5465
# Epoch 12/50
# 500/500 [==============================] - 32s 65ms/step - loss: 1.3768 - accuracy: 0.5052 - val_loss: 1.2349 - val_accuracy: 0.5652
# Epoch 13/50
# 500/500 [==============================] - 33s 65ms/step - loss: 1.3200 - accuracy: 0.5301 - val_loss: 1.2596 - val_accuracy: 0.5512
# Epoch 14/50
# 500/500 [==============================] - 32s 65ms/step - loss: 1.3126 - accuracy: 0.5310 - val_loss: 1.1647 - val_accuracy: 0.5846
# Epoch 15/50
# 500/500 [==============================] - 32s 65ms/step - loss: 1.3225 - accuracy: 0.5254 - val_loss: 1.1446 - val_accuracy: 0.5964
# Epoch 16/50
# 500/500 [==============================] - 33s 65ms/step - loss: 1.2861 - accuracy: 0.5419 - val_loss: 1.1670 - val_accuracy: 0.5782
# Epoch 17/50
# 500/500 [==============================] - 33s 66ms/step - loss: 1.2641 - accuracy: 0.5493 - val_loss: 1.1267 - val_accuracy: 0.6009
# Epoch 18/50
# 500/500 [==============================] - 33s 66ms/step - loss: 1.2473 - accuracy: 0.5552 - val_loss: 1.1160 - val_accuracy: 0.6025
# Epoch 19/50
# 500/500 [==============================] - 33s 66ms/step - loss: 1.2315 - accuracy: 0.5610 - val_loss: 1.0774 - val_accuracy: 0.6194
# Epoch 20/50
# 500/500 [==============================] - 32s 65ms/step - loss: 1.2201 - accuracy: 0.5643 - val_loss: 1.1290 - val_accuracy: 0.6039
# Epoch 21/50
# 500/500 [==============================] - 32s 64ms/step - loss: 1.2183 - accuracy: 0.5711 - val_loss: 1.0625 - val_accuracy: 0.6242
# Epoch 22/50
# 500/500 [==============================] - 32s 64ms/step - loss: 1.1791 - accuracy: 0.5833 - val_loss: 1.0843 - val_accuracy: 0.6120
# Epoch 23/50
# 500/500 [==============================] - 32s 64ms/step - loss: 1.1803 - accuracy: 0.5789 - val_loss: 1.0153 - val_accuracy: 0.6382
# Epoch 24/50
# 500/500 [==============================] - 32s 65ms/step - loss: 1.1580 - accuracy: 0.5947 - val_loss: 1.0385 - val_accuracy: 0.6323
# Epoch 25/50
# 500/500 [==============================] - 31s 63ms/step - loss: 1.1455 - accuracy: 0.5926 - val_loss: 1.0663 - val_accuracy: 0.6321
# Epoch 26/50
# 500/500 [==============================] - 31s 63ms/step - loss: 1.1378 - accuracy: 0.5940 - val_loss: 1.0914 - val_accuracy: 0.6176
# Epoch 27/50
# 500/500 [==============================] - 32s 65ms/step - loss: 1.1475 - accuracy: 0.5951 - val_loss: 1.0159 - val_accuracy: 0.6401
# Epoch 28/50
# 500/500 [==============================] - 33s 65ms/step - loss: 1.1176 - accuracy: 0.6102 - val_loss: 1.0233 - val_accuracy: 0.6370
# Epoch 29/50
# 500/500 [==============================] - 32s 64ms/step - loss: 1.1123 - accuracy: 0.6079 - val_loss: 0.9840 - val_accuracy: 0.6521
# Epoch 30/50
# 500/500 [==============================] - 32s 64ms/step - loss: 1.1010 - accuracy: 0.6102 - val_loss: 0.9740 - val_accuracy: 0.6505
# Epoch 31/50
# 500/500 [==============================] - 33s 65ms/step - loss: 1.0975 - accuracy: 0.6087 - val_loss: 0.9813 - val_accuracy: 0.6535
# Epoch 32/50
# 500/500 [==============================] - 32s 64ms/step - loss: 1.0908 - accuracy: 0.6116 - val_loss: 0.9786 - val_accuracy: 0.6537
# Epoch 33/50
# 500/500 [==============================] - 33s 65ms/step - loss: 1.0745 - accuracy: 0.6188 - val_loss: 0.9857 - val_accuracy: 0.6521
# Epoch 34/50
# 500/500 [==============================] - 32s 64ms/step - loss: 1.0739 - accuracy: 0.6191 - val_loss: 0.9508 - val_accuracy: 0.6621
# Epoch 35/50
# 500/500 [==============================] - 32s 63ms/step - loss: 1.0677 - accuracy: 0.6264 - val_loss: 0.9130 - val_accuracy: 0.6761
# Epoch 36/50
# 500/500 [==============================] - 32s 63ms/step - loss: 1.0583 - accuracy: 0.6248 - val_loss: 0.9369 - val_accuracy: 0.6694
# Epoch 37/50
# 500/500 [==============================] - 32s 63ms/step - loss: 1.0347 - accuracy: 0.6350 - val_loss: 0.9301 - val_accuracy: 0.6717
# Epoch 38/50
# 500/500 [==============================] - 32s 64ms/step - loss: 1.0541 - accuracy: 0.6286 - val_loss: 0.9862 - val_accuracy: 0.6533
# Epoch 39/50
# 500/500 [==============================] - 32s 64ms/step - loss: 1.0413 - accuracy: 0.6347 - val_loss: 0.9185 - val_accuracy: 0.6739
# Epoch 40/50
# 500/500 [==============================] - 32s 64ms/step - loss: 1.0336 - accuracy: 0.6368 - val_loss: 0.9095 - val_accuracy: 0.6790
# Epoch 41/50
# 500/500 [==============================] - 33s 66ms/step - loss: 1.0181 - accuracy: 0.6446 - val_loss: 0.9134 - val_accuracy: 0.6761
# Epoch 42/50
# 500/500 [==============================] - 32s 63ms/step - loss: 1.0255 - accuracy: 0.6407 - val_loss: 0.9073 - val_accuracy: 0.6805
# Epoch 43/50
# 500/500 [==============================] - 32s 64ms/step - loss: 1.0031 - accuracy: 0.6478 - val_loss: 0.9168 - val_accuracy: 0.6757
# Epoch 44/50
# 500/500 [==============================] - 32s 65ms/step - loss: 1.0170 - accuracy: 0.6371 - val_loss: 0.9254 - val_accuracy: 0.6718
# Epoch 45/50
# 500/500 [==============================] - 32s 65ms/step - loss: 0.9968 - accuracy: 0.6463 - val_loss: 0.8799 - val_accuracy: 0.6902
# Epoch 46/50
# 500/500 [==============================] - 33s 65ms/step - loss: 0.9907 - accuracy: 0.6526 - val_loss: 0.9103 - val_accuracy: 0.6856
# Epoch 47/50
# 500/500 [==============================] - 32s 65ms/step - loss: 0.9863 - accuracy: 0.6538 - val_loss: 0.9430 - val_accuracy: 0.6714
# Epoch 48/50
# 500/500 [==============================] - 32s 65ms/step - loss: 0.9864 - accuracy: 0.6552 - val_loss: 0.8401 - val_accuracy: 0.7044
# Epoch 49/50
# 500/500 [==============================] - 32s 65ms/step - loss: 0.9787 - accuracy: 0.6537 - val_loss: 0.9923 - val_accuracy: 0.6638
# Epoch 50/50
# 500/500 [==============================] - 33s 65ms/step - loss: 0.9619 - accuracy: 0.6656 - val_loss: 0.8338 - val_accuracy: 0.7079
# Saved trained model at C:\Users\Jae\Desktop\바탕화면 파일들\HistoryOfMyStudy\Education\AI 이노베이션 스퀘어 시각인지 과정\202004\20200420\saved_models\keras_cifar10_trained_model.h5
# 10000/10000 [==============================] - 3s 335us/step
# Test loss: 0.833815465259552
# Test accuracy: 0.7078999876976013
