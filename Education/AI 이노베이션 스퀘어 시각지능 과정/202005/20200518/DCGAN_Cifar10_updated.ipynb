# %%
from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/gdrive')

# %%
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization, Activation, ZeroPadding2D, GlobalAveragePooling2D
from keras.layers.advanced_activations import LeakyReLU, ReLU
from keras.layers.convolutional import UpSampling2D, Conv2D, Conv2DTranspose
from keras.models import Sequential, Model
from keras.optimizers import Adam,SGD
from keras import initializers
import os
import keras
from keras import layers
import matplotlib.pyplot as plt
import sys
import numpy as np
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.

# %%
(X_train, y_train), (_, _) = keras.datasets.cifar10.load_data()
X_train = X_train[y_train.flatten() == 3]
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %%
def visualize_rgb(img):
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.imshow(img)
    ax.axis("off")
    ax.set_title("Image")
    plt.show()

# %%
visualize_rgb(X_train[0])

# %%
img_rows = 32
img_cols = 32
channels = 3      
img_shape = (img_rows, img_cols, channels)        
latent_dim = 100

# %%
latent_dim = 100

init = initializers.RandomNormal(stddev=0.02)

generator = Sequential()

generator.add(Dense(2*2*512, input_shape=(latent_dim,), activation='relu', kernel_initializer=init))
generator.add(BatchNormalization())
generator.add(Reshape((2, 2, 512)))

generator.add(Conv2DTranspose(256, kernel_size=3, activation='relu', kernel_initializer=init, strides=2, padding='same'))
generator.add(BatchNormalization())

generator.add(Conv2DTranspose(128, kernel_size=3, activation='relu', kernel_initializer=init, strides=2, padding='same'))
generator.add(BatchNormalization())

generator.add(Conv2DTranspose(64, kernel_size=3, activation='relu', kernel_initializer=init, strides=2, padding='same'))
generator.add(BatchNormalization())

generator.add(Conv2DTranspose(3, kernel_size=3, strides=2, padding='same',kernel_initializer=init,
                              activation='tanh'))

# %%
generator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 2048)              206848
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 2048)              8192
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 4, 4, 256)         1179904
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# conv2d_transpose_2 (Conv2DTr (None, 8, 8, 128)         295040
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_transpose_3 (Conv2DTr (None, 16, 16, 64)        73792
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_transpose_4 (Conv2DTr (None, 32, 32, 3)         1731
# =================================================================
# Total params: 1,767,299
# Trainable params: 1,762,307
# Non-trainable params: 4,992
# _________________________________________________________________

# %%
img_shape = X_train[0].shape

discriminator = Sequential()

discriminator.add(Conv2D(64, kernel_size=3, strides=2, use_bias=False, padding='valid',
                         input_shape=(img_shape), kernel_initializer=init))
discriminator.add(BatchNormalization())
discriminator.add(LeakyReLU(0.2))

discriminator.add(Conv2D(128, kernel_size=3, strides=2,  kernel_initializer=init, use_bias=False, padding='valid'))
discriminator.add(BatchNormalization())
discriminator.add(LeakyReLU(0.2))

discriminator.add(Conv2D(256, kernel_size=3, strides=2, kernel_initializer=init, use_bias=False, padding='valid'))
discriminator.add(BatchNormalization())
discriminator.add(LeakyReLU(0.2))

# discriminator.add(Flatten())
discriminator.add(GlobalAveragePooling2D())

discriminator.add(Dense(1, activation='sigmoid'))

# %%
discriminator.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 15, 15, 64)        1728
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 128)         73728
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 7, 7, 128)         512
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 256)         294912
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 3, 3, 256)         1024
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 3, 3, 256)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 372,417
# Trainable params: 371,521
# Non-trainable params: 896
# _________________________________________________________________

# %%
discriminator.compile(Adam(lr=0.0002, beta_1=0.5), loss='binary_crossentropy',
                      metrics=['binary_accuracy'])

# %%
# d_g = discriminador(generador(z))
discriminator.trainable = False

z = Input(shape=(latent_dim,))
img = generator(z)
decision = discriminator(img)
gan_model = Model(inputs=z, outputs=decision)

gan_model.compile(Adam(lr=0.0002, beta_1=0.5), loss='binary_crossentropy',
            metrics=['binary_accuracy'])

# %%
def normalize(img):
    return (img - 127.5) / 127.5

# %%
def denormalize(img):
    img = (img * 127.5) + 127.5
    return img.astype(np.uint8)

# %%
print(X_train.shape)
# Out:
# (5000, 32, 32, 3)

# %%
X_train = normalize(X_train)

iterations = 5000
batch_size = 20
save_dir = os.path.join("./", 'gan_images')

if not os.path.exists(save_dir):
    os.mkdir(save_dir)

# %%
epochs = 1000
batch_size = 32
smooth = 0.1

real = np.ones(shape=(batch_size, 1))
fake = np.zeros(shape=(batch_size, 1))

d_loss = []
g_loss = []

for e in range(epochs + 1):
    for i in range(len(X_train) // batch_size):
        discriminator.trainable = True

        X_batch = X_train[i*batch_size:(i+1)*batch_size]
        d_loss_real = discriminator.train_on_batch(x=X_batch, y=real * (1 - smooth))
    
        z = np.random.normal(loc=0, scale=1, size=(batch_size, latent_dim))
        X_fake = generator.predict_on_batch(z)
        d_loss_fake = discriminator.train_on_batch(x=X_fake, y=fake)
         
        d_loss_batch = (d_loss_real[0] + d_loss_fake[0])
        
        discriminator.trainable = False
        g_loss_batch = gan_model.train_on_batch(x=z, y=real)

        print(
            'epoch = %d/%d, batch = %d/%d, d_loss=%.3f, g_loss=%.3f' % (e + 1, epochs, i, len(X_train) // batch_size, d_loss_batch, g_loss_batch[0]),
            100*' ',
            end='\r'
        )
    
    d_loss.append(d_loss_batch)
    g_loss.append(g_loss_batch[0])

    print('epoch = %d/%d, d_loss=%.3f, g_loss=%.3f' % (e + 1, epochs, d_loss[-1], g_loss[-1]), 100*' ')

    if e % 3 == 0:
      gan_model.save_weights('gan.h5')

      img = image.array_to_img(denormalize(X_fake[0]), scale=False)
      img.save(os.path.join(save_dir, 'generated' + str(e) + '.png'))

      img = image.array_to_img(denormalize(X_batch[0]), scale=False)
      img.save(os.path.join(save_dir, 'real' + str(e) + '.png'))
# Out:
# epoch = 1/1000, d_loss=0.486, g_loss=0.162
# epoch = 2/1000, d_loss=0.472, g_loss=0.157
# epoch = 3/1000, d_loss=1.206, g_loss=0.813
# epoch = 4/1000, d_loss=1.371, g_loss=0.988
# epoch = 5/1000, d_loss=1.284, g_loss=0.896
# epoch = 6/1000, d_loss=1.250, g_loss=0.906
# epoch = 7/1000, d_loss=1.352, g_loss=0.923
# epoch = 8/1000, d_loss=1.317, g_loss=0.884
# epoch = 9/1000, d_loss=1.276, g_loss=0.919
# epoch = 10/1000, d_loss=1.321, g_loss=0.931
# epoch = 11/1000, d_loss=1.334, g_loss=0.906
# epoch = 12/1000, d_loss=1.285, g_loss=0.956
# epoch = 13/1000, d_loss=1.340, g_loss=0.909
# epoch = 14/1000, d_loss=1.341, g_loss=0.892
# epoch = 15/1000, d_loss=1.389, g_loss=0.882
# epoch = 16/1000, d_loss=1.241, g_loss=0.904
# epoch = 17/1000, d_loss=1.343, g_loss=0.879
# epoch = 18/1000, d_loss=1.312, g_loss=0.900
# epoch = 19/1000, d_loss=1.354, g_loss=0.898
# epoch = 20/1000, d_loss=1.335, g_loss=0.943
# epoch = 21/1000, d_loss=1.334, g_loss=0.919
# epoch = 22/1000, d_loss=1.286, g_loss=0.892
# epoch = 23/1000, d_loss=1.321, g_loss=0.969
# epoch = 24/1000, d_loss=1.345, g_loss=0.885
# epoch = 25/1000, d_loss=1.302, g_loss=0.893
# epoch = 26/1000, d_loss=1.313, g_loss=0.948
# epoch = 27/1000, d_loss=1.327, g_loss=0.941
# epoch = 28/1000, d_loss=1.251, g_loss=0.889
# epoch = 29/1000, d_loss=1.283, g_loss=0.893
# epoch = 30/1000, d_loss=1.369, g_loss=0.969
# epoch = 31/1000, d_loss=1.244, g_loss=0.931
# epoch = 32/1000, d_loss=1.240, g_loss=0.951
# epoch = 33/1000, d_loss=1.282, g_loss=0.932
# epoch = 34/1000, d_loss=1.230, g_loss=0.950
# epoch = 35/1000, d_loss=1.267, g_loss=0.925
# epoch = 36/1000, d_loss=1.319, g_loss=0.963
# epoch = 37/1000, d_loss=1.178, g_loss=0.966
# epoch = 38/1000, d_loss=1.230, g_loss=0.945
# epoch = 39/1000, d_loss=1.182, g_loss=0.935
# epoch = 40/1000, d_loss=1.227, g_loss=1.007
# epoch = 41/1000, d_loss=1.249, g_loss=0.933
# epoch = 42/1000, d_loss=1.164, g_loss=1.035
# epoch = 43/1000, d_loss=1.194, g_loss=0.927
# epoch = 44/1000, d_loss=1.312, g_loss=0.986
# epoch = 45/1000, d_loss=1.188, g_loss=1.005
# epoch = 46/1000, d_loss=1.210, g_loss=1.009
# epoch = 47/1000, d_loss=1.128, g_loss=1.021
# epoch = 48/1000, d_loss=1.206, g_loss=0.990
# epoch = 49/1000, d_loss=1.181, g_loss=0.966
# epoch = 50/1000, d_loss=1.119, g_loss=1.028
# epoch = 51/1000, d_loss=1.127, g_loss=1.040
# epoch = 52/1000, d_loss=1.117, g_loss=0.906
# epoch = 53/1000, d_loss=1.166, g_loss=1.039
# epoch = 54/1000, d_loss=1.109, g_loss=0.999
# epoch = 55/1000, d_loss=1.221, g_loss=1.176
# epoch = 56/1000, d_loss=1.081, g_loss=1.192
# epoch = 57/1000, d_loss=1.066, g_loss=1.058
# epoch = 58/1000, d_loss=1.201, g_loss=1.072
# epoch = 59/1000, d_loss=1.104, g_loss=0.979
# epoch = 60/1000, d_loss=1.064, g_loss=1.045
# epoch = 61/1000, d_loss=1.169, g_loss=1.196
# epoch = 62/1000, d_loss=1.149, g_loss=0.926
# epoch = 63/1000, d_loss=1.053, g_loss=1.085
# epoch = 64/1000, d_loss=1.048, g_loss=1.133
# epoch = 65/1000, d_loss=1.081, g_loss=1.101
# epoch = 66/1000, d_loss=1.043, g_loss=1.146
# epoch = 67/1000, d_loss=1.061, g_loss=1.110
# epoch = 68/1000, d_loss=1.026, g_loss=1.078
# epoch = 69/1000, d_loss=1.177, g_loss=1.173
# epoch = 70/1000, d_loss=1.168, g_loss=1.078
# epoch = 71/1000, d_loss=1.154, g_loss=1.009
# epoch = 72/1000, d_loss=1.021, g_loss=1.116
# epoch = 73/1000, d_loss=1.119, g_loss=1.098
# epoch = 74/1000, d_loss=1.018, g_loss=1.072
# epoch = 75/1000, d_loss=1.095, g_loss=1.037
# epoch = 76/1000, d_loss=1.325, g_loss=1.076
# epoch = 77/1000, d_loss=1.049, g_loss=1.202
# epoch = 78/1000, d_loss=1.004, g_loss=1.170
# epoch = 79/1000, d_loss=1.080, g_loss=1.166
# epoch = 80/1000, d_loss=1.036, g_loss=0.913
# epoch = 81/1000, d_loss=0.940, g_loss=1.060
# epoch = 82/1000, d_loss=0.949, g_loss=1.152
# epoch = 83/1000, d_loss=0.966, g_loss=1.149
# epoch = 84/1000, d_loss=1.094, g_loss=1.108
# epoch = 85/1000, d_loss=1.098, g_loss=1.084
# epoch = 86/1000, d_loss=1.037, g_loss=1.163
# epoch = 87/1000, d_loss=1.178, g_loss=1.048
# epoch = 88/1000, d_loss=0.964, g_loss=0.763
# epoch = 89/1000, d_loss=1.193, g_loss=1.403
# epoch = 90/1000, d_loss=1.033, g_loss=1.321
# epoch = 91/1000, d_loss=0.940, g_loss=1.301
# epoch = 92/1000, d_loss=0.953, g_loss=1.206
# epoch = 93/1000, d_loss=1.038, g_loss=1.142
# epoch = 94/1000, d_loss=1.013, g_loss=1.224
# epoch = 95/1000, d_loss=0.956, g_loss=1.184
# epoch = 96/1000, d_loss=0.901, g_loss=1.167
# epoch = 97/1000, d_loss=1.184, g_loss=1.359
# epoch = 98/1000, d_loss=0.920, g_loss=1.156
# epoch = 99/1000, d_loss=1.069, g_loss=1.181
# epoch = 100/1000, d_loss=1.143, g_loss=1.136
# epoch = 101/1000, d_loss=1.038, g_loss=1.120
# epoch = 102/1000, d_loss=1.117, g_loss=1.007
# epoch = 103/1000, d_loss=0.973, g_loss=1.121
# epoch = 104/1000, d_loss=0.883, g_loss=1.257
# epoch = 105/1000, d_loss=1.025, g_loss=1.085
# epoch = 106/1000, d_loss=0.910, g_loss=1.195
# epoch = 107/1000, d_loss=1.074, g_loss=0.926
# epoch = 108/1000, d_loss=0.899, g_loss=1.135
# epoch = 109/1000, d_loss=0.894, g_loss=1.263
# epoch = 110/1000, d_loss=0.966, g_loss=1.215
# epoch = 111/1000, d_loss=1.048, g_loss=1.150
# epoch = 112/1000, d_loss=1.156, g_loss=0.988
# epoch = 113/1000, d_loss=0.851, g_loss=1.197
# epoch = 114/1000, d_loss=0.947, g_loss=1.398
# epoch = 115/1000, d_loss=0.811, g_loss=1.321
# epoch = 116/1000, d_loss=0.904, g_loss=1.355
# epoch = 117/1000, d_loss=1.307, g_loss=1.176
# epoch = 118/1000, d_loss=0.917, g_loss=0.864
# epoch = 119/1000, d_loss=0.897, g_loss=1.207
# epoch = 120/1000, d_loss=0.952, g_loss=1.364
# epoch = 121/1000, d_loss=1.297, g_loss=0.868
# epoch = 122/1000, d_loss=1.248, g_loss=1.188
# epoch = 123/1000, d_loss=0.909, g_loss=1.155
# epoch = 124/1000, d_loss=0.948, g_loss=1.216
# epoch = 125/1000, d_loss=0.858, g_loss=1.360
# epoch = 126/1000, d_loss=0.879, g_loss=1.323
# epoch = 127/1000, d_loss=1.072, g_loss=1.113
# epoch = 128/1000, d_loss=0.931, g_loss=1.128
# epoch = 129/1000, d_loss=0.826, g_loss=1.263
# epoch = 130/1000, d_loss=0.839, g_loss=1.365
# epoch = 131/1000, d_loss=0.931, g_loss=1.312
# epoch = 132/1000, d_loss=0.995, g_loss=1.266
# epoch = 133/1000, d_loss=1.175, g_loss=1.021
# epoch = 134/1000, d_loss=0.946, g_loss=1.241
# epoch = 135/1000, d_loss=1.026, g_loss=1.334
# epoch = 136/1000, d_loss=0.944, g_loss=1.375
# epoch = 137/1000, d_loss=0.807, g_loss=1.515
# epoch = 138/1000, d_loss=1.193, g_loss=1.358
# epoch = 139/1000, d_loss=0.956, g_loss=1.357
# epoch = 140/1000, d_loss=0.963, g_loss=1.303
# epoch = 141/1000, d_loss=1.232, g_loss=1.206
# epoch = 142/1000, d_loss=0.763, g_loss=1.500
# epoch = 143/1000, d_loss=0.815, g_loss=1.544
# epoch = 144/1000, d_loss=0.775, g_loss=1.532
# epoch = 145/1000, d_loss=0.765, g_loss=1.544
# epoch = 146/1000, d_loss=0.815, g_loss=1.475
# epoch = 147/1000, d_loss=0.912, g_loss=1.387
# epoch = 148/1000, d_loss=1.341, g_loss=1.411
# epoch = 149/1000, d_loss=1.073, g_loss=1.237
# epoch = 150/1000, d_loss=0.744, g_loss=1.555
# epoch = 151/1000, d_loss=1.150, g_loss=1.492
# epoch = 152/1000, d_loss=0.926, g_loss=1.366
# epoch = 153/1000, d_loss=1.267, g_loss=1.087
# epoch = 154/1000, d_loss=0.988, g_loss=1.323
# epoch = 155/1000, d_loss=0.940, g_loss=1.295
# epoch = 156/1000, d_loss=0.724, g_loss=1.417
# epoch = 157/1000, d_loss=0.856, g_loss=1.462
# epoch = 158/1000, d_loss=0.818, g_loss=1.418
# epoch = 159/1000, d_loss=0.825, g_loss=1.522
# epoch = 160/1000, d_loss=0.932, g_loss=1.223
# epoch = 161/1000, d_loss=0.737, g_loss=1.624
# epoch = 162/1000, d_loss=0.777, g_loss=1.596
# epoch = 163/1000, d_loss=0.770, g_loss=1.663
# epoch = 164/1000, d_loss=0.766, g_loss=1.583
# epoch = 165/1000, d_loss=1.145, g_loss=1.545
# epoch = 166/1000, d_loss=0.864, g_loss=1.690
# epoch = 167/1000, d_loss=0.955, g_loss=1.827
# epoch = 168/1000, d_loss=0.750, g_loss=1.668
# epoch = 169/1000, d_loss=0.821, g_loss=1.479
# epoch = 170/1000, d_loss=0.957, g_loss=1.386
# epoch = 171/1000, d_loss=0.697, g_loss=1.564
# epoch = 172/1000, d_loss=0.877, g_loss=1.493
# epoch = 173/1000, d_loss=1.088, g_loss=1.216
# epoch = 174/1000, d_loss=0.968, g_loss=1.405
# epoch = 175/1000, d_loss=0.933, g_loss=1.365
# epoch = 176/1000, d_loss=0.912, g_loss=1.539
# epoch = 177/1000, d_loss=0.932, g_loss=1.681
# epoch = 178/1000, d_loss=0.730, g_loss=1.568
# epoch = 179/1000, d_loss=0.726, g_loss=1.695
# epoch = 180/1000, d_loss=1.148, g_loss=1.027
# epoch = 181/1000, d_loss=0.861, g_loss=1.642
# epoch = 182/1000, d_loss=0.793, g_loss=1.622
# epoch = 183/1000, d_loss=0.972, g_loss=1.618
# epoch = 184/1000, d_loss=1.075, g_loss=1.462
# epoch = 185/1000, d_loss=0.878, g_loss=1.799
# epoch = 186/1000, d_loss=1.210, g_loss=1.379
# epoch = 187/1000, d_loss=1.038, g_loss=1.545
# epoch = 188/1000, d_loss=0.809, g_loss=1.226
# epoch = 189/1000, d_loss=0.745, g_loss=1.841
# epoch = 190/1000, d_loss=0.747, g_loss=1.701
# epoch = 191/1000, d_loss=0.816, g_loss=1.704
# epoch = 192/1000, d_loss=0.726, g_loss=1.735
# epoch = 193/1000, d_loss=0.709, g_loss=1.656
# epoch = 194/1000, d_loss=1.062, g_loss=1.516
# epoch = 195/1000, d_loss=0.763, g_loss=1.624
# epoch = 196/1000, d_loss=0.805, g_loss=1.659
# epoch = 197/1000, d_loss=0.900, g_loss=1.530
# epoch = 198/1000, d_loss=0.896, g_loss=1.706
# epoch = 199/1000, d_loss=1.010, g_loss=1.253
# epoch = 200/1000, d_loss=0.748, g_loss=1.512
# epoch = 201/1000, d_loss=0.926, g_loss=1.741
# epoch = 202/1000, d_loss=0.863, g_loss=1.813
# epoch = 203/1000, d_loss=1.114, g_loss=1.602
# epoch = 204/1000, d_loss=1.298, g_loss=1.875
# epoch = 205/1000, d_loss=0.736, g_loss=2.029
# epoch = 206/1000, d_loss=0.658, g_loss=1.869
# epoch = 207/1000, d_loss=1.042, g_loss=1.442
# epoch = 208/1000, d_loss=0.676, g_loss=1.900
# epoch = 209/1000, d_loss=0.627, g_loss=2.130
# epoch = 210/1000, d_loss=0.918, g_loss=1.683
# epoch = 211/1000, d_loss=0.942, g_loss=1.950
# epoch = 212/1000, d_loss=1.015, g_loss=1.514
# epoch = 213/1000, d_loss=0.796, g_loss=1.705
# epoch = 214/1000, d_loss=0.672, g_loss=2.174
# epoch = 215/1000, d_loss=0.956, g_loss=1.781
# epoch = 216/1000, d_loss=0.669, g_loss=1.950
# epoch = 217/1000, d_loss=0.635, g_loss=2.039
# epoch = 218/1000, d_loss=0.808, g_loss=1.978
# epoch = 219/1000, d_loss=0.849, g_loss=1.896
# epoch = 220/1000, d_loss=0.947, g_loss=1.935
# epoch = 221/1000, d_loss=0.594, g_loss=1.924
# epoch = 222/1000, d_loss=0.631, g_loss=1.971
# epoch = 223/1000, d_loss=0.937, g_loss=1.600
# epoch = 224/1000, d_loss=0.624, g_loss=1.885
# epoch = 225/1000, d_loss=0.937, g_loss=1.646
# epoch = 226/1000, d_loss=1.154, g_loss=1.333
# epoch = 227/1000, d_loss=0.752, g_loss=1.723
# epoch = 228/1000, d_loss=0.701, g_loss=1.773
# epoch = 229/1000, d_loss=0.565, g_loss=2.000
# epoch = 230/1000, d_loss=0.898, g_loss=1.793
# epoch = 231/1000, d_loss=0.948, g_loss=1.695
# epoch = 232/1000, d_loss=0.619, g_loss=2.059
# epoch = 233/1000, d_loss=1.014, g_loss=1.586
# epoch = 234/1000, d_loss=0.746, g_loss=1.947
# epoch = 235/1000, d_loss=0.619, g_loss=1.865
# epoch = 236/1000, d_loss=0.718, g_loss=1.635
# epoch = 237/1000, d_loss=0.966, g_loss=1.445
# epoch = 238/1000, d_loss=0.618, g_loss=1.875
# epoch = 239/1000, d_loss=0.783, g_loss=1.844
# epoch = 240/1000, d_loss=0.907, g_loss=1.742
# epoch = 241/1000, d_loss=0.855, g_loss=1.659
# epoch = 242/1000, d_loss=0.927, g_loss=1.601
# epoch = 243/1000, d_loss=0.639, g_loss=2.017
# epoch = 244/1000, d_loss=0.818, g_loss=2.316
# epoch = 245/1000, d_loss=0.626, g_loss=2.223
# epoch = 246/1000, d_loss=0.697, g_loss=1.882
# epoch = 247/1000, d_loss=0.672, g_loss=2.093
# epoch = 248/1000, d_loss=0.782, g_loss=1.884
# epoch = 249/1000, d_loss=0.756, g_loss=1.765
# epoch = 250/1000, d_loss=0.626, g_loss=1.868
# epoch = 251/1000, d_loss=0.780, g_loss=1.999
# epoch = 252/1000, d_loss=0.747, g_loss=2.117
# epoch = 253/1000, d_loss=0.862, g_loss=1.366
# epoch = 254/1000, d_loss=0.667, g_loss=2.116
# epoch = 255/1000, d_loss=0.693, g_loss=2.140
# epoch = 256/1000, d_loss=0.882, g_loss=1.689
# epoch = 257/1000, d_loss=0.628, g_loss=2.451
# epoch = 258/1000, d_loss=0.800, g_loss=1.807
# epoch = 259/1000, d_loss=0.794, g_loss=2.016
# epoch = 260/1000, d_loss=0.681, g_loss=1.977
# epoch = 261/1000, d_loss=0.763, g_loss=1.723
# epoch = 262/1000, d_loss=0.774, g_loss=2.574
# epoch = 263/1000, d_loss=0.653, g_loss=2.072
# epoch = 264/1000, d_loss=0.583, g_loss=1.569
# epoch = 265/1000, d_loss=1.088, g_loss=2.166
# epoch = 266/1000, d_loss=0.690, g_loss=2.320
# epoch = 267/1000, d_loss=0.682, g_loss=2.321
# epoch = 268/1000, d_loss=0.743, g_loss=2.041
# epoch = 269/1000, d_loss=0.756, g_loss=2.263
# epoch = 270/1000, d_loss=0.717, g_loss=2.360
# epoch = 271/1000, d_loss=0.859, g_loss=1.766
# epoch = 272/1000, d_loss=0.502, g_loss=2.478
# epoch = 273/1000, d_loss=0.763, g_loss=2.195
# epoch = 274/1000, d_loss=0.670, g_loss=2.457
# epoch = 275/1000, d_loss=0.839, g_loss=2.122
# epoch = 276/1000, d_loss=0.515, g_loss=2.252
# epoch = 277/1000, d_loss=0.864, g_loss=1.628
# epoch = 278/1000, d_loss=0.754, g_loss=1.779
# epoch = 279/1000, d_loss=0.515, g_loss=2.256
# epoch = 280/1000, d_loss=0.581, g_loss=2.414
# epoch = 281/1000, d_loss=0.489, g_loss=2.560
# epoch = 282/1000, d_loss=1.037, g_loss=2.432
# epoch = 283/1000, d_loss=0.561, g_loss=2.258
# epoch = 284/1000, d_loss=0.610, g_loss=2.370
# epoch = 285/1000, d_loss=0.786, g_loss=2.377
# epoch = 286/1000, d_loss=0.531, g_loss=1.997
# epoch = 287/1000, d_loss=0.580, g_loss=2.843
# epoch = 288/1000, d_loss=0.564, g_loss=2.237
# epoch = 289/1000, d_loss=0.457, g_loss=2.517
# epoch = 290/1000, d_loss=0.626, g_loss=2.356
# epoch = 291/1000, d_loss=0.639, g_loss=1.779
# epoch = 292/1000, d_loss=0.621, g_loss=2.442
# epoch = 293/1000, d_loss=0.765, g_loss=2.448
# epoch = 294/1000, d_loss=0.549, g_loss=2.533
# epoch = 295/1000, d_loss=0.453, g_loss=2.630
# epoch = 296/1000, d_loss=0.828, g_loss=2.582
# epoch = 297/1000, d_loss=0.659, g_loss=2.289
# epoch = 298/1000, d_loss=0.538, g_loss=2.236
# epoch = 299/1000, d_loss=0.490, g_loss=2.818
# epoch = 300/1000, d_loss=0.592, g_loss=3.146
# epoch = 301/1000, d_loss=0.821, g_loss=2.162
# epoch = 302/1000, d_loss=0.653, g_loss=2.181
# epoch = 303/1000, d_loss=0.590, g_loss=2.307
# epoch = 304/1000, d_loss=0.891, g_loss=2.493
# epoch = 305/1000, d_loss=0.467, g_loss=2.455
# epoch = 306/1000, d_loss=0.593, g_loss=2.500
# epoch = 307/1000, d_loss=0.528, g_loss=2.666
# epoch = 308/1000, d_loss=0.688, g_loss=2.215
# epoch = 309/1000, d_loss=0.501, g_loss=2.460
# epoch = 310/1000, d_loss=0.479, g_loss=2.758
# epoch = 311/1000, d_loss=0.506, g_loss=2.466
# epoch = 312/1000, d_loss=0.815, g_loss=2.207
# epoch = 313/1000, d_loss=0.537, g_loss=2.919
# epoch = 314/1000, d_loss=0.563, g_loss=2.769
# epoch = 315/1000, d_loss=0.644, g_loss=1.961
# epoch = 316/1000, d_loss=0.619, g_loss=2.892
# epoch = 317/1000, d_loss=0.533, g_loss=2.512
# epoch = 318/1000, d_loss=0.911, g_loss=3.242
# epoch = 319/1000, d_loss=0.553, g_loss=2.680
# epoch = 320/1000, d_loss=0.536, g_loss=2.430
# epoch = 321/1000, d_loss=0.681, g_loss=2.161
# epoch = 322/1000, d_loss=0.519, g_loss=2.548
# epoch = 323/1000, d_loss=0.619, g_loss=2.954
# epoch = 324/1000, d_loss=0.486, g_loss=3.183
# epoch = 325/1000, d_loss=0.595, g_loss=3.053
# epoch = 326/1000, d_loss=0.548, g_loss=2.625
# epoch = 327/1000, d_loss=0.978, g_loss=2.211
# epoch = 328/1000, d_loss=0.471, g_loss=3.208
# epoch = 329/1000, d_loss=0.658, g_loss=2.397
# ...
# epoch = 892/1000, d_loss=0.384, g_loss=2.009
# epoch = 893/1000, d_loss=0.471, g_loss=2.259
# epoch = 894/1000, d_loss=0.419, g_loss=2.880
# epoch = 895/1000, d_loss=0.451, g_loss=2.966
# epoch = 896/1000, d_loss=0.401, g_loss=2.180
# epoch = 897/1000, d_loss=0.383, g_loss=1.898
# epoch = 898/1000, d_loss=0.407, g_loss=1.553
# epoch = 899/1000, d_loss=0.376, g_loss=2.074
# epoch = 900/1000, d_loss=0.370, g_loss=3.404
# epoch = 901/1000, d_loss=0.714, g_loss=2.010
# epoch = 902/1000, d_loss=0.484, g_loss=1.882
# epoch = 903/1000, d_loss=0.409, g_loss=3.303
# epoch = 904/1000, d_loss=0.757, g_loss=1.987
# epoch = 905/1000, d_loss=0.563, g_loss=3.083
# epoch = 906/1000, d_loss=0.422, g_loss=2.705
# epoch = 907/1000, d_loss=0.438, g_loss=1.829
# epoch = 908/1000, d_loss=0.459, g_loss=3.184
# epoch = 909/1000, d_loss=0.438, g_loss=2.538
# epoch = 910/1000, d_loss=0.370, g_loss=3.285
# epoch = 911/1000, d_loss=0.390, g_loss=2.563
# epoch = 912/1000, d_loss=0.399, g_loss=1.667
# epoch = 913/1000, d_loss=0.404, g_loss=2.625
# epoch = 914/1000, d_loss=0.375, g_loss=3.276
# epoch = 915/1000, d_loss=0.391, g_loss=3.626
# epoch = 916/1000, d_loss=0.375, g_loss=1.715
# epoch = 917/1000, d_loss=0.445, g_loss=3.261
# epoch = 918/1000, d_loss=0.393, g_loss=2.660
# epoch = 919/1000, d_loss=0.499, g_loss=2.383
# epoch = 920/1000, d_loss=0.468, g_loss=2.275
# epoch = 921/1000, d_loss=0.409, g_loss=2.552
# epoch = 922/1000, d_loss=0.403, g_loss=3.042
# epoch = 923/1000, d_loss=0.690, g_loss=1.259
# epoch = 924/1000, d_loss=0.664, g_loss=2.555
# epoch = 925/1000, d_loss=0.384, g_loss=3.397
# epoch = 926/1000, d_loss=0.435, g_loss=1.939
# epoch = 927/1000, d_loss=0.378, g_loss=2.335
# epoch = 928/1000, d_loss=0.417, g_loss=2.607
# epoch = 929/1000, d_loss=0.590, g_loss=2.027
# epoch = 930/1000, d_loss=0.387, g_loss=3.887
# epoch = 931/1000, d_loss=0.389, g_loss=2.089
# epoch = 932/1000, d_loss=0.374, g_loss=2.653
# epoch = 933/1000, d_loss=0.405, g_loss=2.947
# epoch = 934/1000, d_loss=0.391, g_loss=3.421
# epoch = 935/1000, d_loss=0.457, g_loss=4.008
# epoch = 936/1000, d_loss=0.390, g_loss=3.143
# epoch = 937/1000, d_loss=0.533, g_loss=2.644
# epoch = 938/1000, d_loss=0.397, g_loss=2.835
# epoch = 939/1000, d_loss=0.350, g_loss=1.753
# epoch = 940/1000, d_loss=0.352, g_loss=3.303
# epoch = 941/1000, d_loss=0.488, g_loss=2.823
# epoch = 942/1000, d_loss=0.385, g_loss=3.661
# epoch = 943/1000, d_loss=0.402, g_loss=2.863
# epoch = 944/1000, d_loss=0.461, g_loss=2.738
# epoch = 945/1000, d_loss=0.370, g_loss=3.456
# epoch = 946/1000, d_loss=0.644, g_loss=2.394
# epoch = 947/1000, d_loss=0.556, g_loss=1.955
# epoch = 948/1000, d_loss=0.538, g_loss=3.958
# epoch = 949/1000, d_loss=0.524, g_loss=1.717
# epoch = 950/1000, d_loss=0.530, g_loss=3.200
# epoch = 951/1000, d_loss=0.406, g_loss=3.330
# epoch = 952/1000, d_loss=0.399, g_loss=2.898
# epoch = 953/1000, d_loss=0.375, g_loss=2.999
# epoch = 954/1000, d_loss=0.384, g_loss=3.153
# epoch = 955/1000, d_loss=0.420, g_loss=3.192
# epoch = 956/1000, d_loss=0.428, g_loss=4.147
# epoch = 957/1000, d_loss=0.404, g_loss=3.465
# epoch = 958/1000, d_loss=0.377, g_loss=3.062
# epoch = 959/1000, d_loss=0.353, g_loss=2.693
# epoch = 960/1000, d_loss=0.402, g_loss=3.027
# epoch = 961/1000, d_loss=0.388, g_loss=3.995
# epoch = 962/1000, d_loss=0.391, g_loss=2.496
# epoch = 963/1000, d_loss=0.422, g_loss=4.959
# epoch = 964/1000, d_loss=0.459, g_loss=3.531
# epoch = 965/1000, d_loss=0.400, g_loss=2.827
# epoch = 966/1000, d_loss=0.412, g_loss=2.600
# epoch = 967/1000, d_loss=0.363, g_loss=3.272
# epoch = 968/1000, d_loss=0.422, g_loss=2.873
# epoch = 969/1000, d_loss=0.397, g_loss=2.865
# epoch = 970/1000, d_loss=0.367, g_loss=2.565
# epoch = 971/1000, d_loss=0.381, g_loss=4.175
# epoch = 972/1000, d_loss=0.377, g_loss=3.083
# epoch = 973/1000, d_loss=0.496, g_loss=2.280
# epoch = 974/1000, d_loss=0.373, g_loss=4.457
# epoch = 975/1000, d_loss=0.380, g_loss=2.548
# epoch = 976/1000, d_loss=0.482, g_loss=2.760
# epoch = 977/1000, d_loss=0.424, g_loss=2.862
# epoch = 978/1000, d_loss=0.417, g_loss=1.502
# epoch = 979/1000, d_loss=0.367, g_loss=2.311
# epoch = 980/1000, d_loss=0.372, g_loss=2.598
# epoch = 981/1000, d_loss=0.391, g_loss=3.509
# epoch = 982/1000, d_loss=0.364, g_loss=2.964
# epoch = 983/1000, d_loss=0.408, g_loss=2.868
# epoch = 984/1000, d_loss=0.413, g_loss=3.938
# epoch = 985/1000, d_loss=0.368, g_loss=3.486
# epoch = 986/1000, d_loss=0.353, g_loss=2.804
# epoch = 987/1000, d_loss=0.357, g_loss=3.983
# epoch = 988/1000, d_loss=0.415, g_loss=2.938
# epoch = 989/1000, d_loss=0.446, g_loss=2.224
# epoch = 990/1000, d_loss=0.416, g_loss=1.813
# epoch = 991/1000, d_loss=0.375, g_loss=2.402
# epoch = 992/1000, d_loss=0.377, g_loss=3.589
# epoch = 993/1000, d_loss=0.367, g_loss=2.589
# epoch = 994/1000, d_loss=0.471, g_loss=2.109
# epoch = 995/1000, d_loss=0.374, g_loss=2.556
# epoch = 996/1000, d_loss=0.388, g_loss=3.773
# epoch = 997/1000, d_loss=0.639, g_loss=1.885
# epoch = 998/1000, d_loss=0.501, g_loss=3.196
# epoch = 999/1000, d_loss=0.730, g_loss=1.942
# epoch = 1000/1000, d_loss=0.397, g_loss=2.514
# epoch = 1001/1000, d_loss=0.351, g_loss=2.620
