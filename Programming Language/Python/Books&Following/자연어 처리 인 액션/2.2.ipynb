# %%
sentence = """Thomas Jefferson began building Monticello at the age of 26."""

sentence.split()
# Out:
# ['Thomas',
#  'Jefferson',
#  'began',
#  'building',
#  'Monticello',
#  'at',
#  'the',
#  'age',
#  'of',
#  '26.']

# %%
str.split(sentence)
# Out:
# ['Thomas',
#  'Jefferson',
#  'began',
#  'building',
#  'Monticello',
#  'at',
#  'the',
#  'age',
#  'of',
#  '26.']
