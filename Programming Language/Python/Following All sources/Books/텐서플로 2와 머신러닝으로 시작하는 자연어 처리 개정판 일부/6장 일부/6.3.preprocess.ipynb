# %%
from preprocess import *

# %%
PATH = 'data_in/ChatBotData.csv'
VOCAB_PATH = 'data_in/vocabulary.txt'

# %%
inputs, outputs = load_data(PATH)

# %%
char2idx, idx2char, vocab_size = load_vocabulary(PATH, VOCAB_PATH, tokenize_as_morph=True)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 11823/11823 [00:16<00:00, 723.91it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 11823/11823 [00:18<00:00, 649.41it/s]

# %%
index_inputs, input_seq_len = enc_processing(inputs, char2idx, tokenize_as_morph=True)
index_outputs, output_seq_len = dec_output_processing(outputs, char2idx, tokenize_as_morph=True)
index_targets = dec_target_processing(outputs, char2idx, tokenize_as_morph=True)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 11823/11823 [00:13<00:00, 856.89it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 11823/11823 [00:21<00:00, 560.34it/s]
# 100%|███████████████████████████████████████████████████████████████████████████| 11823/11823 [00:21<00:00, 560.78it/s]

# %%
data_configs = {}
data_configs['char2idx'] = char2idx
data_configs['idx2char'] = idx2char
data_configs['vocab_size'] = vocab_size
data_configs['pad_symbol'] = PAD
data_configs['std_symbol'] = STD
data_configs['end_symbol'] = END
data_configs['unk_symbol'] = UNK

# %%
DATA_IN_PATH = './data_in/'
TRAIN_INPUTS = 'train_inputs.npy'
TRAIN_OUTPUTS = 'train_outputs.npy'
TRAIN_TARGETS = 'train_targets.npy'
DATA_CONFIGS = 'data_configs.json'

np.save(open(DATA_IN_PATH + TRAIN_INPUTS, 'wb'), index_inputs)
np.save(open(DATA_IN_PATH + TRAIN_OUTPUTS , 'wb'), index_outputs)
np.save(open(DATA_IN_PATH + TRAIN_TARGETS , 'wb'), index_targets)

json.dump(data_configs, open(DATA_IN_PATH + DATA_CONFIGS, 'w'))

# %%
char2idx
# Out:
# {'<PAD>': 0,
#  '<SOS>': 1,
#  '<END>': 2,
#  '<UNK>': 3,
#  '먹을거하나도': 4,
#  '잠이안와': 5,
#  '보셨어': 6,
#  '먹은대로': 7,
#  '든거': 8,
#  '미안': 9,
#  '동굴': 10,
#  '올텐데': 11,
#  '캬': 12,
#  '또뭘': 13,
#  '탁했는데': 14,
#  '띄웠었다네': 15,
#  '심심한데': 16,
#  '바람기': 17,
#  '잊은것': 18,
#  '할수있어': 19,
#  '다가가는거죠': 20,
#  '주고받고': 21,
#  '위': 22,
#  '장이': 23,
#  '이자': 24,
#  '내려놓기로': 25,
#  '월욜': 26,
#  '폭': 27,
#  '자장면': 28,
#  '디딜': 29,
#  '없다면': 30,
#  '나갑니다': 31,
#  '같지가': 32,
#  '멋진데': 33,
#  '중요한지': 34,
#  '임': 35,
#  '미리': 36,
#  '남이있는데': 37,
#  '쓰니까': 38,
#  '가수': 39,
#  '행복해요': 40,
#  '장난스러운': 41,
#  '필요한거예요': 42,
#  '사귀긴': 43,
#  '냥': 44,
#  '있죠': 45,
#  '몰라요': 46,
#  '힘들어하지': 47,
#  '고충': 48,
#  '쓰디': 49,
#  '결혼': 50,
#  '치매': 51,
#  '진한': 52,
#  '끼부리는': 53,
#  '방식': 54,
#  '떠보는것': 55,
#  '디': 56,
#  '마실수있어요': 57,
#  '헤어진': 58,
#  '운': 59,
#  '꾸준히하세요': 60,
#  '조급해져': 61,
#  '불공평': 62,
#  '활력소': 63,
#  '배려있는': 64,
#  '용서': 65,
#  '잡히네': 66,
#  '고통': 67,
#  '할수있어요': 68,
#  '기르고싶어': 69,
#  '하는것': 70,
#  '보자고말': 71,
#  '됐으면': 72,
#  '장통': 73,
#  '밑거름': 74,
#  '맛있다': 75,
#  '태어났어요': 76,
#  '와서': 77,
#  '시선': 78,
#  '가고있어': 79,
#  '식상하지': 80,
#  '약하게': 81,
#  '잘살아요': 82,
#  '원하던': 83,
#  '까먹고안': 84,
#  '만나러가': 85,
#  '속상하니': 86,
#  '간접흡연': 87,
#  '해달라는': 88,
#  '의빈': 89,
#  '흘러가니까': 90,
#  '관심': 91,
#  '힘들었거나': 92,
#  '맞춰가기': 93,
#  '내남자': 94,
#  '어딘가': 95,
#  '지나갈거예요': 96,
#  '살찐거': 97,
#  '소개팅': 98,
#  '가능함': 99,
#  '가세': 100,
#  '그남자': 101,
#  '동물원': 102,
#  '맞았네': 103,
#  '선보라고': 104,
#  '여자': 105,
#  '넘나리': 106,
#  '휴학': 107,
#  '걸까봐': 108,
#  '괜찮은': 109,
#  '할거': 110,
#  '자금': 111,
#  '오르지는': 112,
#  '나날': 113,
#  '하고말하는': 114,
#  '길었나': 115,
#  '꿰메': 116,
#  '분들': 117,
#  '찾았으면': 118,
#  '친추': 119,
#  '숨막히고': 120,
#  '하다니': 121,
#  '익숙해지기': 122,
#  '부안': 123,
#  '나누구게': 124,
#  '니야': 125,
#  '왔습니다': 126,
#  '시원해요': 127,
#  '알아볼': 128,
#  '잘아시네요': 129,
#  '끓여': 130,
#  '구경': 131,
#  '달려있겠죠': 132,
#  '정해져있을지도': 133,
#  '고모': 134,
#  '가능할거': 135,
#  '넘': 136,
#  '화려하지': 137,
#  '없는것': 138,
#  '힘들기만': 139,
#  '심하죠': 140,
#  '군대': 141,
#  '잊는데는': 142,
#  '저물어가네': 143,
#  '사귄': 144,
#  '어리석게': 145,
#  '담긴': 146,
#  '많겠지만': 147,
#  '오랫동안': 148,
#  '찾아봐요': 149,
#  '질긴': 150,
#  '기울이고': 151,
#  '또폭': 152,
#  '하고만': 153,
#  '곤': 154,
#  '월지': 155,
#  '널': 156,
#  '떠오른다': 157,
#  '친구': 158,
#  '못': 159,
#  '친구사이': 160,
#  '공': 161,
#  '할줄도': 162,
#  '일이이': 163,
#  '오름': 164,
#  '씹어': 165,
#  '같네하하': 166,
#  '하얘졌어': 167,
#  '연휴': 168,
#  '도술': 169,
#  '다행': 170,
#  '찼어': 171,
#  '피곤하신': 172,
#  '설명': 173,
#  '자세': 174,
#  '들어간다고': 175,
#  '아련해': 176,
#  '않았나': 177,
#  '뜨끈한': 178,
#  '타는줄': 179,
#  '장해': 180,
#  '안되나': 181,
#  '비싼게': 182,
#  '사귀다가헤어젔는데': 183,
#  '살고싶어': 184,
#  '선연하더라고요': 185,
#  '씨앗': 186,
#  '맞는것과': 187,
#  '돕는': 188,
#  '그렇다는': 189,
#  '알았지': 190,
#  '하고의': 191,
#  '지우려': 192,
#  '팔로우': 193,
#  '밤': 194,
#  '이룰수있을거예요': 195,
#  '희망고문': 196,
#  '공감': 197,
#  '되겠네요': 198,
#  '있대': 199,
#  '만나러가세요': 200,
#  '괜': 201,
#  '자책': 202,
#  '피해': 203,
#  '누락': 204,
#  '자장가': 205,
#  '모르겠습니다': 206,
#  'O': 207,
#  '힘빠지는': 208,
#  '비판': 209,
#  '지겨워': 210,
#  '사귀려고': 211,
#  '코스터': 212,
#  '친해질까': 213,
#  '촉': 214,
#  '싱숭생숭해서': 215,
#  '집아': 216,
#  '이브': 217,
#  '했네': 218,
#  '애': 219,
#  '설레면': 220,
#  '좋아하지': 221,
#  '광탈': 222,
#  '바꿀수있을텐데': 223,
#  '봤는데말': 224,
#  '키우고싶어': 225,
#  '않는데이거': 226,
#  '망함': 227,
#  '되는지': 228,
#  '내든': 229,
#  '마셨나': 230,
#  '봤네요': 231,
#  '놀랐겠네요': 232,
#  '직원': 233,
#  '멀어진다는데': 234,
#  '남이같이': 235,
#  '그렇': 236,
#  '보내고오세요': 237,
#  '죽진못하겠구': 238,
#  '했을까요': 239,
#  '떠져': 240,
#  '문고': 241,
#  '해주었다는': 242,
#  '오해': 243,
#  '좋았길': 244,
#  '있었지하고': 245,
#  '않으니': 246,
#  '괜찮아졌다가': 247,
#  '그립겠지만': 248,
#  '그만두는': 249,
#  '해볼까': 250,
#  '알거': 251,
#  '선택': 252,
#  '춤': 253,
#  '해줄수있어': 254,
#  '내려는거라면': 255,
#  '자식': 256,
#  '목탄': 257,
#  '독': 258,
#  '세': 259,
#  '특종': 260,
#  '그럼에도': 261,
#  '가지고있네요': 262,
#  '알수있나': 263,
#  '했더니': 264,
#  '듣고싶다': 265,
#  '아파서': 266,
#  '변덕쟁이': 267,
#  '때해선': 268,
#  '두었을까': 269,
#  '숫자': 270,
#  '유지': 271,
#  '갈수있을까': 272,
#  '나옵니다': 273,
#  '꾸네': 274,
#  '칠': 275,
#  '가오': 276,
#  '챙겨줄까': 277,
#  '배워놓는게': 278,
#  '했다는': 279,
#  '털털': 280,
#  '하러가고싶다': 281,
#  '잘살': 282,
#  '지내자': 283,
#  '원망': 284,
#  '주아니': 285,
#  '울고싶을': 286,
#  '세심': 287,
#  '먹으라고': 288,
#  '떠보는걸': 289,
#  '따야': 290,
#  '미친거': 291,
#  '빼도': 292,
#  '만나도': 293,
#  '좀쉬': 294,
#  '많': 295,
#  '카톡대화': 296,
#  '한때': 297,
#  '될지': 298,
#  '끊기는거': 299,
#  '연하': 300,
#  '봐주세요': 301,
#  '아깝다는': 302,
#  '가내': 303,
#  '싶다면': 304,
#  '받으면': 305,
#  '축복': 306,
#  '바쁜게': 307,
#  '타세요': 308,
#  '따뜻해졌죠': 309,
#  '열': 310,
#  '공허함': 311,
#  '생길까': 312,
#  '담해줄래': 313,
#  '정신차리세요': 314,
#  'ㅎㅎ': 315,
#  '땐': 316,
#  '좀넘은저의사랑그리고이별이야기': 317,
#  '톡': 318,
#  '채널': 319,
#  '덜어': 320,
#  '다른거니': 321,
#  '무너짐': 322,
#  '제해': 323,
#  '어린': 324,
#  '1000일': 325,
#  '쓰던': 326,
#  '만났든': 327,
#  '잊지말자': 328,
#  '왕만': 329,
#  '설사': 330,
#  '더주세요': 331,
#  '콘서트': 332,
#  '번하니': 333,
#  '걸이': 334,
#  '먹을수록': 335,
#  '왔나요': 336,
#  '의욕': 337,
#  '풀릴거예요': 338,
#  '흘려': 339,
#  '편하고': 340,
#  '기를하죠': 341,
#  '중요한가': 342,
#  '다른사람': 343,
#  '상책': 344,
#  '낮추는': 345,
#  '연금': 346,
#  '두려운데': 347,
#  '잠을잘': 348,
#  '결혼합시다': 349,
#  '공시생': 350,
#  '놀램': 351,
#  '그만하는게': 352,
#  '감수': 353,
#  '추운': 354,
#  '쉽': 355,
#  '다치지': 356,
#  '잃을거예요': 357,
#  '왜현': 358,
#  '갈': 359,
#  '맞겠지': 360,
#  '먹으면나에게도': 361,
#  '뜬눈': 362,
#  '본': 363,
#  '타는거야': 364,
#  '헤아리지말아요': 365,
#  '열어': 366,
#  '먹고자야지': 367,
#  '허전할거': 368,
#  '서노래': 369,
#  '낀듯': 370,
#  '남기기': 371,
#  '살줄': 372,
#  '올리내': 373,
#  '장갑': 374,
#  '허락': 375,
#  '시보': 376,
#  '정신병': 377,
#  '왤': 378,
#  '팁좀': 379,
#  '회원': 380,
#  '생겼으면': 381,
#  '부서진': 382,
#  '그랬던거죠': 383,
#  '애석하지만': 384,
#  '솔직하게말': 385,
#  '될지도': 386,
#  '좋을듯': 387,
#  '무심한데': 388,
#  '분히이해': 389,
#  '한약': 390,
#  '있지만': 391,
#  '그럴까': 392,
#  '가리는': 393,
#  '차가고': 394,
#  '익숙함이라는': 395,
#  '맘추': 396,
#  '쪼': 397,
#  '두지말아요': 398,
#  '여행지': 399,
#  '불날': 400,
#  '청해': 401,
#  '썸탈때': 402,
#  '했을지도': 403,
#  '키왜안': 404,
#  '힘들긴': 405,
#  '순수한': 406,
#  '바라겠습니다': 407,
#  '빠져나오세요': 408,
#  '나오기': 409,
#  '오세요': 410,
#  '노력': 411,
#  '지내니': 412,
#  '나아가야지': 413,
#  '따라오게': 414,
#  '도문': 415,
#  '날림': 416,
#  '까먹어': 417,
#  '바뀌어': 418,
#  '좋아하는데': 419,
#  '보려고': 420,
#  '이러지말자': 421,
#  '페메': 422,
#  '진부한말': 423,
#  '듣고싶어요': 424,
#  '세워': 425,
#  '있는': 426,
#  '걸게하고': 427,
#  '버려야지': 428,
#  '관계': 429,
#  '하면나를': 430,
#  '당연한거예요': 431,
#  '잠자리': 432,
#  '아무렇게나': 433,
#  '미워지네': 434,
#  '가두': 435,
#  '하시겠어요': 436,
#  '썸을길': 437,
#  '계속': 438,
#  '까먹지말고': 439,
#  '볼텐데': 440,
#  '곡': 441,
#  '좋아하는이': 442,
#  '많을까요': 443,
#  '나라고': 444,
#  '듣는데': 445,
#  '시키는거': 446,
#  '만날거예요': 447,
#  '변해가요': 448,
#  '싸우게': 449,
#  '갖자하면': 450,
#  '나가기도': 451,
#  '될수': 452,
#  '마셔요': 453,
#  '보고왔다': 454,
#  '자다가도': 455,
#  '보내려': 456,
#  '온': 457,
#  '불행': 458,
#  '난정': 459,
#  '온종일': 460,
#  '어울렸던': 461,
#  '방가': 462,
#  '글쎄요': 463,
#  '심각해요': 464,
#  '달랬더니': 465,
#  '발인': 466,
#  '뽑은': 467,
#  '같다고': 468,
#  '헹리': 469,
#  '생길것': 470,
#  '한일': 471,
#  '명도': 472,
#  '필통': 473,
#  '안되겠지만': 474,
#  '귀국': 475,
#  '안지워': 476,
#  '전술': 477,
#  '좋아질거예요': 478,
#  '수수한': 479,
#  '작아져': 480,
#  '지나가겠죠': 481,
#  '버리세요': 482,
#  '자고있을지도': 483,
#  '돼서': 484,
#  '완전히': 485,
#  '잊을수가있을까': 486,
#  '못자고': 487,
#  '가능할까': 488,
#  '힐링': 489,
#  '찍어주세요': 490,
#  '이니까': 491,
#  '가죠': 492,
#  '부모님': 493,
#  '불공평한거': 494,
#  '모태솔로': 495,
#  '화보': 496,
#  '있는데내가': 497,
#  '미래': 498,
#  '추세더라구요': 499,
#  '야하는것도': 500,
#  '재채기': 501,
#  '홀': 502,
#  '쉬운가': 503,
#  '닮아서': 504,
#  '곧주말이': 505,
#  '죽고싶은': 506,
#  '봄날': 507,
#  '잊혀': 508,
#  '더울어도': 509,
#  '생겼는지도': 510,
#  '부족한가': 511,
#  '지만': 512,
#  '호칭': 513,
#  '이기': 514,
#  '나빴네': 515,
#  '받아줘': 516,
#  '헤어질거면': 517,
#  '소중하던': 518,
#  '날짜': 519,
#  '이제마': 520,
#  '큰': 521,
#  '걸거': 522,
#  '취': 523,
#  '받아들이는것인가': 524,
#  '차있더라': 525,
#  '미남': 526,
#  '난다면': 527,
#  '들이었죠': 528,
#  '될듯': 529,
#  '행복해야': 530,
#  '참답': 531,
#  '리다': 532,
#  '나아질거야': 533,
#  '달라질까': 534,
#  '먹었다': 535,
#  '깐깐해': 536,
#  '교복': 537,
#  '좋으면서도': 538,
#  '남전': 539,
#  '싸웠어': 540,
#  '위병': 541,
#  '이라고는': 542,
#  '모르고있을수도': 543,
#  '놓친': 544,
#  '좋아졌어': 545,
#  '다크서클': 546,
#  '날카로워진다': 547,
#  '아름다운': 548,
#  '나갔어': 549,
#  '기를까': 550,
#  '바랐지만': 551,
#  '의기나긴이야기': 552,
#  '절대로': 553,
#  '40일': 554,
#  '이되었나봐요': 555,
#  '마디네': 556,
#  '결별': 557,
#  '똑같아': 558,
#  '재밌을거예요': 559,
#  '기만': 560,
#  '자기': 561,
#  '꿀수있다면': 562,
#  '힘들어하지말아요': 563,
#  '예매': 564,
#  '보고': 565,
#  '있었는데': 566,
#  '설레': 567,
#  '직감': 568,
#  '들어줄': 569,
#  '헤어진여': 570,
#  '말못하는': 571,
#  '하는사': 572,
#  '잠기는게': 573,
#  '헤어졌으니': 574,
#  '발렌타인데이': 575,
#  '편하겠지': 576,
#  '쉬고싶어': 577,
#  '문득': 578,
#  '크리': 579,
#  '떠가기전하는': 580,
#  '그만둔': 581,
#  '지독한': 582,
#  '괜찮아지려나': 583,
#  '지을수': 584,
#  '끓여서': 585,
#  '받고있다고말': 586,
#  '맞아요': 587,
#  '실험실': 588,
#  '행복하게도': 589,
#  '흔들리나요': 590,
#  '이미': 591,
#  '알았어요': 592,
#  '겁': 593,
#  '쉬고있어': 594,
#  '배우는거야': 595,
#  '바라는것도': 596,
#  '쪽지': 597,
#  '까먹겠죠': 598,
#  '조': 599,
#  '크시': 600,
#  '내게': 601,
#  '싫어하지': 602,
#  '질테': 603,
#  '옆': 604,
#  '공채': 605,
#  '충실하면': 606,
#  '어울림': 607,
#  '뽀송뽀송': 608,
#  '불쑥': 609,
#  '만나는': 610,
#  '나폰겜': 611,
#  '슬픈말이네요': 612,
#  '꾼건': 613,
#  '이해해': 614,
#  '만들더라고요': 615,
#  '간만': 616,
#  '낸다': 617,
#  '돌봐줘': 618,
#  '다가오지마': 619,
#  '수족': 620,
#  '사귀고있지': 621,
#  '없겠네요': 622,
#  '이어나가는게': 623,
#  '데이': 624,
#  '아무리': 625,
#  '실': 626,
#  '헤어져야': 627,
#  '이럴': 628,
#  '마안': 629,
#  '마트': 630,
#  '나온거': 631,
#  '상관없지만': 632,
#  '찾았습니다': 633,
#  '철': 634,
#  '괴롭네': 635,
#  '김치': 636,
#  '나가야하는데': 637,
#  '짜증난다': 638,
#  '매달렸나': 639,
#  '고백': 640,
#  '라는': 641,
#  '게맘': 642,
#  '다녀': 643,
#  '타냐고': 644,
#  '자취': 645,
#  '돌아가고': 646,
#  '목숨': 647,
#  '알아차렸을수도': 648,
#  '지냈나요': 649,
#  '평온': 650,
#  '붙잡고싶다면': 651,
#  '중고': 652,
#  '때매': 653,
#  '따지고싶은데': 654,
#  '할수록': 655,
#  '주인': 656,
#  '안된다고': 657,
#  '넓고': 658,
#  '틀': 659,
#  '편해도되': 660,
#  '성숙해지는': 661,
#  '놀자': 662,
#  '해내고있어요': 663,
#  '부도': 664,
#  '기운내는것을': 665,
#  '하고있어': 666,
#  '벌떡': 667,
#  '사해': 668,
#  '궁금하니까': 669,
#  '다퉜어': 670,
#  '말놓으려': 671,
#  '꺼내고싶은데': 672,
#  '온통': 673,
#  '익숙해지는': 674,
#  '에놀': 675,
#  '중소기업': 676,
#  '가습기': 677,
#  '받지': 678,
#  '소나기': 679,
#  '힘든데도': 680,
#  '첫날': 681,
#  '만나고싶어': 682,
#  '풀었네요': 683,
#  '가량': 684,
#  '살아가고': 685,
#  '열쇠': 686,
#  '빨렸': 687,
#  '않는것이겠죠': 688,
#  '지나가지말지': 689,
#  '소심': 690,
#  '하고픈말다': 691,
#  '두지': 692,
#  '말려': 693,
#  '만나고와': 694,
#  '헤어졌데': 695,
#  '지내고': 696,
#  '띄는': 697,
#  '세탁기': 698,
#  '요리': 699,
#  '마법': 700,
#  '부러우면': 701,
#  '눈물났어': 702,
#  '멋있게': 703,
#  '타지말아야지': 704,
#  '씻기': 705,
#  '부는아니에요': 706,
#  '없을수있어요': 707,
#  '좋아하는줄': 708,
#  '위험해': 709,
#  '잠을자': 710,
#  '호랑이': 711,
#  '담을수': 712,
#  '고칠수있을거예요': 713,
#  '안되겠지': 714,
#  '않은듯': 715,
#  '나눠': 716,
#  '알겠어서': 717,
#  '설레요': 718,
#  '이천원': 719,
#  '자꾸나': 720,
#  '모아니': 721,
#  '한테': 722,
#  '덜해지는것': 723,
#  '편해': 724,
#  '이란시간을정리했습니다': 725,
#  '접어': 726,
#  '치료받아야하나': 727,
#  '움직이세요': 728,
#  '중요하니까': 729,
#  '갚냐': 730,
#  '누굴까': 731,
#  '버려줘서': 732,
#  '우울할': 733,
#  '카페': 734,
#  '근데': 735,
#  '큰게': 736,
#  '힘드시겠네요': 737,
#  '찬물': 738,
#  '볼것': 739,
#  '물못': 740,
#  '면알': 741,
#  '사랑받는걸': 742,
#  '안될것도': 743,
#  '찾아왔네': 744,
#  '게이': 745,
#  '타고있는데': 746,
#  '식상한말이라도': 747,
#  '너그러웠으면': 748,
#  '전세': 749,
#  '쓰': 750,
#  '높나': 751,
#  '그래': 752,
#  '필요할수있어요': 753,
#  '당해': 754,
#  '살찔까봐': 755,
#  '드론': 756,
#  '준것보다': 757,
#  '있는주말': 758,
#  '같았는데': 759,
#  '내가다시': 760,
#  '종교의자유': 761,
#  '가자던': 762,
#  '예쁘': 763,
#  '맞는거': 764,
#  '썰러': 765,
#  '상속': 766,
#  '된여자친구랑이별': 767,
#  '일거야': 768,
#  '느낄지': 769,
#  '벌': 770,
#  '감당': 771,
#  '지우는것을': 772,
#  '뜨는거': 773,
#  '오랜': 774,
#  '덤덤': 775,
#  '변하네': 776,
#  '르름': 777,
#  '더안': 778,
#  '게다가': 779,
#  '뒀네요': 780,
#  '무궁무진': 781,
#  '째네': 782,
#  '가야겠네': 783,
#  '였길': 784,
#  '앞둔이': 785,
#  '돌리기': 786,
#  '지워지겠지': 787,
#  '톡안': 788,
#  '이었을까': 789,
#  '보내야지': 790,
#  '닫고': 791,
#  '헤어지자': 792,
#  '잡고싶은데': 793,
#  '인지': 794,
#  '이상정': 795,
#  '나오면': 796,
#  '하늘아래': 797,
#  '어울리는': 798,
#  '주기': 799,
#  '빠르면': 800,
#  '에걸쳐서정리를했습니다': 801,
#  '똑똑': 802,
#  '간질간질': 803,
#  '찜질방': 804,
#  '특판': 805,
#  '거너': 806,
#  '금수': 807,
#  '걸릴거': 808,
#  '아줌마': 809,
#  '시들으세요': 810,
#  '멋있을텐데': 811,
#  '냉증': 812,
#  '8': 813,
#  '젊게': 814,
#  '쉬어': 815,
#  '공통점': 816,
#  '복잡하겠네요': 817,
#  '많아지죠': 818,
#  '녹음': 819,
#  '탈것': 820,
#  '방심했어': 821,
#  '슬프게만': 822,
#  '였다': 823,
#  '은애': 824,
#  '척': 825,
#  '좋아하면다시': 826,
#  '전학': 827,
#  '동안난미친듯이살았다': 828,
#  '그러든지': 829,
#  '끌리': 830,
#  '공황장애': 831,
#  '월세': 832,
#  '지오': 833,
#  '사랑받는구나': 834,
#  '번안': 835,
#  '끊었었는데': 836,
#  '다녀야하나': 837,
#  '잊어야하는게': 838,
#  '해줄수있을까': 839,
#  '이욕': 840,
#  '쳐다봄': 841,
#  '보러가고싶다': 842,
#  '딸거야': 843,
#  '둘리': 844,
#  '비우세요': 845,
#  '치열한': 846,
#  '상메': 847,
#  '용기랍니다': 848,
#  '안녕': 849,
#  '알겠어': 850,
#  '허전하': 851,
#  '찾아가는건': 852,
#  '가라': 853,
#  '잠못': 854,
#  '그런거니': 855,
#  '선의': 856,
#  '위험한거': 857,
#  '만장': 858,
#  '남았어': 859,
#  '잡힐듯': 860,
#  '였으면': 861,
#  '내가아는': 862,
#  '더워': 863,
#  '변했다고': 864,
#  '수월해요': 865,
#  '내렸어': 866,
#  '그런말하더군': 867,
#  '졸린데': 868,
#  '전공': 869,
#  '걸음': 870,
#  '까': 871,
#  '식물': 872,
#  '차네': 873,
#  '붙잡고싶습니다': 874,
#  '비가오네': 875,
#  '보내는거': 876,
#  '사라지지': 877,
#  '터짐': 878,
#  '헷갈릴수있지요': 879,
#  '번호': 880,
#  '넣어': 881,
#  '않아요': 882,
#  '아깝다': 883,
#  '아자': 884,
#  '편하게못해': 885,
#  '감았는데': 886,
#  '살': 887,
#  '아기': 888,
#  '그런대로': 889,
#  '오늘날': 890,
#  '막고싶어': 891,
#  '좋아하는내가': 892,
#  '쓰는지': 893,
#  '비슷해': 894,
#  '아프겠지만': 895,
#  '기다려줄것': 896,
#  '괘씸하고': 897,
#  '질린다네': 898,
#  '오네': 899,
#  '있었겠어요': 900,
#  '남못': 901,
#  '하고내말은': 902,
#  '잊지': 903,
#  '로안': 904,
#  '꿰매': 905,
#  '뻔해': 906,
#  '만에': 907,
#  '자체': 908,
#  '마다의': 909,
#  '중요합니다': 910,
#  '대외': 911,
#  '우스워질': 912,
#  '효율': 913,
#  '됐어': 914,
#  '귀찮은': 915,
#  '필요하다면하는게': 916,
#  '차라': 917,
#  '여기있으니까': 918,
#  '소': 919,
#  '해서': 920,
#  '찾아갔는데': 921,
#  '였겠어요': 922,
#  '쓰이겠네요': 923,
#  '죠': 924,
#  '예쁘더라': 925,
#  '고막': 926,
#  '나가도': 927,
#  '않을거란': 928,
#  '행복했길': 929,
#  '대충': 930,
#  '그러면말하세요': 931,
#  '변해야': 932,
#  '씁니다': 933,
#  '싫다': 934,
#  '서울': 935,
#  '근': 936,
#  '털까': 937,
#  '무게': 938,
#  '해요': 939,
#  '느꼈을': 940,
#  '맞지': 941,
#  '많을까': 942,
#  '백수': 943,
#  '궁금한게': 944,
#  '잘해주는데': 945,
#  '좋아진것': 946,
#  '나가기가': 947,
#  '쎄': 948,
#  '식당': 949,
#  '싶은건': 950,
#  '알땐': 951,
#  '않은걸': 952,
#  '말하세요': 953,
#  '신호': 954,
#  '잠꾸러기': 955,
#  '해달라고기': 956,
#  '안됩니다': 957,
#  '닉': 958,
#  '들어왔나': 959,
#  '난또': 960,
#  '해안': 961,
#  '시려': 962,
#  '나도하고': 963,
#  '않되': 964,
#  '내려놓으면': 965,
#  '월간': 966,
#  '놀았는데다': 967,
#  '새장': 968,
#  '류': 969,
#  '드시고오셨길': 970,
#  '자랑': 971,
#  '보내야하는데': 972,
#  '제목': 973,
#  '은우': 974,
#  '질린듯': 975,
#  '먹는': 976,
#  '체력': 977,
#  '사귈래': 978,
#  '만나는데': 979,
#  '회원정보': 980,
#  '찍은': 981,
#  '사는거예요': 982,
#  '설레나': 983,
#  '주가': 984,
#  '남있는데': 985,
#  '사먹을까': 986,
#  '돌아오기': 987,
#  '자연스러워질': 988,
#  '가위': 989,
#  '개쫄음': 990,
#  '자르지말까': 991,
#  '보이스피싱': 992,
#  '많아서': 993,
#  '계륵': 994,
#  '아이고': 995,
#  '걸알': 996,
#  '어색할거': 997,
#  '멍충': 998,
#  '그만하고싶네': 999,
#  ...}

# %%
idx2char
# Out:
# {0: '<PAD>',
#  1: '<SOS>',
#  2: '<END>',
#  3: '<UNK>',
#  4: '먹을거하나도',
#  5: '잠이안와',
#  6: '보셨어',
#  7: '먹은대로',
#  8: '든거',
#  9: '미안',
#  10: '동굴',
#  11: '올텐데',
#  12: '캬',
#  13: '또뭘',
#  14: '탁했는데',
#  15: '띄웠었다네',
#  16: '심심한데',
#  17: '바람기',
#  18: '잊은것',
#  19: '할수있어',
#  20: '다가가는거죠',
#  21: '주고받고',
#  22: '위',
#  23: '장이',
#  24: '이자',
#  25: '내려놓기로',
#  26: '월욜',
#  27: '폭',
#  28: '자장면',
#  29: '디딜',
#  30: '없다면',
#  31: '나갑니다',
#  32: '같지가',
#  33: '멋진데',
#  34: '중요한지',
#  35: '임',
#  36: '미리',
#  37: '남이있는데',
#  38: '쓰니까',
#  39: '가수',
#  40: '행복해요',
#  41: '장난스러운',
#  42: '필요한거예요',
#  43: '사귀긴',
#  44: '냥',
#  45: '있죠',
#  46: '몰라요',
#  47: '힘들어하지',
#  48: '고충',
#  49: '쓰디',
#  50: '결혼',
#  51: '치매',
#  52: '진한',
#  53: '끼부리는',
#  54: '방식',
#  55: '떠보는것',
#  56: '디',
#  57: '마실수있어요',
#  58: '헤어진',
#  59: '운',
#  60: '꾸준히하세요',
#  61: '조급해져',
#  62: '불공평',
#  63: '활력소',
#  64: '배려있는',
#  65: '용서',
#  66: '잡히네',
#  67: '고통',
#  68: '할수있어요',
#  69: '기르고싶어',
#  70: '하는것',
#  71: '보자고말',
#  72: '됐으면',
#  73: '장통',
#  74: '밑거름',
#  75: '맛있다',
#  76: '태어났어요',
#  77: '와서',
#  78: '시선',
#  79: '가고있어',
#  80: '식상하지',
#  81: '약하게',
#  82: '잘살아요',
#  83: '원하던',
#  84: '까먹고안',
#  85: '만나러가',
#  86: '속상하니',
#  87: '간접흡연',
#  88: '해달라는',
#  89: '의빈',
#  90: '흘러가니까',
#  91: '관심',
#  92: '힘들었거나',
#  93: '맞춰가기',
#  94: '내남자',
#  95: '어딘가',
#  96: '지나갈거예요',
#  97: '살찐거',
#  98: '소개팅',
#  99: '가능함',
#  100: '가세',
#  101: '그남자',
#  102: '동물원',
#  103: '맞았네',
#  104: '선보라고',
#  105: '여자',
#  106: '넘나리',
#  107: '휴학',
#  108: '걸까봐',
#  109: '괜찮은',
#  110: '할거',
#  111: '자금',
#  112: '오르지는',
#  113: '나날',
#  114: '하고말하는',
#  115: '길었나',
#  116: '꿰메',
#  117: '분들',
#  118: '찾았으면',
#  119: '친추',
#  120: '숨막히고',
#  121: '하다니',
#  122: '익숙해지기',
#  123: '부안',
#  124: '나누구게',
#  125: '니야',
#  126: '왔습니다',
#  127: '시원해요',
#  128: '알아볼',
#  129: '잘아시네요',
#  130: '끓여',
#  131: '구경',
#  132: '달려있겠죠',
#  133: '정해져있을지도',
#  134: '고모',
#  135: '가능할거',
#  136: '넘',
#  137: '화려하지',
#  138: '없는것',
#  139: '힘들기만',
#  140: '심하죠',
#  141: '군대',
#  142: '잊는데는',
#  143: '저물어가네',
#  144: '사귄',
#  145: '어리석게',
#  146: '담긴',
#  147: '많겠지만',
#  148: '오랫동안',
#  149: '찾아봐요',
#  150: '질긴',
#  151: '기울이고',
#  152: '또폭',
#  153: '하고만',
#  154: '곤',
#  155: '월지',
#  156: '널',
#  157: '떠오른다',
#  158: '친구',
#  159: '못',
#  160: '친구사이',
#  161: '공',
#  162: '할줄도',
#  163: '일이이',
#  164: '오름',
#  165: '씹어',
#  166: '같네하하',
#  167: '하얘졌어',
#  168: '연휴',
#  169: '도술',
#  170: '다행',
#  171: '찼어',
#  172: '피곤하신',
#  173: '설명',
#  174: '자세',
#  175: '들어간다고',
#  176: '아련해',
#  177: '않았나',
#  178: '뜨끈한',
#  179: '타는줄',
#  180: '장해',
#  181: '안되나',
#  182: '비싼게',
#  183: '사귀다가헤어젔는데',
#  184: '살고싶어',
#  185: '선연하더라고요',
#  186: '씨앗',
#  187: '맞는것과',
#  188: '돕는',
#  189: '그렇다는',
#  190: '알았지',
#  191: '하고의',
#  192: '지우려',
#  193: '팔로우',
#  194: '밤',
#  195: '이룰수있을거예요',
#  196: '희망고문',
#  197: '공감',
#  198: '되겠네요',
#  199: '있대',
#  200: '만나러가세요',
#  201: '괜',
#  202: '자책',
#  203: '피해',
#  204: '누락',
#  205: '자장가',
#  206: '모르겠습니다',
#  207: 'O',
#  208: '힘빠지는',
#  209: '비판',
#  210: '지겨워',
#  211: '사귀려고',
#  212: '코스터',
#  213: '친해질까',
#  214: '촉',
#  215: '싱숭생숭해서',
#  216: '집아',
#  217: '이브',
#  218: '했네',
#  219: '애',
#  220: '설레면',
#  221: '좋아하지',
#  222: '광탈',
#  223: '바꿀수있을텐데',
#  224: '봤는데말',
#  225: '키우고싶어',
#  226: '않는데이거',
#  227: '망함',
#  228: '되는지',
#  229: '내든',
#  230: '마셨나',
#  231: '봤네요',
#  232: '놀랐겠네요',
#  233: '직원',
#  234: '멀어진다는데',
#  235: '남이같이',
#  236: '그렇',
#  237: '보내고오세요',
#  238: '죽진못하겠구',
#  239: '했을까요',
#  240: '떠져',
#  241: '문고',
#  242: '해주었다는',
#  243: '오해',
#  244: '좋았길',
#  245: '있었지하고',
#  246: '않으니',
#  247: '괜찮아졌다가',
#  248: '그립겠지만',
#  249: '그만두는',
#  250: '해볼까',
#  251: '알거',
#  252: '선택',
#  253: '춤',
#  254: '해줄수있어',
#  255: '내려는거라면',
#  256: '자식',
#  257: '목탄',
#  258: '독',
#  259: '세',
#  260: '특종',
#  261: '그럼에도',
#  262: '가지고있네요',
#  263: '알수있나',
#  264: '했더니',
#  265: '듣고싶다',
#  266: '아파서',
#  267: '변덕쟁이',
#  268: '때해선',
#  269: '두었을까',
#  270: '숫자',
#  271: '유지',
#  272: '갈수있을까',
#  273: '나옵니다',
#  274: '꾸네',
#  275: '칠',
#  276: '가오',
#  277: '챙겨줄까',
#  278: '배워놓는게',
#  279: '했다는',
#  280: '털털',
#  281: '하러가고싶다',
#  282: '잘살',
#  283: '지내자',
#  284: '원망',
#  285: '주아니',
#  286: '울고싶을',
#  287: '세심',
#  288: '먹으라고',
#  289: '떠보는걸',
#  290: '따야',
#  291: '미친거',
#  292: '빼도',
#  293: '만나도',
#  294: '좀쉬',
#  295: '많',
#  296: '카톡대화',
#  297: '한때',
#  298: '될지',
#  299: '끊기는거',
#  300: '연하',
#  301: '봐주세요',
#  302: '아깝다는',
#  303: '가내',
#  304: '싶다면',
#  305: '받으면',
#  306: '축복',
#  307: '바쁜게',
#  308: '타세요',
#  309: '따뜻해졌죠',
#  310: '열',
#  311: '공허함',
#  312: '생길까',
#  313: '담해줄래',
#  314: '정신차리세요',
#  315: 'ㅎㅎ',
#  316: '땐',
#  317: '좀넘은저의사랑그리고이별이야기',
#  318: '톡',
#  319: '채널',
#  320: '덜어',
#  321: '다른거니',
#  322: '무너짐',
#  323: '제해',
#  324: '어린',
#  325: '1000일',
#  326: '쓰던',
#  327: '만났든',
#  328: '잊지말자',
#  329: '왕만',
#  330: '설사',
#  331: '더주세요',
#  332: '콘서트',
#  333: '번하니',
#  334: '걸이',
#  335: '먹을수록',
#  336: '왔나요',
#  337: '의욕',
#  338: '풀릴거예요',
#  339: '흘려',
#  340: '편하고',
#  341: '기를하죠',
#  342: '중요한가',
#  343: '다른사람',
#  344: '상책',
#  345: '낮추는',
#  346: '연금',
#  347: '두려운데',
#  348: '잠을잘',
#  349: '결혼합시다',
#  350: '공시생',
#  351: '놀램',
#  352: '그만하는게',
#  353: '감수',
#  354: '추운',
#  355: '쉽',
#  356: '다치지',
#  357: '잃을거예요',
#  358: '왜현',
#  359: '갈',
#  360: '맞겠지',
#  361: '먹으면나에게도',
#  362: '뜬눈',
#  363: '본',
#  364: '타는거야',
#  365: '헤아리지말아요',
#  366: '열어',
#  367: '먹고자야지',
#  368: '허전할거',
#  369: '서노래',
#  370: '낀듯',
#  371: '남기기',
#  372: '살줄',
#  373: '올리내',
#  374: '장갑',
#  375: '허락',
#  376: '시보',
#  377: '정신병',
#  378: '왤',
#  379: '팁좀',
#  380: '회원',
#  381: '생겼으면',
#  382: '부서진',
#  383: '그랬던거죠',
#  384: '애석하지만',
#  385: '솔직하게말',
#  386: '될지도',
#  387: '좋을듯',
#  388: '무심한데',
#  389: '분히이해',
#  390: '한약',
#  391: '있지만',
#  392: '그럴까',
#  393: '가리는',
#  394: '차가고',
#  395: '익숙함이라는',
#  396: '맘추',
#  397: '쪼',
#  398: '두지말아요',
#  399: '여행지',
#  400: '불날',
#  401: '청해',
#  402: '썸탈때',
#  403: '했을지도',
#  404: '키왜안',
#  405: '힘들긴',
#  406: '순수한',
#  407: '바라겠습니다',
#  408: '빠져나오세요',
#  409: '나오기',
#  410: '오세요',
#  411: '노력',
#  412: '지내니',
#  413: '나아가야지',
#  414: '따라오게',
#  415: '도문',
#  416: '날림',
#  417: '까먹어',
#  418: '바뀌어',
#  419: '좋아하는데',
#  420: '보려고',
#  421: '이러지말자',
#  422: '페메',
#  423: '진부한말',
#  424: '듣고싶어요',
#  425: '세워',
#  426: '있는',
#  427: '걸게하고',
#  428: '버려야지',
#  429: '관계',
#  430: '하면나를',
#  431: '당연한거예요',
#  432: '잠자리',
#  433: '아무렇게나',
#  434: '미워지네',
#  435: '가두',
#  436: '하시겠어요',
#  437: '썸을길',
#  438: '계속',
#  439: '까먹지말고',
#  440: '볼텐데',
#  441: '곡',
#  442: '좋아하는이',
#  443: '많을까요',
#  444: '나라고',
#  445: '듣는데',
#  446: '시키는거',
#  447: '만날거예요',
#  448: '변해가요',
#  449: '싸우게',
#  450: '갖자하면',
#  451: '나가기도',
#  452: '될수',
#  453: '마셔요',
#  454: '보고왔다',
#  455: '자다가도',
#  456: '보내려',
#  457: '온',
#  458: '불행',
#  459: '난정',
#  460: '온종일',
#  461: '어울렸던',
#  462: '방가',
#  463: '글쎄요',
#  464: '심각해요',
#  465: '달랬더니',
#  466: '발인',
#  467: '뽑은',
#  468: '같다고',
#  469: '헹리',
#  470: '생길것',
#  471: '한일',
#  472: '명도',
#  473: '필통',
#  474: '안되겠지만',
#  475: '귀국',
#  476: '안지워',
#  477: '전술',
#  478: '좋아질거예요',
#  479: '수수한',
#  480: '작아져',
#  481: '지나가겠죠',
#  482: '버리세요',
#  483: '자고있을지도',
#  484: '돼서',
#  485: '완전히',
#  486: '잊을수가있을까',
#  487: '못자고',
#  488: '가능할까',
#  489: '힐링',
#  490: '찍어주세요',
#  491: '이니까',
#  492: '가죠',
#  493: '부모님',
#  494: '불공평한거',
#  495: '모태솔로',
#  496: '화보',
#  497: '있는데내가',
#  498: '미래',
#  499: '추세더라구요',
#  500: '야하는것도',
#  501: '재채기',
#  502: '홀',
#  503: '쉬운가',
#  504: '닮아서',
#  505: '곧주말이',
#  506: '죽고싶은',
#  507: '봄날',
#  508: '잊혀',
#  509: '더울어도',
#  510: '생겼는지도',
#  511: '부족한가',
#  512: '지만',
#  513: '호칭',
#  514: '이기',
#  515: '나빴네',
#  516: '받아줘',
#  517: '헤어질거면',
#  518: '소중하던',
#  519: '날짜',
#  520: '이제마',
#  521: '큰',
#  522: '걸거',
#  523: '취',
#  524: '받아들이는것인가',
#  525: '차있더라',
#  526: '미남',
#  527: '난다면',
#  528: '들이었죠',
#  529: '될듯',
#  530: '행복해야',
#  531: '참답',
#  532: '리다',
#  533: '나아질거야',
#  534: '달라질까',
#  535: '먹었다',
#  536: '깐깐해',
#  537: '교복',
#  538: '좋으면서도',
#  539: '남전',
#  540: '싸웠어',
#  541: '위병',
#  542: '이라고는',
#  543: '모르고있을수도',
#  544: '놓친',
#  545: '좋아졌어',
#  546: '다크서클',
#  547: '날카로워진다',
#  548: '아름다운',
#  549: '나갔어',
#  550: '기를까',
#  551: '바랐지만',
#  552: '의기나긴이야기',
#  553: '절대로',
#  554: '40일',
#  555: '이되었나봐요',
#  556: '마디네',
#  557: '결별',
#  558: '똑같아',
#  559: '재밌을거예요',
#  560: '기만',
#  561: '자기',
#  562: '꿀수있다면',
#  563: '힘들어하지말아요',
#  564: '예매',
#  565: '보고',
#  566: '있었는데',
#  567: '설레',
#  568: '직감',
#  569: '들어줄',
#  570: '헤어진여',
#  571: '말못하는',
#  572: '하는사',
#  573: '잠기는게',
#  574: '헤어졌으니',
#  575: '발렌타인데이',
#  576: '편하겠지',
#  577: '쉬고싶어',
#  578: '문득',
#  579: '크리',
#  580: '떠가기전하는',
#  581: '그만둔',
#  582: '지독한',
#  583: '괜찮아지려나',
#  584: '지을수',
#  585: '끓여서',
#  586: '받고있다고말',
#  587: '맞아요',
#  588: '실험실',
#  589: '행복하게도',
#  590: '흔들리나요',
#  591: '이미',
#  592: '알았어요',
#  593: '겁',
#  594: '쉬고있어',
#  595: '배우는거야',
#  596: '바라는것도',
#  597: '쪽지',
#  598: '까먹겠죠',
#  599: '조',
#  600: '크시',
#  601: '내게',
#  602: '싫어하지',
#  603: '질테',
#  604: '옆',
#  605: '공채',
#  606: '충실하면',
#  607: '어울림',
#  608: '뽀송뽀송',
#  609: '불쑥',
#  610: '만나는',
#  611: '나폰겜',
#  612: '슬픈말이네요',
#  613: '꾼건',
#  614: '이해해',
#  615: '만들더라고요',
#  616: '간만',
#  617: '낸다',
#  618: '돌봐줘',
#  619: '다가오지마',
#  620: '수족',
#  621: '사귀고있지',
#  622: '없겠네요',
#  623: '이어나가는게',
#  624: '데이',
#  625: '아무리',
#  626: '실',
#  627: '헤어져야',
#  628: '이럴',
#  629: '마안',
#  630: '마트',
#  631: '나온거',
#  632: '상관없지만',
#  633: '찾았습니다',
#  634: '철',
#  635: '괴롭네',
#  636: '김치',
#  637: '나가야하는데',
#  638: '짜증난다',
#  639: '매달렸나',
#  640: '고백',
#  641: '라는',
#  642: '게맘',
#  643: '다녀',
#  644: '타냐고',
#  645: '자취',
#  646: '돌아가고',
#  647: '목숨',
#  648: '알아차렸을수도',
#  649: '지냈나요',
#  650: '평온',
#  651: '붙잡고싶다면',
#  652: '중고',
#  653: '때매',
#  654: '따지고싶은데',
#  655: '할수록',
#  656: '주인',
#  657: '안된다고',
#  658: '넓고',
#  659: '틀',
#  660: '편해도되',
#  661: '성숙해지는',
#  662: '놀자',
#  663: '해내고있어요',
#  664: '부도',
#  665: '기운내는것을',
#  666: '하고있어',
#  667: '벌떡',
#  668: '사해',
#  669: '궁금하니까',
#  670: '다퉜어',
#  671: '말놓으려',
#  672: '꺼내고싶은데',
#  673: '온통',
#  674: '익숙해지는',
#  675: '에놀',
#  676: '중소기업',
#  677: '가습기',
#  678: '받지',
#  679: '소나기',
#  680: '힘든데도',
#  681: '첫날',
#  682: '만나고싶어',
#  683: '풀었네요',
#  684: '가량',
#  685: '살아가고',
#  686: '열쇠',
#  687: '빨렸',
#  688: '않는것이겠죠',
#  689: '지나가지말지',
#  690: '소심',
#  691: '하고픈말다',
#  692: '두지',
#  693: '말려',
#  694: '만나고와',
#  695: '헤어졌데',
#  696: '지내고',
#  697: '띄는',
#  698: '세탁기',
#  699: '요리',
#  700: '마법',
#  701: '부러우면',
#  702: '눈물났어',
#  703: '멋있게',
#  704: '타지말아야지',
#  705: '씻기',
#  706: '부는아니에요',
#  707: '없을수있어요',
#  708: '좋아하는줄',
#  709: '위험해',
#  710: '잠을자',
#  711: '호랑이',
#  712: '담을수',
#  713: '고칠수있을거예요',
#  714: '안되겠지',
#  715: '않은듯',
#  716: '나눠',
#  717: '알겠어서',
#  718: '설레요',
#  719: '이천원',
#  720: '자꾸나',
#  721: '모아니',
#  722: '한테',
#  723: '덜해지는것',
#  724: '편해',
#  725: '이란시간을정리했습니다',
#  726: '접어',
#  727: '치료받아야하나',
#  728: '움직이세요',
#  729: '중요하니까',
#  730: '갚냐',
#  731: '누굴까',
#  732: '버려줘서',
#  733: '우울할',
#  734: '카페',
#  735: '근데',
#  736: '큰게',
#  737: '힘드시겠네요',
#  738: '찬물',
#  739: '볼것',
#  740: '물못',
#  741: '면알',
#  742: '사랑받는걸',
#  743: '안될것도',
#  744: '찾아왔네',
#  745: '게이',
#  746: '타고있는데',
#  747: '식상한말이라도',
#  748: '너그러웠으면',
#  749: '전세',
#  750: '쓰',
#  751: '높나',
#  752: '그래',
#  753: '필요할수있어요',
#  754: '당해',
#  755: '살찔까봐',
#  756: '드론',
#  757: '준것보다',
#  758: '있는주말',
#  759: '같았는데',
#  760: '내가다시',
#  761: '종교의자유',
#  762: '가자던',
#  763: '예쁘',
#  764: '맞는거',
#  765: '썰러',
#  766: '상속',
#  767: '된여자친구랑이별',
#  768: '일거야',
#  769: '느낄지',
#  770: '벌',
#  771: '감당',
#  772: '지우는것을',
#  773: '뜨는거',
#  774: '오랜',
#  775: '덤덤',
#  776: '변하네',
#  777: '르름',
#  778: '더안',
#  779: '게다가',
#  780: '뒀네요',
#  781: '무궁무진',
#  782: '째네',
#  783: '가야겠네',
#  784: '였길',
#  785: '앞둔이',
#  786: '돌리기',
#  787: '지워지겠지',
#  788: '톡안',
#  789: '이었을까',
#  790: '보내야지',
#  791: '닫고',
#  792: '헤어지자',
#  793: '잡고싶은데',
#  794: '인지',
#  795: '이상정',
#  796: '나오면',
#  797: '하늘아래',
#  798: '어울리는',
#  799: '주기',
#  800: '빠르면',
#  801: '에걸쳐서정리를했습니다',
#  802: '똑똑',
#  803: '간질간질',
#  804: '찜질방',
#  805: '특판',
#  806: '거너',
#  807: '금수',
#  808: '걸릴거',
#  809: '아줌마',
#  810: '시들으세요',
#  811: '멋있을텐데',
#  812: '냉증',
#  813: '8',
#  814: '젊게',
#  815: '쉬어',
#  816: '공통점',
#  817: '복잡하겠네요',
#  818: '많아지죠',
#  819: '녹음',
#  820: '탈것',
#  821: '방심했어',
#  822: '슬프게만',
#  823: '였다',
#  824: '은애',
#  825: '척',
#  826: '좋아하면다시',
#  827: '전학',
#  828: '동안난미친듯이살았다',
#  829: '그러든지',
#  830: '끌리',
#  831: '공황장애',
#  832: '월세',
#  833: '지오',
#  834: '사랑받는구나',
#  835: '번안',
#  836: '끊었었는데',
#  837: '다녀야하나',
#  838: '잊어야하는게',
#  839: '해줄수있을까',
#  840: '이욕',
#  841: '쳐다봄',
#  842: '보러가고싶다',
#  843: '딸거야',
#  844: '둘리',
#  845: '비우세요',
#  846: '치열한',
#  847: '상메',
#  848: '용기랍니다',
#  849: '안녕',
#  850: '알겠어',
#  851: '허전하',
#  852: '찾아가는건',
#  853: '가라',
#  854: '잠못',
#  855: '그런거니',
#  856: '선의',
#  857: '위험한거',
#  858: '만장',
#  859: '남았어',
#  860: '잡힐듯',
#  861: '였으면',
#  862: '내가아는',
#  863: '더워',
#  864: '변했다고',
#  865: '수월해요',
#  866: '내렸어',
#  867: '그런말하더군',
#  868: '졸린데',
#  869: '전공',
#  870: '걸음',
#  871: '까',
#  872: '식물',
#  873: '차네',
#  874: '붙잡고싶습니다',
#  875: '비가오네',
#  876: '보내는거',
#  877: '사라지지',
#  878: '터짐',
#  879: '헷갈릴수있지요',
#  880: '번호',
#  881: '넣어',
#  882: '않아요',
#  883: '아깝다',
#  884: '아자',
#  885: '편하게못해',
#  886: '감았는데',
#  887: '살',
#  888: '아기',
#  889: '그런대로',
#  890: '오늘날',
#  891: '막고싶어',
#  892: '좋아하는내가',
#  893: '쓰는지',
#  894: '비슷해',
#  895: '아프겠지만',
#  896: '기다려줄것',
#  897: '괘씸하고',
#  898: '질린다네',
#  899: '오네',
#  900: '있었겠어요',
#  901: '남못',
#  902: '하고내말은',
#  903: '잊지',
#  904: '로안',
#  905: '꿰매',
#  906: '뻔해',
#  907: '만에',
#  908: '자체',
#  909: '마다의',
#  910: '중요합니다',
#  911: '대외',
#  912: '우스워질',
#  913: '효율',
#  914: '됐어',
#  915: '귀찮은',
#  916: '필요하다면하는게',
#  917: '차라',
#  918: '여기있으니까',
#  919: '소',
#  920: '해서',
#  921: '찾아갔는데',
#  922: '였겠어요',
#  923: '쓰이겠네요',
#  924: '죠',
#  925: '예쁘더라',
#  926: '고막',
#  927: '나가도',
#  928: '않을거란',
#  929: '행복했길',
#  930: '대충',
#  931: '그러면말하세요',
#  932: '변해야',
#  933: '씁니다',
#  934: '싫다',
#  935: '서울',
#  936: '근',
#  937: '털까',
#  938: '무게',
#  939: '해요',
#  940: '느꼈을',
#  941: '맞지',
#  942: '많을까',
#  943: '백수',
#  944: '궁금한게',
#  945: '잘해주는데',
#  946: '좋아진것',
#  947: '나가기가',
#  948: '쎄',
#  949: '식당',
#  950: '싶은건',
#  951: '알땐',
#  952: '않은걸',
#  953: '말하세요',
#  954: '신호',
#  955: '잠꾸러기',
#  956: '해달라고기',
#  957: '안됩니다',
#  958: '닉',
#  959: '들어왔나',
#  960: '난또',
#  961: '해안',
#  962: '시려',
#  963: '나도하고',
#  964: '않되',
#  965: '내려놓으면',
#  966: '월간',
#  967: '놀았는데다',
#  968: '새장',
#  969: '류',
#  970: '드시고오셨길',
#  971: '자랑',
#  972: '보내야하는데',
#  973: '제목',
#  974: '은우',
#  975: '질린듯',
#  976: '먹는',
#  977: '체력',
#  978: '사귈래',
#  979: '만나는데',
#  980: '회원정보',
#  981: '찍은',
#  982: '사는거예요',
#  983: '설레나',
#  984: '주가',
#  985: '남있는데',
#  986: '사먹을까',
#  987: '돌아오기',
#  988: '자연스러워질',
#  989: '가위',
#  990: '개쫄음',
#  991: '자르지말까',
#  992: '보이스피싱',
#  993: '많아서',
#  994: '계륵',
#  995: '아이고',
#  996: '걸알',
#  997: '어색할거',
#  998: '멍충',
#  999: '그만하고싶네',
#  ...}
